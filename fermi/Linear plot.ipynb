# %%
import healpy
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import matplotlib as mpl
from astropy.table import Table
from scipy.optimize import curve_fit

# %%
plt.style.use('seaborn')

# %%
#open map #energy range are 100-300,000 MeV
#a day
mapp_day = fits.open('day/L210628115715F357373F68_PH00.fits')
t_mapp_day = Table(mapp_day[1].data)
mapp_select_day = fits.open('day/8yearsday.fits')
t_mapp_select_day = Table(mapp_select_day[1].data)
mapp_filtered_day = fits.open('day/8yearsday_filtered.fits')
t_mapp_filtered_day = Table(mapp_filtered_day[1].data)

# a week
mapp_week = fits.open('week/L210628115918F357373F35_PH00.fits')
t_mapp_week = Table(mapp_week[1].data)
mapp_select_week = fits.open('week/8yearsweek.fits')
t_mapp_select_week = Table(mapp_select_week[1].data)
mapp_filtered_week = fits.open('week/8yearsweek_filtered.fits')
t_mapp_filtered_week = Table(mapp_filtered_week[1].data)

#1 month
mapp_1month = fits.open('1month/L210628120008F357373F91_PH00.fits')
t_mapp_1month = Table(mapp_1month[1].data)
mapp_select_1month = fits.open('1month/8years1month.fits')
t_mapp_select_1month = Table(mapp_select_1month[1].data)
mapp_filtered_1month = fits.open('1month/8years1month_filtered.fits')
t_mapp_filtered_1month = Table(mapp_filtered_1month[1].data)

# 2 months
mapp_2month = fits.open('2month/L210628120123F357373F01_PH00.fits')
t_mapp_2month = Table(mapp_2month[1].data)
mapp_select_2month = fits.open('2month/8years2month.fits')
t_mapp_select_2month = Table(mapp_select_2month[1].data)
mapp_filtered_2month = fits.open('2month/8years2month_filtered.fits')
t_mapp_filtered_2month = Table(mapp_filtered_2month[1].data)

# 3 months
mapp_3month = fits.open('3month/L210628120319F357373F94_PH00.fits')
t_mapp_3month = Table(mapp_3month[1].data)
mapp_select_3month = fits.open('3month/8years3month.fits')
t_mapp_select_3month = Table(mapp_select_3month[1].data)
mapp_filtered_3month = fits.open('3month/8years3month_filtered.fits')
t_mapp_filtered_3month = Table(mapp_filtered_3month[1].data)

# 4 months
mapp_4month = fits.open('4month/L210628120412F357373F34_PH00.fits')
t_mapp_4month = Table(mapp_4month[1].data)
mapp_select_4month = fits.open('4month/8years4month.fits')
t_mapp_select_4month = Table(mapp_select_4month[1].data)
mapp_filtered_4month = fits.open('4month/8years4month_filtered.fits')
t_mapp_filtered_4month = Table(mapp_filtered_4month[1].data)

# 5 months
mapp_5month0 = fits.open('5month/L210628120531F357373F79_PH00.fits')
t_mapp_5month0 = Table(mapp_5month0[1].data)
mapp_5month1 = fits.open('5month/L210628120531F357373F79_PH01.fits')
t_mapp_5month1 = Table(mapp_5month1[1].data)
mapp_select_5month = fits.open('5month/8years5month.fits')
t_mapp_select_5month = Table(mapp_select_5month[1].data)
mapp_filtered_5month = fits.open('5month/8years5month_filtered.fits')
t_mapp_filtered_5month = Table(mapp_filtered_5month[1].data)


# 6 months
mapp_6month0 = fits.open('6month/L210628120642F357373F63_PH00.fits')
t_mapp_6month0 = Table(mapp_6month0[1].data)
mapp_6month1 = fits.open('6month/L210628120642F357373F63_PH01.fits')
t_mapp_6month1 = Table(mapp_6month1[1].data)
mapp_select_6month = fits.open('6month/8years6month.fits')
t_mapp_select_6month = Table(mapp_select_6month[1].data)
mapp_filtered_6month = fits.open('6month/8years6month_filtered.fits')
t_mapp_filtered_6month = Table(mapp_filtered_6month[1].data)

# %%
# 7 months
mapp_7month0 = fits.open('7month/L210628120752F357373F95_PH00.fits')
t_mapp_7month0 = Table(mapp_7month0[1].data)
mapp_7month1 = fits.open('7month/L210628120752F357373F95_PH01.fits')
t_mapp_7month1 = Table(mapp_7month1[1].data)
mapp_select_7month = fits.open('7month/8years7month.fits')
t_mapp_select_7month = Table(mapp_select_7month[1].data)
mapp_filtered_7month = fits.open('7month/8years7month_filtered.fits')
t_mapp_filtered_7month = Table(mapp_filtered_7month[1].data)

# 8 months
mapp_8month0 = fits.open('8month/L210628120938F357373F04_PH00.fits')
t_mapp_8month0 = Table(mapp_8month0[1].data)
mapp_8month1 = fits.open('8month/L210628120938F357373F04_PH01.fits')
t_mapp_8month1 = Table(mapp_8month1[1].data)
mapp_select_8month = fits.open('8month/8years8month.fits')
t_mapp_select_8month = Table(mapp_select_8month[1].data)
mapp_filtered_8month = fits.open('8month/8years8month_filtered.fits')
t_mapp_filtered_8month = Table(mapp_filtered_8month[1].data)

# 9 months
mapp_9month0 = fits.open('9month/L210628121049F357373F82_PH00.fits')
t_mapp_9month0 = Table(mapp_9month0[1].data)
mapp_9month1 = fits.open('9month/L210628121049F357373F82_PH01.fits')
t_mapp_9month1 = Table(mapp_9month1[1].data)
mapp_9month2 = fits.open('9month/L210628121049F357373F82_PH02.fits')
t_mapp_9month2 = Table(mapp_9month2[1].data)
mapp_select_9month = fits.open('9month/8years9month.fits')
t_mapp_select_9month = Table(mapp_select_9month[1].data)
mapp_filtered_9month = fits.open('9month/8years9month_filtered.fits')
t_mapp_filtered_9month = Table(mapp_filtered_9month[1].data)

# 10 months
mapp_10month0 = fits.open('10month/L210628121210F357373F06_PH00.fits')
t_mapp_10month0 = Table(mapp_10month0[1].data)
mapp_10month1 = fits.open('10month/L210628121210F357373F06_PH01.fits')
t_mapp_10month1 = Table(mapp_10month1[1].data)
mapp_10month2 = fits.open('10month/L210628121210F357373F06_PH02.fits')
t_mapp_10month2 = Table(mapp_10month2[1].data)
mapp_select_10month = fits.open('10month/8years10month.fits')
t_mapp_select_10month = Table(mapp_select_10month[1].data)
mapp_filtered_10month = fits.open('10month/8years10month_filtered.fits')
t_mapp_filtered_10month = Table(mapp_filtered_10month[1].data)

# 11 months
mapp_11month0 = fits.open('11month/L210628121330F357373F34_PH00.fits')
t_mapp_11month0 = Table(mapp_11month0[1].data)
mapp_11month1 = fits.open('11month/L210628121330F357373F34_PH01.fits')
t_mapp_11month1 = Table(mapp_11month1[1].data)
mapp_11month2 = fits.open('11month/L210628121330F357373F34_PH02.fits')
t_mapp_11month2 = Table(mapp_11month2[1].data)
mapp_select_11month = fits.open('11month/8years11month.fits')
t_mapp_select_11month = Table(mapp_select_11month[1].data)
mapp_filtered_11month = fits.open('11month/8years11month_filtered.fits')
t_mapp_filtered_11month = Table(mapp_filtered_11month[1].data)

# 12 months
mapp_12month0 = fits.open('12month/L210628121503F357373F86_PH00.fits')
t_mapp_12month0 = Table(mapp_12month0[1].data)
mapp_12month1 = fits.open('12month/L210628121503F357373F86_PH01.fits')
t_mapp_12month1 = Table(mapp_12month1[1].data)
mapp_12month2 = fits.open('12month/L210628121503F357373F86_PH02.fits')
t_mapp_12month2 = Table(mapp_12month2[1].data)
mapp_12month3 = fits.open('12month/L210628121503F357373F86_PH03.fits')
t_mapp_12month3 = Table(mapp_12month3[1].data)
mapp_select_12month = fits.open('12month/8years12month.fits')
t_mapp_select_12month = Table(mapp_select_12month[1].data)
mapp_filtered_12month = fits.open('12month/8years12month_filtered.fits')
t_mapp_filtered_12month = Table(mapp_filtered_12month[1].data)

# %%
#3 year
mapp_3year0 = fits.open('3year/L210628121705F357373F34_PH00.fits')
t_mapp_3year0 = Table(mapp_3year0[1].data)
mapp_3year1 = fits.open('3year/L210628121705F357373F34_PH01.fits')
t_mapp_3year1 = Table(mapp_3year1[1].data)
mapp_3year2 = fits.open('3year/L210628121705F357373F34_PH02.fits')
t_mapp_3year2 = Table(mapp_3year2[1].data)
mapp_3year3 = fits.open('3year/L210628121705F357373F34_PH03.fits')
t_mapp_3year3 = Table(mapp_3year3[1].data)
mapp_3year4 = fits.open('3year/L210628121705F357373F34_PH04.fits')
t_mapp_3year4 = Table(mapp_3year4[1].data)
mapp_3year5 = fits.open('3year/L210628121705F357373F34_PH05.fits')
t_mapp_3year5 = Table(mapp_3year5[1].data)
mapp_3year6 = fits.open('3year/L210628121705F357373F34_PH06.fits')
t_mapp_3year6 = Table(mapp_3year6[1].data)
mapp_3year7 = fits.open('3year/L210628121705F357373F34_PH07.fits')
t_mapp_3year7 = Table(mapp_3year7[1].data)
mapp_3year8 = fits.open('3year/L210628121705F357373F34_PH08.fits')
t_mapp_3year8 = Table(mapp_3year8[1].data)
mapp_select_3year = fits.open('3year/8years3year.fits')
t_mapp_select_3year = Table(mapp_select_3year[1].data)
mapp_filtered_3year = fits.open('3year/8years3year_filtered.fits')
t_mapp_filtered_3year = Table(mapp_filtered_3year[1].data)

#5 year
mapp_5year0 = fits.open('5year/L210628122117F357373F02_PH00.fits')
t_mapp_5year0 = Table(mapp_5year0[1].data)
mapp_5year1 = fits.open('5year/L210628122117F357373F02_PH01.fits')
t_mapp_5year1 = Table(mapp_5year1[1].data)
mapp_5year2 = fits.open('5year/L210628122117F357373F02_PH02.fits')
t_mapp_5year2 = Table(mapp_5year2[1].data)
mapp_5year3 = fits.open('5year/L210628122117F357373F02_PH03.fits')
t_mapp_5year3 = Table(mapp_5year3[1].data)
mapp_5year4 = fits.open('5year/L210628122117F357373F02_PH04.fits')
t_mapp_5year4 = Table(mapp_5year4[1].data)
mapp_5year5 = fits.open('5year/L210628122117F357373F02_PH05.fits')
t_mapp_5year5 = Table(mapp_5year5[1].data)
mapp_5year6 = fits.open('5year/L210628122117F357373F02_PH06.fits')
t_mapp_5year6 = Table(mapp_5year6[1].data)
mapp_5year7 = fits.open('5year/L210628122117F357373F02_PH07.fits')
t_mapp_5year7 = Table(mapp_5year7[1].data)
mapp_5year8 = fits.open('5year/L210628122117F357373F02_PH08.fits')
t_mapp_5year8 = Table(mapp_5year8[1].data)
mapp_select_5year = fits.open('5year/8years5year.fits')
t_mapp_select_5year = Table(mapp_select_5year[1].data)
mapp_filtered_5year = fits.open('5year/8years5year_filtered.fits')
t_mapp_filtered_5year = Table(mapp_filtered_5year[1].data)

#8 year
mapp_8year0 = fits.open('8year/L210628122441F357373F45_PH00.fits')
t_mapp_8year0 = Table(mapp_8year0[1].data)
mapp_8year1 = fits.open('8year/L210628122441F357373F45_PH01.fits')
t_mapp_8year1 = Table(mapp_8year1[1].data)
mapp_8year2 = fits.open('8year/L210628122441F357373F45_PH02.fits')
t_mapp_8year2 = Table(mapp_8year2[1].data)
mapp_8year3 = fits.open('8year/L210628122441F357373F45_PH03.fits')
t_mapp_8year3 = Table(mapp_8year3[1].data)
mapp_8year4 = fits.open('8year/L210628122441F357373F45_PH04.fits')
t_mapp_8year4 = Table(mapp_8year4[1].data)
mapp_8year5 = fits.open('8year/L210628122441F357373F45_PH05.fits')
t_mapp_8year5 = Table(mapp_8year5[1].data)
mapp_8year6 = fits.open('8year/L210628122441F357373F45_PH06.fits')
t_mapp_8year6 = Table(mapp_8year6[1].data)
mapp_8year7 = fits.open('8year/L210628122441F357373F45_PH07.fits')
t_mapp_8year7 = Table(mapp_8year7[1].data)
mapp_8year8 = fits.open('8year/L210628122441F357373F45_PH08.fits')
t_mapp_8year8 = Table(mapp_8year8[1].data)
mapp_select_8year = fits.open('8year/8years8year.fits')
t_mapp_select_8year = Table(mapp_select_8year[1].data)
mapp_filtered_8year = fits.open('8year/8years8year_filtered.fits')
t_mapp_filtered_8year = Table(mapp_filtered_8year[1].data)

# %%
number8year =(len(t_mapp_day),len(t_mapp_week),len(t_mapp_1month),
         len(t_mapp_2month),len(t_mapp_3month),len(t_mapp_4month),
         len(t_mapp_5month0)+len(t_mapp_5month1),
         len(t_mapp_6month0)+len(t_mapp_6month1),
         len(t_mapp_7month0)+len(t_mapp_7month1),
         len(t_mapp_8month0)+len(t_mapp_8month1),
         len(t_mapp_9month0)+len(t_mapp_9month1)+len(t_mapp_9month2),
         len(t_mapp_10month0)+len(t_mapp_10month1)+len(t_mapp_10month2),
         len(t_mapp_11month0)+len(t_mapp_11month1)+len(t_mapp_11month2),
         len(t_mapp_12month0)+len(t_mapp_12month1)+len(t_mapp_12month2)+len(t_mapp_12month3),
         len(t_mapp_3year0)+len(t_mapp_3year1)+len(t_mapp_3year2)+len(t_mapp_3year3)+len(t_mapp_3year4)+len(t_mapp_3year5)+len(t_mapp_3year6)+len(t_mapp_3year7)+len(t_mapp_3year8),
         len(t_mapp_5year0)+len(t_mapp_5year1)+len(t_mapp_5year2)+len(t_mapp_5year3)+len(t_mapp_5year4)+len(t_mapp_5year5)+len(t_mapp_5year6)+len(t_mapp_5year7)+len(t_mapp_5year8),
         len(t_mapp_8year0)+len(t_mapp_8year1)+len(t_mapp_8year2)+len(t_mapp_8year3)+len(t_mapp_8year4)+len(t_mapp_8year5)+len(t_mapp_8year6)+len(t_mapp_8year7)+len(t_mapp_8year8)
         )


numberselect =(len(t_mapp_select_day),len(t_mapp_select_week),len(t_mapp_select_1month),
         len(t_mapp_select_2month),len(t_mapp_select_3month),len(t_mapp_select_4month),
         len(t_mapp_select_5month),
         len(t_mapp_select_6month),
         len(t_mapp_select_7month),
         len(t_mapp_select_8month),
         len(t_mapp_select_9month),
         len(t_mapp_select_10month),
         len(t_mapp_select_11month),
         len(t_mapp_select_12month),
         len(t_mapp_select_3year),
         len(t_mapp_select_5year),
         len(t_mapp_select_8year))

numberfiltered =(len(t_mapp_filtered_day),len(t_mapp_filtered_week),len(t_mapp_filtered_1month),
         len(t_mapp_filtered_2month),len(t_mapp_filtered_3month),len(t_mapp_filtered_4month),
         len(t_mapp_filtered_5month),
         len(t_mapp_filtered_6month),
         len(t_mapp_filtered_7month),
         len(t_mapp_filtered_8month),
         len(t_mapp_filtered_9month),
         len(t_mapp_filtered_10month),
         len(t_mapp_filtered_11month),
         len(t_mapp_filtered_12month),
         len(t_mapp_filtered_3year),
         len(t_mapp_filtered_5year),
         len(t_mapp_filtered_8year))

number1year =(len(t_mapp_day),len(t_mapp_week),len(t_mapp_1month),
         len(t_mapp_2month),len(t_mapp_3month),len(t_mapp_4month),
         len(t_mapp_5month0)+len(t_mapp_5month1),
         len(t_mapp_6month0)+len(t_mapp_6month1),
         len(t_mapp_7month0)+len(t_mapp_7month1),
         len(t_mapp_8month0)+len(t_mapp_8month1),
         len(t_mapp_9month0)+len(t_mapp_9month1)+len(t_mapp_9month2),
         len(t_mapp_10month0)+len(t_mapp_10month1)+len(t_mapp_10month2),
         len(t_mapp_11month0)+len(t_mapp_11month1)+len(t_mapp_11month2),
         len(t_mapp_12month0)+len(t_mapp_12month1)+len(t_mapp_12month2)+len(t_mapp_12month3))
    
number1year_select =(len(t_mapp_select_day),len(t_mapp_select_week),len(t_mapp_select_1month),
         len(t_mapp_select_2month),len(t_mapp_select_3month),len(t_mapp_select_4month),
         len(t_mapp_select_5month),
         len(t_mapp_select_6month),
         len(t_mapp_select_7month),
         len(t_mapp_select_8month),
         len(t_mapp_select_9month),
         len(t_mapp_select_10month),
         len(t_mapp_select_11month),
         len(t_mapp_select_12month))
    

number1year_filtered =(len(t_mapp_filtered_day),len(t_mapp_filtered_week),len(t_mapp_filtered_1month),
         len(t_mapp_filtered_2month),len(t_mapp_filtered_3month),len(t_mapp_filtered_4month),
         len(t_mapp_filtered_5month),
         len(t_mapp_filtered_6month),
         len(t_mapp_filtered_7month),
         len(t_mapp_filtered_8month),
         len(t_mapp_filtered_9month),
         len(t_mapp_filtered_10month),
         len(t_mapp_filtered_11month),
         len(t_mapp_filtered_12month))
                 
day8year =(1,7,30,61,89,120,151,181,212,242,273,304,334,365,1103,1833,2922)
day1year = (1,7,30,61,89,120,151,181,212,242,273,304,334,365)
#make data smooth
day8yearnew = np.linspace(1, 2922, 2922) 
#print(day8yearnew)
day1yearnew = np.linspace(1, 365, 365) 
#print(day1yearnew)

# %%
#plot 2 D 
#-----fit curve----#
#Show 1-365 day
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(40,20))

def linear(day, a):
	return (a * day)
 
popt1, pcov1 = curve_fit(linear, day8year, number8year ,method='lm')
a1 = popt1
popt2, pcov2 = curve_fit(linear, day8year, numberselect ,method='lm')
a2 = popt2
popt3, pcov3 = curve_fit(linear, day8year, numberfiltered ,method='lm')
a3 = popt3


# calculate the output for the range
y_a1 = linear(day8yearnew, a1)
y_a2 = linear(day8yearnew, a2)
y_a3 = linear(day8yearnew, a3)



# create a line plot for the mapping function
#8 year
ax1.plot(day8yearnew, y_a1, linewidth=2, label='%.5f * x ' % tuple(popt1),fillstyle='bottom',color='lime')
ax1.scatter(day8year, number8year,color='green', label='raw data')
#select
ax1.plot(day8yearnew, y_a2, linewidth=2, label='%.5f * x ' % tuple(popt2),fillstyle='bottom',color='blue')
ax1.scatter(day8year, numberselect,color='navy', label='select data')
#filtered
ax1.plot(day8yearnew, y_a3, linewidth=2, label='%.5f * x ' % tuple(popt3),fillstyle='bottom',color='violet')
ax1.scatter(day8year, numberfiltered,color='purple', label='filtered data')
###########################
ax1.tick_params(labelsize=20) 
ax1.set_xlabel('Time (days)',fontsize=25)
ax1.set_ylabel('Count of photons (counts)',fontsize=25)
fig.suptitle('Observation dates record',fontsize=50)
ax1.legend(loc='lower right',fontsize=25)


#show 365 day
y_b1 = linear(day1yearnew, a1)
y_b2 = linear(day1yearnew, a2)
y_b3 = linear(day1yearnew, a3)

# create a line plot for the mapping function
ax2.plot(day1yearnew, y_b1, linewidth=2, label='%.5f * x ' % tuple(popt1),fillstyle='bottom',color='lime')
ax2.scatter(day1year, number1year,color='green', label='raw data')
#select
ax2.plot(day1yearnew, y_b2, linewidth=2, label='%.5f * x ' % tuple(popt2),fillstyle='bottom',color='blue')
ax2.scatter(day1year, number1year_select,color='navy', label='select data')
#filtered
ax2.plot(day1yearnew, y_b3, linewidth=2, label='%.5f * x ' % tuple(popt3),fillstyle='bottom',color='violet')
ax2.scatter(day1year, number1year_filtered,color='purple', label='filtered data')
###########################
ax2.tick_params(labelsize=20) 
ax2.set_xlabel('Time (days)',fontsize=25)
ax2.set_ylabel('Count of photons (counts)',fontsize=25)
fig.suptitle('Observation dates record',fontsize=50)
ax2.legend(loc='lower right',fontsize=25)
plt.show()
