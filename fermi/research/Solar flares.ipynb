# %%
import fermitools 
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
plt.style.use('seaborn')
catalog = fits.open("gll_psc_v22.fit")

# %%
t = Table(catalog[1].data)
new_glon = np.logical_and(t['GLON'] >=52, t['GLON']<=55)
new_tg = t[new_glon]
new_glat = np.logical_and(new_tg['GLAT'] >= -1.2, new_tg['GLAT'] <=1.8)
new_t = new_tg[new_glat]

# %%
#non solar flare event
#2008-12-22 
#DATE-OBS= '2008-12-22T00:00:00.0000'
#DATE-END= '2008-12-23T00:00:00.0000'
#For 1 day
raw_data_0= fits.open('raw data/20081222_PH00.fits')
raw_data= Table(raw_data_0[1].data)
#raw data in a minute
raw_data_1 = fits.open('raw data/20081222-195230-195330')
raw_data_1minute = Table(raw_data_1[1].data)
#raw data in 2 minutes
raw_data_2 = fits.open('raw data/20081222-195200-195400')
raw_data_2minute = Table(raw_data_2[1].data)
#raw data in 3 minutes
raw_data_3 = fits.open('raw data/20081222-195130-195430')
raw_data_3minute = Table(raw_data_3[1].data)
#raw data in 4 minutes
raw_data_4 = fits.open('raw data/20081222-195100-195500')
raw_data_4minute = Table(raw_data_4[1].data)
#raw data in 5 minutes
raw_data_5 = fits.open('raw data/20081222-195030-195530')
raw_data_5minute = Table(raw_data_5[1].data)
#raw data in 6 minutes
raw_data_6 = fits.open('raw data/20081222-195000-195600')
raw_data_6minute = Table(raw_data_6[1].data)
#raw data in 7 minutes
raw_data_7 = fits.open('raw data/20081222-194930-195630')
raw_data_7minute = Table(raw_data_7[1].data)
#raw data in 8 minutes
raw_data_8 = fits.open('raw data/20081222-194900-195700')
raw_data_8minute = Table(raw_data_8[1].data)
#raw data in 9 minutes
raw_data_9 = fits.open('raw data/20081222-194830-195730')
raw_data_9minute = Table(raw_data_9[1].data)
#raw data in 10 minutes
raw_data_10 = fits.open('raw data/20081222-194800-195800')
raw_data_10minute = Table(raw_data_10[1].data)
#raw data in 20 minutes
raw_data_20 = fits.open('raw data/20081222-194300-200300')
raw_data_20minute = Table(raw_data_20[1].data)
#raw data in 30 minutes
raw_data_30 = fits.open('raw data/20081222-193800-200800')
raw_data_30minute = Table(raw_data_30[1].data)

# %%
print('total count of photons in 1 minute', len(raw_data_1minute))
print('total count of photons in 2 minute', len(raw_data_2minute))
print('total count of photons in 3 minute', len(raw_data_3minute))
print('total count of photons in 4 minute', len(raw_data_4minute))
print('total count of photons in 5 minute', len(raw_data_5minute))
print('total count of photons in 6 minute', len(raw_data_6minute))
print('total count of photons in 7 minute', len(raw_data_7minute))
print('total count of photons in 8 minute', len(raw_data_8minute))
print('total count of photons in 9 minute', len(raw_data_9minute))
print('total count of photons in 10 minute', len(raw_data_10minute))
print('total count of photons in 20 minute', len(raw_data_20minute))
print('total count of photons in 30 minute', len(raw_data_30minute))
# Out:
# total count of photons in 1 minute 0
# total count of photons in 2 minute 0
# total count of photons in 3 minute 0
# total count of photons in 4 minute 0
# total count of photons in 5 minute 0
# total count of photons in 6 minute 0
# total count of photons in 7 minute 0
# total count of photons in 8 minute 0
# total count of photons in 9 minute 0
# total count of photons in 10 minute 0
# total count of photons in 20 minute 0
# total count of photons in 30 minute 0

# %%
#for 1 day
raw_data
# Out:
# <Table length=223>
#   ENERGY       RA       DEC         L     ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
#  float32    float32   float32    float32  ... float32 float32 float32 float32
# ---------- --------- ---------- --------- ... ------- ------- ------- -------
#   595.2704 289.65814   18.96106 52.847733 ...     0.0     0.0     0.0     0.0
#   571.3478 290.74997  18.889206 53.268593 ...     0.0     0.0     0.0     0.0
#  869.08685 290.13693  17.504747  51.77217 ...     0.0     0.0     0.0     0.0
#  431.54187 294.07883  19.488464 55.301655 ...     0.0     0.0     0.0     0.0
#  421.76184  291.9408   18.79562 53.720627 ...     0.0     0.0     0.0     0.0
#    838.103 292.15088 15.5103035 50.929863 ...     0.0     0.0     0.0     0.0
#  132.14012 291.01202    18.6875 53.207806 ...     0.0     0.0     0.0     0.0
#  352.97598  292.9736  15.492594 51.294662 ...     0.0     0.0     0.0     0.0
#   593.6936 293.62103  15.725592 51.800022 ...     0.0     0.0     0.0     0.0
# ...

# %%
#select time in time of interest
x = np.greater_equal(raw_data['TIME'],251667481)
raw_data_ = raw_data[x]
y = np.less_equal(raw_data_['TIME'],251669281)
raw_data_new = raw_data_[y]

# %%
raw_data_new
# Out:
# <Table length=0>
#  ENERGY    RA     DEC      L       B    ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
# float32 float32 float32 float32 float32 ... float32 float32 float32 float32
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------

# %%
#20110809 data
#solar flare event
#2011-08-09
#DATE-OBS= '2011-08-09T00:00:00.0000'
#DATE-END= '2011-08-10T00:00:00.0000'
#For 1 day
Solar_20110809_data = fits.open('solar flare events/20110809_PH00.fits')
Solar_20110809_data_minute = Table(Solar_20110809_data[1].data)
#1 minute
Solar_20110809_data_1 = fits.open('solar flare events/20110809-080430-080530')
Solar_20110809_data_1minute = Table(Solar_20110809_data_1[1].data)
#2 minute
Solar_20110809_data_2 = fits.open('solar flare events/20110809-080400-080600')
Solar_20110809_data_2minute = Table(Solar_20110809_data_2[1].data)
#3 minute
Solar_20110809_data_3 = fits.open('solar flare events/20110809-080330-080630')
Solar_20110809_data_3minute = Table(Solar_20110809_data_3[1].data)
#4 minute
Solar_20110809_data_4 = fits.open('solar flare events/20110809-080300-080700')
Solar_20110809_data_4minute = Table(Solar_20110809_data_4[1].data)
#5 minute
Solar_20110809_data_5 = fits.open('solar flare events/20110809-080230-080730')
Solar_20110809_data_5minute = Table(Solar_20110809_data_5[1].data)
#6 minute
Solar_20110809_data_6 = fits.open('solar flare events/20110809-080200-080800')
Solar_20110809_data_6minute = Table(Solar_20110809_data_6[1].data)
#7 minute
Solar_20110809_data_7 = fits.open('solar flare events/20110809-080130-080830')
Solar_20110809_data_7minute = Table(Solar_20110809_data_7[1].data)
#8 minute
Solar_20110809_data_8 = fits.open('solar flare events/20110809-080100-080900')
Solar_20110809_data_8minute = Table(Solar_20110809_data_8[1].data)
#9 minute
Solar_20110809_data_9 = fits.open('solar flare events/20110809-080030-080930')
Solar_20110809_data_9minute = Table(Solar_20110809_data_9[1].data)
#10 minute
Solar_20110809_data_10 = fits.open('solar flare events/20110809-080000-081000')
Solar_20110809_data_10minute = Table(Solar_20110809_data_10[1].data)
#20 minute
Solar_20110809_data_20 = fits.open('solar flare events/20110809-075500-081500')
Solar_20110809_data_20minute = Table(Solar_20110809_data_20[1].data)
#30 minute
Solar_20110809_data_30= fits.open('solar flare events/20110809-075000-082000')
Solar_20110809_data_30minute = Table(Solar_20110809_data_30[1].data)

# %%
#check total of photon
print('total count of photons in 1 minute', len(Solar_20110809_data_1minute))
print('total count of photons in 2 minute', len(Solar_20110809_data_2minute))
print('total count of photons in 3 minute', len(Solar_20110809_data_3minute))
print('total count of photons in 4 minute', len(Solar_20110809_data_4minute))
print('total count of photons in 5 minute', len(Solar_20110809_data_5minute))
print('total count of photons in 6 minute', len(Solar_20110809_data_6minute))
print('total count of photons in 7 minute', len(Solar_20110809_data_7minute))
print('total count of photons in 8 minute', len(Solar_20110809_data_8minute))
print('total count of photons in 9 minute', len(Solar_20110809_data_9minute))
print('total count of photons in 10 minute', len(Solar_20110809_data_10minute))
print('total count of photons in 20 minute', len(Solar_20110809_data_20minute))
print('total count of photons in 30 minute', len(Solar_20110809_data_30minute))
# Out:
# total count of photons in 1 minute 0
# total count of photons in 2 minute 0
# total count of photons in 3 minute 0
# total count of photons in 4 minute 0
# total count of photons in 5 minute 0
# total count of photons in 6 minute 0
# total count of photons in 7 minute 0
# total count of photons in 8 minute 0
# total count of photons in 9 minute 0
# total count of photons in 10 minute 0
# total count of photons in 20 minute 0
# total count of photons in 30 minute 0

# %%
#For 1 days
Solar_20110809_data_minute
# Out:
# <Table length=189>
#   ENERGY      RA       DEC        L     ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
#  float32   float32   float32   float32  ... float32 float32 float32 float32
# --------- --------- --------- --------- ... ------- ------- ------- -------
# 1403.9269  291.6754 17.110369  52.11861 ...     0.0     0.0     0.0     0.0
#  836.1659 292.58893 19.938013 55.016457 ...     0.0     0.0     0.0     0.0
# 465.86255   294.226  19.52981 55.405457 ...     0.0     0.0     0.0     0.0
# 309.73416  293.4672 20.275663     55.71 ...     0.0     0.0     0.0     0.0
#  334.0301  291.3253 18.059662  52.79541 ...     0.0     0.0     0.0     0.0
# 195.32954 292.94293  18.54614 53.956863 ...     0.0     0.0     0.0     0.0
# 278.40628  292.4977 21.086027 55.983025 ...     0.0     0.0     0.0     0.0
#  196.0206 290.25296 19.908056  53.94834 ...     0.0     0.0     0.0     0.0
#   180.377 291.00424  17.07937  51.78695 ...     0.0     0.0     0.0     0.0
# ...

# %%
#select time in time of interest
x = np.greater_equal(Solar_20110809_data_minute['TIME'],334569002)
Solar_20110809_data_minute_ = Solar_20110809_data_minute[x]
y = np.less_equal(Solar_20110809_data_minute_['TIME'],334570802)
Solar_20110809_data_minute_new = Solar_20110809_data_minute_[y]

# %%
Solar_20110809_data_minute_new
# Out:
# <Table length=0>
#  ENERGY    RA     DEC      L       B    ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
# float32 float32 float32 float32 float32 ... float32 float32 float32 float32
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------

# %%
#20170906 data
#2017-09-06
#DATE-OBS= '2017-09-05T00:00:00.9999'
#DATE-END= '2017-09-07T00:00:00.9999
#For 2 days
Solar_20170906_data = fits.open('solar flare events/20170906_PH00.fits')
Solar_20170906_data_minute = Table(Solar_20170906_data[1].data)
#1 minute
Solar_20170906_data_1 = fits.open('solar flare events/20170906-120130-120230')
Solar_20170906_data_1minute = Table(Solar_20170906_data_1[1].data)
#2 minute
Solar_20170906_data_2 = fits.open('solar flare events/20170906-120100-120300')
Solar_20170906_data_2minute = Table(Solar_20170906_data_2[1].data)
#3 minute
Solar_20170906_data_3 = fits.open('solar flare events/20170906-120030-120330')
Solar_20170906_data_3minute = Table(Solar_20170906_data_3[1].data)
#4 minute
Solar_20170906_data_4 = fits.open('solar flare events/20170906-120000-124000')
Solar_20170906_data_4minute = Table(Solar_20170906_data_4[1].data)
#5 minute
Solar_20170906_data_5 = fits.open('solar flare events/20170906-115930-120430')
Solar_20170906_data_5minute = Table(Solar_20170906_data_5[1].data)
#6 minute
Solar_20170906_data_6 = fits.open('solar flare events/20170906-115900-120500')
Solar_20170906_data_6minute = Table(Solar_20170906_data_6[1].data)
#7 minute
Solar_20170906_data_7 = fits.open('solar flare events/20170906-115830-120530')
Solar_20170906_data_7minute = Table(Solar_20170906_data_7[1].data)
#8 minute
Solar_20170906_data_8 = fits.open('solar flare events/20170906-115800-120600')
Solar_20170906_data_8minute = Table(Solar_20170906_data_8[1].data)
#9 minute
Solar_20170906_data_9 = fits.open('solar flare events/20170906-115730-120630')
Solar_20170906_data_9minute = Table(Solar_20170906_data_9[1].data)
#10 minute
Solar_20170906_data_10 = fits.open('solar flare events/20170906-115700-120700')
Solar_20170906_data_10minute = Table(Solar_20170906_data_10[1].data)
#20 minute
Solar_20170906_data_20 = fits.open('solar flare events/20170906-115200-121200')
Solar_20170906_data_20minute = Table(Solar_20170906_data_20[1].data)
#30 minute
Solar_20170906_data_30 = fits.open('solar flare events/20170906-114700-121700')
Solar_20170906_data_30minute = Table(Solar_20170906_data_30[1].data)

# %%
#check total of photon
print('total count of photons in 1 minute', len(Solar_20170906_data_1minute))
print('total count of photons in 2 minute', len(Solar_20170906_data_2minute))
print('total count of photons in 3 minute', len(Solar_20170906_data_3minute))
print('total count of photons in 4 minute', len(Solar_20170906_data_4minute))
print('total count of photons in 5 minute', len(Solar_20170906_data_5minute))
print('total count of photons in 6 minute', len(Solar_20170906_data_6minute))
print('total count of photons in 7 minute', len(Solar_20170906_data_7minute))
print('total count of photons in 8 minute', len(Solar_20170906_data_8minute))
print('total count of photons in 9 minute', len(Solar_20170906_data_9minute))
print('total count of photons in 10 minute', len(Solar_20170906_data_10minute))
print('total count of photons in 20 minute', len(Solar_20170906_data_20minute))
print('total count of photons in 30 minute', len(Solar_20170906_data_30minute))
# Out:
# total count of photons in 1 minute 0
# total count of photons in 2 minute 0
# total count of photons in 3 minute 0
# total count of photons in 4 minute 0
# total count of photons in 5 minute 0
# total count of photons in 6 minute 0
# total count of photons in 7 minute 0
# total count of photons in 8 minute 0
# total count of photons in 9 minute 0
# total count of photons in 10 minute 0
# total count of photons in 20 minute 0
# total count of photons in 30 minute 0

# %%
#For 2 days
Solar_20170906_data_minute
# Out:
# <Table length=338>
#   ENERGY       RA       DEC        L     ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
#  float32    float32   float32   float32  ... float32 float32 float32 float32
# ---------- --------- --------- --------- ... ------- ------- ------- -------
#   887.6871 291.97144 16.187471  51.44198 ...     0.0     0.0     0.0     0.0
#  1583.0259  291.1042 16.023323 50.901505 ...     0.0     0.0     0.0     0.0
#  322.20837  294.0381 20.364445  56.04734 ...     0.0     0.0     0.0     0.0
#   229.3832  290.8905 16.518166 51.240463 ...     0.0     0.0     0.0     0.0
# 117.531525  292.4015  15.91838 51.403236 ...     0.0     0.0     0.0     0.0
#  210.36766  292.8489 19.652504  54.88322 ...     0.0     0.0     0.0     0.0
#   592.2557 290.28928 20.232605  54.25101 ...     0.0     0.0     0.0     0.0
#   286.7183 294.01392 19.011131 54.854515 ...     0.0     0.0     0.0     0.0
#  1134.4221  293.5146 15.684623 51.714066 ...     0.0     0.0     0.0     0.0
# ...

# %%
#select time in time of interest
x = np.greater_equal(Solar_20170906_data_minute['TIME'],526391225)
Solar_20170906_data_minute_ = Solar_20170906_data_minute[x]
y = np.less_equal(Solar_20170906_data_minute_['TIME'],526393025)
Solar_20170906_data_minute_new = Solar_20170906_data_minute_[y]

# %%
Solar_20170906_data_minute_new
# Out:
# <Table length=0>
#  ENERGY    RA     DEC      L       B    ... DIFRSP1 DIFRSP2 DIFRSP3 DIFRSP4
# float32 float32 float32 float32 float32 ... float32 float32 float32 float32
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------
