# %% [markdown]
# # Likelihood Analysis of the Crab with fermipy

# %% [markdown]
# Instructions on installing fermipy and the Fermi ScienceTools : [fermipy Installation Instructions](http://fermipy.readthedocs.org/en/latest/install.html).
#
# Documentation for fermipy : [fermipy](http://fermipy.readthedocs.org)
#
# Credit : notebook adapted from [Likelihood Analysis of a bright point source with fermipy](https://nbviewer.org/github/me-manu/fermipy-extra/blob/master/notebooks/pg1553.ipynb)

# %% [markdown]
# ## Get the Data

# %% [markdown]
# The data were extracted from the [LAT data server](http://fermi.gsfc.nasa.gov/cgi-bin/ssc/LAT/LATDataQuery.cgi) with the following selections :

# %% [markdown]
# ### Make a file list
#
# First you need to make a file containing the list of all your input event files.

# %% [markdown]
# Read one file as a table

# %% [markdown]
# ## Make a config file
#
#
# Make a config file named 'config.yaml' ([yaml](http://yaml.org) format). For more details on the config file see [config.html](http://fermipy.readthedocs.org/en/latest/config.html).

# %%
cat config_0.1GeV/config_J1932_15_bin_6
# Out:
# data:
#   evfile : data_0.1GeV/photon_files.txt # list of photon files
#   scfile : data_0.1GeV/L2206060606222DE20A3589_SC00.fits # spacecraft file
#
# binning:
#   roiwidth   : 15.0
#   binsz      : 0.06
#   binsperdec : 6
#
# selection :
#   emin : 100 # minimum energy
#   emax : 1000000 # maximum energy
#   zmax    : 90 # zenith angle cut
#   evclass : 128 # event class : simple point source analysis for pass 8
#   evtype  : 3 # event type (front 1 + back events 2 = 3)
#   tmin : 239557417  # starting time
#   tmax : 673405656  # ending time
#   filter : DATA_QUAL>0 && LAT_CONFIG==1 # Recommendation for Galactic Point Source Analysis
#   ra : 292.747
#   dec : 18.944
#
# gtlike:
#   edisp : -2 # Enable energy dispersion
#   irfs : 'P8R3_SOURCE_V3'
#   edisp_disable : ['isodiff'] # Never enable energy dispersion for the isodiff or galdiff models
#
# model:
#   src_roiwidth : 25.0 # Includes sources outside of the ROI
#   galdiff  : 'gll_iem_v07.fits' # The most recent and up to date model of the galactic diffuse emission
#   isodiff  : 'iso_P8R3_SOURCE_V3_v1.txt' # The most recent and up to date model for the isotropic diffuse emission, and for our event class
#   catalogs : ['4FGL'] # The 4FGL catalogue, 8 year Fermi-LAT point source catalogue.

# %% [markdown]
# ## Start the analysis
#
# Next, you create an analysis script and run the setup steps (which include running the selections and generating exposure maps for example). This will take some time to run.
#
# Fermipy will load the point source model, create an xml file for you which contains the models for all your sources in the region of interest (ROI).  All of this is configurable from python or from the config file.

# %% [markdown]
# ### Load up some useful modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from astropy.table import Table
from astropy.io import fits
from astropy.wcs import WCS

# %% [markdown]
# Let's ignore some deprecation warnings

# %%
import warnings
from matplotlib import MatplotlibDeprecationWarning
warnings.filterwarnings("ignore", category=MatplotlibDeprecationWarning)

# %% [markdown]
# ### Import the GTAnalysis module from fermipy
#
# You start by importing the module and then creating an instance of the analysis object from our config file.  When instantiating the analysis object we can override any options defined in the configuration file by passing keyword arguments to the object constructor.
# The verbosity parameter is set to 3 (INFO) which supresses DEBUG output.

# %%
from fermipy.gtanalysis import GTAnalysis
gta = GTAnalysis('config_0.1GeV/config_J1932_15_bin_6',logging={'verbosity': 3},fileio={'outdir': 'J1932+1916_0.1GeV_15_bin6'})
matplotlib.interactive(True)
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]
# 2022-06-10 11:00:03 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version v1.0.1
# ScienceTools version 2.0.8

# %% [markdown]
# ### The setup routine
#
# This gets everything ready for the likelihood analysis.  Note that fermipy will skip generating any files that already exist in the working directory.

# %%
gta.setup()
# Out:
# 2022-06-10 11:00:04 INFO    GTAnalysis.setup(): Running setup.
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis.setup(): Running setup for component 00
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/fermipy/irfs.py:51: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   log_ratio = np.log(x[xs1] / x[xs0])
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/fermipy/irfs.py:52: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return 0.5 * (y[ys0] * x[xs0] + y[ys1] * x[xs1]) * log_ratio
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis.setup(): Finished setup for component 00
# 2022-06-10 11:00:04 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 00.
# Drm_Cache::update Measured counts < 0 4FGL J1842.1+2737 23 -1.18245e-15 7.31909e-16
# 0.239203 0.456312 0.6406 0.649341 0.501611 0.326119 0.167895 0.0684979 0.0260394 0.0078816 0.0019261 0.000515416 0.000135349 3.22454e-05 6.72369e-06 1.18531e-06 1.61899e-07 1.63127e-08 1.28396e-09 7.82217e-11 4.50208e-12 2.30038e-13 1.18336e-14 7.31909e-16
# 2022-06-10 11:00:21 INFO    GTAnalysis.setup(): Initializing source properties
# 2022-06-10 11:00:27 INFO    GTAnalysis.setup(): Finished setup.

# %%
h = fits.open('J1932+1916_15_bin_3/ccube_00.fits')
filtered = fits.open('J1932+1916_15_bin_3/ft1_00.fits')
t_filtered = Table(filtered[1].data)
catalog = fits.open('gll_psc_v22.fit')

# %% [markdown]
# Let's have a look at the components of the model :

# %%
 gta.print_model()
# Out:
# 2022-06-10 11:00:29 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916      0.449   2.791  3.99e-05   3.72       nan     30071.8
# 4FGL J1929.8+1832      0.482   1.614  1.03e-05   2.42       nan      8548.1
# 4FGL J1934.3+1859      0.794   2.658  1.32e-05   4.26       nan     12505.2
# 4FGL J1928.4+1801c     1.104   0.954  1.01e-05   2.46       nan      8660.5
# J1932+1916_15_bin_3/bexpmap_00.fits
# J1932+1916_15_bin_3/bexpmap_roi_00.fits
# J1932+1916_15_bin_3/ccube_00.fits
# J1932+1916_15_bin_3/ccube.fits
# J1932+1916_15_bin_3/ft1_00.fits
# J1932+1916_15_bin_3/ltcube_00.fits
# J1932+1916_15_bin_3/mcube_Pulsar_J1932_00.fits
# J1932+1916_15_bin_3/mcube_Pulsar_J1932.fits
# J1932+1916_15_bin_3/mcube_Reference_00.fits
# J1932+1916_15_bin_3/mcube_Reference.fits
# J1932+1916_15_bin_3/Pulsar_J1932.fits
# J1932+1916_15_bin_3/Reference.fits
# J1932+1916_15_bin_3/Reference_pointsource_powerlaw_2.00_residmap.fits
# J1932+1916_15_bin_3/srcmap_00.fits

# %% [markdown]
# Here is a brief explanation of the contents of each file and its role in the analysis:
#
# * **ft1_00.fits**: Event list.  This is generated by running gtselect and gtmktime on our input file list.
# * **bexpmap_00.fits**: All-sky binned exposure map.  This map is interpolated to create an exposure model when generating the srcmap file.
# * **bexpmap_roi_00.fits**: Binned exposure map for the ROI.  This file is only provided for visualization purposes in order to have an exposure map with the same binning as the data and model maps.
# * **ccube_00.fits**: Counts cube for the ROI.
# * **ltcube_00.fits**: Livetime cube.  This contains a map of the livetime for this observation over the whole sky as a function of incidence angle.
# * **srcmap_00.fits**: Source map cube.  This file contains maps for each of the components in the ROI after convolution with exposure and the PSF.  Note that energy dispersion is applied at run-time.
#
# Note that all of the files have a numerical suffix '00'.  This is the analysis component index.  In a multi-component analysis there would be instances of all of the above files for each analysis component.  The files with no component index are co-added maps that are provided for visualization purposes.
#
# To see example of one of these files we can open and plot the counts cube file.  This is a 3D cube that contains the distribution of events as a function of energy and two spatial coordinates.  In the example below we sum over the energy dimension of the cube to make a 2-D sky image.

# %%
#h = fits.open('J1928+178_15_bin3/ccube_00.fits')
h.info()

wcs = WCS(h[0].header).dropaxis(-1)  # load the coordinate system, drop the energy axis

counts = h[0].data

plt.subplot(projection=wcs)
im = plt.imshow(np.sum(counts,axis=0),vmax= 20,interpolation='nearest',origin='lower', cmap='plasma')

plt.grid()
plt.gca().tick_params(direction='out')
plt.gca().set_xlabel("R.A. (deg)")
plt.gca().set_ylabel("Dec. (deg)")
plt.colorbar(im, label="counts")
plt.show()
#plt.savefig("Crab_5_bin_6/ccube_00.png")
# Out:
# Filename: J1932+1916_15_bin_3/ccube_00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     138   (750, 750, 9)   int32
#   1  EBOUNDS       1 BinTableHDU     43   9R x 3C   [I, 1E, 1E]
#   2  GTI           1 BinTableHDU     50   76600R x 2C   [D, D]

# %%
#filtered = fits.open('J1928+178_15_bin3/ft1_00.fits')
#t_filtered = Table(filtered[1].data)

# %%
x=t_filtered['RA']
y=t_filtered['DEC']
z=t_filtered['ENERGY']

# %%
print('x_min',np.min(x))
print('x_max',np.max(x))
# Out:
# x_min 280.9983
# x_max 304.49734

# %%
bin = 300
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(304.47318, 281.0085)
#ax.set_ylim(0.3-1.5, 0.3+1.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Count maps of 13 years of Fermi LAT data',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Count maps of 13 years of Fermi LAT data')

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

ax.set_xlabel("RA (deg)",fontsize=40)
ax.set_ylabel("DEC (deg)",fontsize=40)
ax.set_xlim(292.747+7.5, 292.747-7.5)
ax.set_ylim(18.944-7.5, 18.944+7.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Filtered data (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Filtered data (J1928+178)')

# %%
#catalog = fits.open('gll_psc_v22.fit')
c = Table(catalog[1].data)

# %%
catalog = fits.open("gll_psc_v22.fit")
t = Table(catalog[1].data)
new_glon = np.logical_and(t['RAJ2000'] >=292.747-2.5, t['RAJ2000']<=292.747+2.5)
new_tg = t[new_glon]
new_glat = np.logical_and(new_tg['DEJ2000'] >= 18.944-2.5, new_tg['DEJ2000'] <=18.944+2.5)
sources = new_tg[new_glat]

# %%
 gta.print_model()
# Out:
# 2022-06-10 11:00:31 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916      0.449   2.791  3.99e-05   3.72       nan     30071.8
# 4FGL J1929.8+1832      0.482   1.614  1.03e-05   2.42       nan      8548.1
-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  2.998e-13 +/-        nan
# b'Index'       :     -2.527 +/-        nan
# b'Scale'       :       1595 +/-        nan

# %%
print(gta.roi['4FGL J1925.1+1707'])
# Out:
# Name           : 4FGL J1925.1+1707
# Associations   : ['4FGL J1925.1+1707', 'MG2 J192501+1727']
# RA/DEC         :    291.289/    17.122
# GLON/GLAT      :     51.954/     0.548
# TS             : nan
# Npred          : 7504.01
# Flux           :  2.85e-08 +/-      nan
# EnergyFlux     : 8.785e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :    5.1e-14 +/-        nan
# b'Index'       :      -2.47 +/-        nan
# b'Scale'       :       3843 +/-        nan

# %%
print(gta.roi['4FGL J1925.2+1729'])
# Out:
# Name           : 4FGL J1925.2+1729
# Associations   : ['4FGL J1925.2+1729', 'PSR J1925+1720', '3EG J1928+1733']
# RA/DEC         :    291.322/    17.485
# GLON/GLAT      :     52.287/     0.692
# TS             : nan
# Npred          : 3730.88
# Flux           : 9.227e-09 +/-      nan
# EnergyFlux     : 6.321e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.976e-11 +/-        nan
# b'Index1'      :   -0.08822 +/-        nan
# b'Scale'       :       1981 +/-        nan
# b'Expfactor'   :    0.02449 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1928.4+1801c'])
# Out:
# Name           : 4FGL J1928.4+1801c
# Associations   : ['4FGL J1928.4+1801c', 'MG2 J192830+1759', '3EG J1928+1733']
# RA/DEC         :    292.112/    18.019
# GLON/GLAT      :     53.115/     0.285
# TS             : nan
# Npred          : 8660.53
# Flux           : 3.235e-08 +/-      nan
# EnergyFlux     : 1.011e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  9.542e-14 +/-        nan
# b'Index'       :      -2.46 +/-        nan
# b'Scale'       :       3175 +/-        nan

# %%
print(gta.roi['4FGL J1929.0+1729'])
# Out:
# Name           : 4FGL J1929.0+1729
# Associations   : ['4FGL J1929.0+1729', '3EG J1928+1733']
# RA/DEC         :    292.256/    17.490
# GLON/GLAT      :     52.717/    -0.088
# TS             : nan
# Npred          : 10051.32
# Flux           : 2.829e-08 +/-      nan
# EnergyFlux     : 1.425e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  1.526e-12 +/-        nan
# b'alpha'       :      2.644 +/-        nan
# b'beta'        :     0.3992 +/-        nan
# b'Eb'          :       1634 +/-        nan

# %%
print(gta.roi['4FGL J1929.8+1832'])
# Out:
# Name           : 4FGL J1929.8+1832
# Associations   : ['4FGL J1929.8+1832', '1RXS J193012.1+183201']
# RA/DEC         :    292.454/    18.550
# GLON/GLAT      :     53.737/     0.254
# TS             : nan
# Npred          : 8548.06
# Flux           : 3.131e-08 +/-      nan
# EnergyFlux     : 1.034e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  1.614e-13 +/-        nan
# b'Index'       :     -2.421 +/-        nan
# b'Scale'       :       2635 +/-        nan

# %%
print(gta.roi['4FGL J1931.1+1656'])
# Out:
# Name           : 4FGL J1931.1+1656
# Associations   : ['4FGL J1931.1+1656']
# RA/DEC         :    292.785/    16.944
# GLON/GLAT      :     52.480/    -0.794
# TS             : nan
# Npred          : 12572.36
# Flux           : 3.736e-08 +/-      nan
# EnergyFlux     :  1.69e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :   2.82e-12 +/-        nan
# b'alpha'       :      2.532 +/-        nan
# b'beta'        :     0.3525 +/-        nan
# b'Eb'          :       1324 +/-        nan

# %%
print(gta.roi['4FGL J1932.3+1916'])
# Out:
# Name           : 4FGL J1932.3+1916
# Associations   : ['4FGL J1932.3+1916', 'PSR J1932+1916']
# RA/DEC         :    293.076/    19.268
# GLON/GLAT      :     54.650/     0.084
# TS             : nan
# Npred          : 30071.84
# Flux           :  9.12e-08 +/-      nan
# EnergyFlux     : 3.992e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.791e-11 +/-        nan
# b'Index1'      :     -1.252 +/-        nan
# b'Scale'       :       1538 +/-        nan
# b'Expfactor'   :    0.01314 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1934.3+1859'])
# Out:
# Name           : 4FGL J1934.3+1859
# Associations   : ['4FGL J1934.3+1859', 'SNR G054.4-00.3']
# RA/DEC         :    293.585/    18.998
# GLON/GLAT      :     54.646/    -0.468
# TS             : nan
# Npred          : 12505.20
# Flux           : 3.996e-08 +/-      nan
# EnergyFlux     : 1.321e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  2.658e-12 +/-        nan
# b'alpha'       :      3.137 +/-        nan
# b'beta'        :     0.5334 +/-        nan
# b'Eb'          :       1105 +/-        nan

# %%
print(gta.roi['4FGL J1935.2+2029'])
# Out:
# Name           : 4FGL J1935.2+2029
# Associations   : ['4FGL J1935.2+2029', 'PSR J1935+2025']
# RA/DEC         :    293.818/    20.491
# GLON/GLAT      :     56.057/     0.065
# TS             : nan
# Npred          : 22687.59
# Flux           : 8.072e-08 +/-      nan
# EnergyFlux     : 2.335e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  1.062e-11 +/-        nan
# b'Index1'      :     -1.903 +/-        nan
# b'Scale'       :       1190 +/-        nan
# b'Expfactor'   :    0.01018 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1936.6+1921'])
# Out:
# Name           : 4FGL J1936.6+1921
# Associations   : ['4FGL J1936.6+1921']
# RA/DEC         :    294.163/    19.354
# GLON/GLAT      :     55.222/    -0.772
# TS             : nan
# Npred          : 975.95
# Flux           : 1.956e-09 +/-      nan
# EnergyFlux     : 2.482e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  3.245e-13 +/-        nan
# b'alpha'       :      2.041 +/-        nan
# b'beta'        :     0.6762 +/-        nan
# b'Eb'          :       1884 +/-        nan

# %%
plt.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'black' , s=200 , facecolor='none')
for i, txt in enumerate(sources['Source_Name']):           
    plt.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]),fontsize=10,color='black')
#plt.ylim(22.0145-2.5,22.0145+2.5)
#plt.xlim(83.633-2.5,83.633+2.5)
plt.show()

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))
count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=200,  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])

for i, txt in enumerate(sources['Source_Name']):           
    ax.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]+0.2),fontsize=15,color='white')
ax.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'white' , s=400 , facecolor='none')
ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(292.747+7.5, 292.747-7.5)
ax.set_ylim(18.944-7.5, 18.944+7.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 
ax.set_title('Filtered data map (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Filtered data map (J1928+178)')

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))
count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=200,  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])

for i, txt in enumerate(sources['Source_Name']):           
    ax.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]+0.1),fontsize=30,color='white')
ax.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'white' , s=400 , facecolor='none')
ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(292.747+2.5, 292.747-2.5)
ax.set_ylim(18.944-2.5, 18.944+2.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 
ax.set_title('Zoom in filtered data map (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Zoom in filtered data map (J1928+178)')

# %% [markdown]
# Next, we look at the sky map of the exposure

# %% [markdown]
# ... and the energy dependence of the exposure for the central pixel

# %% [markdown]
# We can now inspect the state of the ROI before the fit

# %%
gta.print_roi()
# Out:
# 2022-06-10 11:00:33 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449       nan     30071.8
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482       nan      8548.1
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794       nan     12505.2
# 4FGL J1928.4+1801c  PointSource    PowerLaw          1.104       nan      8660.5
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399       nan       975.9
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527       nan     10051.3
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846       nan     22687.6
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991       nan      3730.9
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000       nan     12572.4
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289       nan      7504.0
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386       nan      5695.6
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977       nan     12396.8
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097       nan     12291.3
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314       nan      7417.9
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343       nan     10057.8
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431       nan      1203.9
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820       nan      8449.6
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855       nan       163.4
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094       nan      1051.3
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535       nan      7650.7
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760       nan      1738.1
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882       nan     15831.3
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143       nan     96390.1
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274       nan      3816.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364       nan     15449.3
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366       nan      1907.9
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591       nan      1114.1
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675       nan       882.4
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909       nan      2002.4
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260       nan       427.3
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347       nan     14591.0
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603       nan      5365.3
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663       nan      2694.1
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869       nan      1558.8
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979       nan      5141.4
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023       nan      4722.3
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137       nan      7637.5
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154       nan      3890.0
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359       nan      6089.7
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589       nan      1396.9
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649       nan      4074.9
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698       nan       834.0
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949       nan      2651.2
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011       nan       993.6
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061       nan      8468.9
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069       nan      1339.5
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272       nan      1733.3
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283       nan      1198.7
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381       nan       990.2
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489       nan      1747.2
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567       nan      3690.5
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716       nan      1040.1
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738       nan      3807.0
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769       nan      2793.3
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809       nan      2439.0
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856       nan      1351.3
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075       nan       832.0
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298       nan       126.9
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313       nan       276.7
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418       nan       240.7
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574       nan       852.8
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590       nan       176.6
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606       nan       873.4
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748       nan       759.8
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870       nan       979.3
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961       nan       568.2
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012       nan       199.5
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014       nan      1113.7
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189       nan       580.2
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599       nan       190.9
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735       nan       386.8
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808       nan       175.0
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818       nan       154.5
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971       nan      3570.8
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002       nan        49.3
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033       nan      3044.7
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077       nan      1200.7
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093       nan      1062.4
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279       nan       251.3
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518       nan        71.7
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536       nan       132.9
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561       nan        52.2
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582       nan        39.0
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686       nan      2391.5
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006       nan        20.6
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020       nan       642.5
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328       nan       212.0
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504       nan        75.4
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975       nan       145.5
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994       nan       806.7
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098       nan       508.1
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538       nan        76.7
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800       nan       185.6
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876       nan        86.6
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945       nan       285.4
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006       nan        85.1
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166       nan         3.0
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456       nan        82.7
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488       nan        46.5
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590       nan        99.2
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904       nan        93.3
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071       nan        65.2
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228       nan         6.3
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809       nan         9.8
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109       nan         8.7
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146       nan        16.9
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337       nan         7.6
# isodiff             ConstantValue  FileFunction      -----       nan    204406.2
# galdiff             MapCubeFunctio PowerLaw          -----       nan   4524813.7

# %% [markdown]
# Additional details about an individual source can be retrieved by printing the corresponding source object

# %% [markdown]
# ## Do the likelihood fitting
#
# Now that all of the ancillary files have been generated, we can move on to the actual fitting.  The first thing you should do is free some of the sources since all of the sources are initially fixed.  We'll just free those sources in the center region.

# %%
gta.print_params()
# Out:
# 2022-06-10 11:00:34 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------

# %%
gta.delete_source('4FGL J1928.4+1801c')
gta.add_source('3HWC J1928+178PSR',{ 'glon' : 52.93, 'glat' : 0.2,
                            'SpectrumType' : 'PLSuperExpCutoff', 'Index1':1.55,
                            'Index2' : 1.0,'Scale' : 1000,'Prefactor':1e-9,'Cutoff' : 1.93e+03 ,'SpatialModel' : 'PointSource' })
gta.add_source('3HWC J1928+178i',{ 'glon' : 52.93, 'glat' : 0.2,
                'SpectrumType' : 'LogParabola', 'alpha' : 1.5,
                'beta' : 0.1, 'norm' : 0.466e-12,'Eb' : 1e+04,
                'SpatialModel': 'RadialGaussian', 'SpatialWidth': 1 })
gta.add_source('3HWC J1928+178s',{ 'glon' : 52.93, 'glat' : 0.2,
                'SpectrumType' : 'PowerLaw', 'Index' : 1.5,
                'Scale' : 1000, 'Prefactor' : 1.0e-11,
                'SpatialModel': 'RadialGaussian', 'SpatialWidth': 1 })

gta.free_sources(free=False) # make sure everything is fixed first
gta.optimize()
# Out:
# 2022-06-10 11:00:34 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1928.4+1801c
# 2022-06-10 11:00:34 INFO    GTAnalysis.add_source(): Adding source 3HWC J1928+178PSR
# 2022-06-10 11:00:39 INFO    GTAnalysis.add_source(): Adding source 3HWC J1928+178i
# 2022-06-10 11:01:04 INFO    GTAnalysis.add_source(): Adding source 3HWC J1928+178s
# 2022-06-10 11:01:28 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178PSR     : ['Prefactor']
# 2022-06-10 11:01:28 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178i       : ['norm']
# 2022-06-10 11:01:28 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178s       : ['Prefactor']
# 2022-06-10 11:01:29 INFO    GTAnalysis.optimize(): Starting
# Joint fit  ['galdiff', '3HWC J1928+178PSR', 'isodiff', '4FGL J1923.2+1408e', '4FGL J1932.3+1916']
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/scipy/interpolate/fitpack2.py:279: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# Fitting shape galdiff TS: 2008194.921
# Fitting shape 4FGL J1923.2+1408e TS:  30653.411
# Fitting shape isodiff TS:   5998.761
# Fitting shape 4FGL J1932.3+1916 TS:   2934.586
# Fitting shape 4FGL J1931.1+1656 TS:   1504.080
# Fitting shape 4FGL J1959.5+2048 TS:   1125.363
# Fitting shape 4FGL J1919.4+1313 TS:   1022.273
# Fitting shape 4FGL J1922.7+1428 TS:    986.691
# Fitting shape 4FGL J1915.3+1149 TS:    969.420
# Fitting shape 4FGL J1929.0+1729 TS:    878.172
# Fitting shape 4FGL J1934.3+1859 TS:    804.977
# Fitting shape 4FGL J1920.9+1408 TS:    764.289
# Fitting shape 4FGL J1935.2+2029 TS:    582.669
# Fitting shape 4FGL J1925.4+1616 TS:    562.290
# Fitting shape 4FGL J1912.5+1320 TS:    522.869
# Fitting shape 4FGL J1926.4+1602 TS:    460.601
# Fitting shape 4FGL J1955.2+1358 TS:    287.509
# Fitting shape 4FGL J1918.1+1215 TS:    266.048
# Fitting shape 4FGL J1949.0+1314 TS:    262.450
# Fitting shape 4FGL J1944.0+2117 TS:    252.566
# Fitting shape 4FGL J1925.7+1227 TS:    230.747
# Fitting shape 4FGL J1925.2+1729 TS:    226.441
# Fitting shape 4FGL J1925.3+1522 TS:    216.786
# Fitting shape 4FGL J1939.6+2135 TS:    215.180
# Fitting shape 4FGL J1950.8+1211 TS:    199.095
# Fitting shape 4FGL J1908.9+2103 TS:    145.675
# Fitting shape 4FGL J1912.0+1612 TS:    127.668
# Fitting shape 4FGL J1922.2+2314 TS:    123.491
# Fitting shape 4FGL J1958.1+2438 TS:    122.668
# Fitting shape 4FGL J1929.8+1832 TS:    115.508
# Fitting shape 4FGL J1916.3+1108 TS:    111.961
# Fitting shape 4FGL J1906.1+1651 TS:    111.280
# Fitting shape 4FGL J1919.1+2354 TS:    101.301
# Fitting shape 4FGL J1951.0+2523 TS:     99.535
# Fitting shape 4FGL J1921.1+1930 TS:     95.278
# Fitting shape 4FGL J1859.0+2329 TS:     89.543
# Fitting shape 4FGL J1911.0+0905 TS:     83.667
# Fitting shape 4FGL J1925.1+1707 TS:     80.586
# Fitting shape 4FGL J1951.6+2621 TS:     77.456
# Fitting shape 4FGL J1942.7+1033 TS:     72.794
# Fitting shape 4FGL J1957.6+1230 TS:     72.229
# Fitting shape 4FGL J1924.3+1601 TS:     67.622
# Fitting shape 4FGL J1954.5+2420 TS:     67.046
# Fitting shape 4FGL J1948.3+1207 TS:     65.505
# Fitting shape 4FGL J1922.4+1453 TS:     59.582
# Fitting shape 4FGL J1946.1+2436 TS:     56.212
# Fitting shape 4FGL J1953.6+1846 TS:     55.662
# Fitting shape 4FGL J1912.7+0957 TS:     52.663
# Fitting shape 3HWC J1928+178i TS:     41.218
# Fitting shape 4FGL J1936.6+1921 TS:     39.992
# Fitting shape 4FGL J1859.8+1545 TS:     38.368
# Fitting shape 4FGL J1949.4+1247 TS:     28.900
# Fitting shape 4FGL J1932.2+2221 TS:     26.097
# 2022-06-10 11:10:13 INFO    GTAnalysis.optimize(): Finished
# 2022-06-10 11:10:13 INFO    GTAnalysis.optimize(): LogLike: 7186739.345134 Delta-LogLike: 585158.566237
# 2022-06-10 11:10:13 INFO    GTAnalysis.optimize(): Execution time: 524.54 s
# {'loglike0': 6601580.778896398,
#  'loglike1': 7186739.345133718,
#  'dloglike': 585158.5662373202,
#  'config': {'npred_threshold': 1.0,
#   'npred_frac': 0.95,
#   'shape_ts_threshold': 25.0,
#   'max_free_sources': 5,
#   'skip': [],
#   'optimizer': {'optimizer': 'MINUIT',
#    'tol': 0.001,
#    'max_iter': 100,
#    'init_lambda': 0.0001,
#    'retries': 3,
#    'min_fit_quality': 2,
#    'verbosity': 0}}}

# %%
print(gta.roi['3HWC J1928+178PSR'])
# Out:
# Name           : 3HWC J1928+178PSR
# Associations   : ['3HWC J1928+178PSR']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.76
# Npred          : 14.31
# Flux           : 4.365e-11 +/- 3.25e-14
# EnergyFlux     :  1.87e-08 +/- 1.39e-11
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff
# Spectral Parameters
# b'Prefactor'   :      1e-14 +/-  7.447e-18
# b'Index1'      :      -1.55 +/-        nan
# b'Scale'       :       1000 +/-        nan
# b'Cutoff'      :       1930 +/-        nan
# b'Index2'      :          1 +/-        nan

# %%
print(gta.roi['3HWC J1928+178i'])
# Out:
# Name           : 3HWC J1928+178i
# Associations   : ['3HWC J1928+178i']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 88.49
# Npred          : 6149.29
# Flux           : 1.539e-08 +/- 9.07e-10
# EnergyFlux     : 1.567e-05 +/- 2.25e-06
# SpatialModel   : RadialGaussian
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :   2.71e-14 +/-  5.669e-15
# b'alpha'       :      2.566 +/-    0.04935
# b'beta'        :        0.2 +/-  3.909e-06
# b'Eb'          :      1e+04 +/-        nan

# %%
print(gta.roi['3HWC J1928+178s'])
# Out:
# Name           : 3HWC J1928+178s
# Associations   : ['3HWC J1928+178s']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.06
# Npred          : 0.25
# Flux           : 6.262e-13 +/- 2.55e-17
# EnergyFlux     : 6.262e-09 +/- 2.55e-13
# SpatialModel   : RadialGaussian
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :      1e-16 +/-  4.074e-21
# b'Index'       :       -1.5 +/-        nan
# b'Scale'       :       1000 +/-        nan

# %%
# Free Normalization of all Sources within 3 deg of ROI center
gta.free_sources(distance=3.0,pars='norm')
gta.free_sources(minmax_ts=[100,None],pars='norm')
# Free normalizations of isotropic and galactic diffuse components
gta.free_source('galdiff',pars='norm')
gta.free_source('isodiff')
# Out:
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1932.3+1916     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1929.8+1832     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1934.3+1859     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 3HWC J1928+178PSR     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 3HWC J1928+178i       : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 3HWC J1928+178s       : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1936.6+1921     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1929.0+1729     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1935.2+2029     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.2+1729     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1931.1+1656     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.1+1707     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1921.1+1930     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.4+1616     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1926.4+1602     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1939.6+2135     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.3+1522     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1944.0+2117     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.4+1453     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.2+2314     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.7+1428     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1923.2+1408e    : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.0+1612     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1920.9+1408     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1908.9+2103     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1919.1+2354     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.1+1651     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1919.4+1313     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.7+1227     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1959.5+2048     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.5+1320     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1949.0+1314     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1918.1+1215     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1955.2+1358     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1951.0+2523     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1915.3+1149     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1950.8+1211     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1958.1+2438     : ['Prefactor']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1916.3+1108     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1951.6+2621     : ['norm']
# 2022-06-10 11:13:56 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.0+0905     : ['norm']

# %%
print(gta.roi['3HWC J1928+178PSR'])
# Out:
# Name           : 3HWC J1928+178PSR
# Associations   : ['3HWC J1928+178PSR']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.76
# Npred          : 14.31
# Flux           : 4.365e-11 +/- 3.25e-14
# EnergyFlux     :  1.87e-08 +/- 1.39e-11
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff
# Spectral Parameters
# b'Prefactor'   :      1e-14 +/-  7.447e-18
# b'Index1'      :      -1.55 +/-        nan
# b'Scale'       :       1000 +/-        nan
# b'Cutoff'      :       1930 +/-        nan
# b'Index2'      :          1 +/-        nan

# %%
print(gta.roi['3HWC J1928+178i'])
# Out:
# Name           : 3HWC J1928+178i
# Associations   : ['3HWC J1928+178i']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 88.49
# Npred          : 6149.29
# Flux           : 1.539e-08 +/- 9.07e-10
# EnergyFlux     : 1.567e-05 +/- 2.25e-06
# SpatialModel   : RadialGaussian
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :   2.71e-14 +/-  5.669e-15
# b'alpha'       :      2.566 +/-    0.04935
# b'beta'        :        0.2 +/-  3.909e-06
# b'Eb'          :      1e+04 +/-        nan

# %%
print(gta.roi['3HWC J1928+178s'])
# Out:
# Name           : 3HWC J1928+178s
# Associations   : ['3HWC J1928+178s']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.06
# Npred          : 0.25
# Flux           : 6.262e-13 +/- 2.55e-17
# EnergyFlux     : 6.262e-09 +/- 2.55e-13
# SpatialModel   : RadialGaussian
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :      1e-16 +/-  4.074e-21
# b'Index'       :       -1.5 +/-        nan
# b'Scale'       :       1000 +/-        nan

# %%
gta.free_source('3HWC J1928+178PSR')
gta.free_source('3HWC J1928+178i')
gta.free_source('3HWC J1928+178s')
ext1 = gta.extension('3HWC J1928+178i',update=True,make_plots=True)
ext2 = gta.extension('3HWC J1928+178s',update=True,make_plots=True)
# Out:
# 2022-06-10 11:21:03 INFO    GTAnalysis.extension(): Running extension fit for 3HWC J1928+178i
# 2022-06-10 11:22:26 INFO    GTAnalysis._extension(): Fitting extended-source model.
# 2022-06-10 11:23:14 INFO    GTAnalysis._extension(): Generating TS map.
# 2022-06-10 11:23:59 INFO    GTAnalysis._extension(): Testing point-source model.
# 2022-06-10 11:24:28 INFO    GTAnalysis._extension(): Best-fit extension: 0.7881 + 0.0913 - 0.0889
# 2022-06-10 11:24:28 INFO    GTAnalysis._extension(): TS_ext:        61.954
# 2022-06-10 11:24:28 INFO    GTAnalysis._extension(): Extension UL: 0.9396
# 2022-06-10 11:24:28 INFO    GTAnalysis._extension(): LogLike:  7186742.061 DeltaLogLike:       30.825
# 2022-06-10 11:24:28 INFO    GTAnalysis.extension(): Finished extension fit.
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}
# {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}
# 2022-06-10 11:24:34 WARNING GTAnalysis.extension(): Saving maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /home/user/fermi/J1928+178/J1932+1916_0.1GeV_15_bin6/3hwc_j1928+178i_ext.npy
# 2022-06-10 11:24:34 INFO    GTAnalysis.extension(): Execution time: 210.31 s
# 2022-06-10 11:24:34 INFO    GTAnalysis.extension(): Running extension fit for 3HWC J1928+178s
# {'name': '3HWC J1928+178i', 'file': None, 'config': {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}, 'width': array([0.        , 0.01      , 0.01258925, 0.01584893, 0.01995262,
([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err_hi': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err_lo': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_ul95': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ts_ext': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_dloglike': array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan]]), 'ebin_loglike': array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan]]), 'ebin_loglike_ptsrc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_loglike_ext': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ra': 292.09724537791766, 'dec': 17.815662567309136, 'glon': 52.92999999999997, 'glat': 0.20000000000006654, 'ra_err': nan, 'dec_err': nan, 'glon_err': nan, 'glat_err': nan, 'pos_offset': 0.0, 'pos_err': nan, 'pos_r68': nan, 'pos_r95': nan, 'pos_r99': nan, 'pos_err_semimajor': nan, 'pos_err_semiminor': nan, 'pos_angle': nan, 'tsmap': WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat']
# 	shape : (52, 53)
# 	ndim  : 2
# 	unit  :
# 	dtype : float64
# , 'ptsrc_tot_map': None, 'ptsrc_src_map': None, 'ptsrc_bkg_map': None, 'ext_tot_map': None, 'ext_src_map': None, 'ext_bkg_map': None, 'source_fit': {'param_names': array([b'norm', b'alpha', b'beta', b'Eb', b'', b'', b'', b'', b'', b''],
#       dtype='|S32'), 'param_values': array([2.49718588e-14, 2.52649188e+00, 1.99999924e-01, 1.00000000e+04,
#                   nan,            nan,            nan,            nan,
#                   nan,            nan]), 'param_errors': array([8.79691021e-15, 1.66803663e-01, 1.91180927e-05,            nan,
#                   nan,            nan,            nan,            nan,
#                   nan,            nan]), 'ts': 89.7150322124362, 'loglike': 7186742.157605135, 'loglike_scan': array([7186697.30008903, 7186739.44819612, 7186740.08542976,
#        7186740.63682231, 7186741.1026456 , 7186741.48316952,
#        7186741.77866215, 7186741.98938967, 7186742.11561648,
#        7186742.15760513, 7186742.13033349, 7186742.04867864,
#        7186741.91277545, 7186741.72275801, 7186741.4787597 ,
#        7186741.18091319, 7186740.82935041, 7186740.42420261,
#        7186739.96560033, 7186739.4536734 ]), 'dloglike_scan': array([-4.48575161e+01, -2.70940902e+00, -2.07217538e+00, -1.52078282e+00,
#        -1.05495954e+00, -6.74435612e-01, -3.78942987e-01, -1.68215461e-01,
#        -4.19886550e-02,  0.00000000e+00, -2.72716498e-02, -1.08926490e-01,
#        -2.44829684e-01, -4.34847124e-01, -6.78845433e-01, -9.76691949e-01,
#        -1.32825473e+00, -1.73340253e+00, -2.19200481e+00, -2.70393174e+00]), 'eflux_scan': array([0.00000000e+00, 1.03121067e-05, 1.07395171e-05, 1.11669276e-05,
#        1.15943380e-05, 1.20217484e-05, 1.24491589e-05, 1.28765693e-05,
#        1.33039797e-05, 1.37313902e-05, 1.40757696e-05, 1.44201489e-05,
#        1.47645283e-05, 1.51089077e-05, 1.54532871e-05, 1.57976665e-05,
#        1.61420458e-05, 1.64864252e-05, 1.68308046e-05, 1.71751840e-05]), 'flux_scan': array([0.00000000e+00, 9.45435346e-09, 9.84621222e-09, 1.02380710e-08,
#        1.49936784e-20, 6.74270609e-21]), 'dnde_err': array([1.68969646e-11, 1.36436007e-11, 1.07904046e-11, 8.34842055e-12,
#        6.30865429e-12, 4.64631620e-12, 3.32538135e-12, 2.30302700e-12,
#        1.53360568e-12, 9.71931054e-13, 5.75781574e-13, 3.07685159e-13,
#        1.36517065e-13, 4.46771681e-14, 4.78887345e-14, 6.81931639e-14,
#        7.39479601e-14, 6.97525866e-14, 6.05070145e-14, 4.95274132e-14,
#        3.87856361e-14, 2.92984844e-14, 2.14612417e-14, 1.52986370e-14,
#        1.06399783e-14, 7.23317124e-15, 4.81314855e-15, 3.13846061e-15,
#        2.00708530e-15, 1.25973154e-15, 7.76424062e-16, 4.70145090e-16,
#        2.79799248e-16, 1.63714165e-16, 9.42048345e-17, 5.33227159e-17,
#        2.96957465e-17, 1.62741467e-17, 8.77795789e-18, 4.66059235e-18,
#        2.43610045e-18, 1.25372953e-18, 6.35345756e-19, 3.17068169e-19,
#        1.55835420e-19, 7.54366114e-20, 3.59690658e-20, 1.68940231e-20,
#        7.81659526e-21, 3.56290664e-21]), 'dnde_ferr': array([0.3551426 , 0.33151697, 0.30752563, 0.28314374, 0.25834454,
#        0.23309945, 0.20737836, 0.18115066, 0.15438759, 0.1270687 ,
#        0.09920054, 0.07088369, 0.04266054, 0.01916627, 0.02815062,
#        0.055222  , 0.08363004, 0.1117771 , 0.13941114, 0.16648894,
#        0.19301986, 0.21902923, 0.24454706, 0.26960387, 0.29422911,
#        0.31845052, 0.34229398, 0.36578344, 0.38894108, 0.41178734,
#        0.4343411 , 0.45661982, 0.4786396 , 0.50041537, 0.52196093,
#        0.54328909, 0.56441172, 0.58533987, 0.60608382, 0.62665314,
#        0.64705675, 0.66730297, 0.6873996 , 0.70735392, 0.72717276,
#        0.7468625 , 0.76642915, 0.78587835, 0.8052154 , 0.82444529]), 'pivot_energy': 1197.1226537735797}}}
# 2022-06-10 11:25:49 INFO    GTAnalysis._extension(): Fitting extended-source model.
# 2022-06-10 11:26:30 INFO    GTAnalysis._extension(): Generating TS map.
# 2022-06-10 11:26:50 INFO    GTAnalysis._extension(): Testing point-source model.
# 2022-06-10 11:27:18 INFO    GTAnalysis._extension(): Best-fit extension: 0.4648 + 0.0225 - 0.0411
# 2022-06-10 11:27:18 INFO    GTAnalysis._extension(): TS_ext:        0.000
# 2022-06-10 11:27:18 INFO    GTAnalysis._extension(): Extension UL: 0.5019
# 2022-06-10 11:27:18 INFO    GTAnalysis._extension(): LogLike:  7186742.061 DeltaLogLike:        0.000
# 2022-06-10 11:27:18 INFO    GTAnalysis.extension(): Finished extension fit.
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}
# {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}
# 2022-06-10 11:27:24 WARNING GTAnalysis.extension(): Saving maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /home/user/fermi/J1928+178/J1932+1916_0.1GeV_15_bin6/3hwc_j1928+178s_ext.npy
# 2022-06-10 11:27:24 INFO    GTAnalysis.extension(): Execution time: 169.90 s
# {'name': '3HWC J1928+178s', 'file': None, 'config': {'spatial_model': 'RadialGaussian', 'width': [], 'fit_position': False, 'width_min': 0.01, 'width_max': 1.0, 'width_nstep': 21, 'free_background': False, 'fix_shape': False, 'free_radius': None, 'fit_ebin': False, 'update': True, 'save_model_map': False, 'sqrt_ts_threshold': None, 'psf_scale_fn': None, 'make_tsmap': True, 'tsmap_fitter': 'tsmap', 'make_plots': True, 'write_fits': True, 'write_npy': True, 'optimizer': {'optimizer': 'MINUIT', 'tol': 0.001, 'max_iter': 100, 'init_lambda': 0.0001, 'retries': 3, 'min_fit_quality': 2, 'verbosity': 0}, 'prefix': '', 'outfile': None}, 'width': array([0.        , 0.01      , 0.01258925, 0.01584893, 0.01995262,
#        0.02511886, 0.03162278, 0.03981072, 0.05011872, 0.06309573,
#        0.07943282, 0.1       , 0.12589254, 0.15848932, 0.19952623,
#        0.25118864, 0.31622777, 0.39810717, 0.50118723, 0.63095734,
#        0.79432823, 1.        ]), 'dloglike': array([6.34230673e-07, 5.33098355e-05, 8.43806192e-05, 1.08161010e-04,
#        1.28515996e-04, 1.46672130e-04, 1.75677240e-04, 1.90507621e-04,
#        2.09062360e-04, 2.42953189e-04, 3.05698253e-04, 3.96238640e-04,
#        4.88655642e-04, 5.42506576e-04, 5.07688150e-04, 5.01789153e-04,
#        4.55002300e-04, 4.10751440e-04, 3.86711210e-04, 3.92182730e-04,
#        4.17686068e-04, 4.44022007e-04]), 'loglike': array([7186742.06130997, 7186742.06136265, 7186742.06139372,
#        7186742.0614175 , 7186742.06143785, 7186742.06145601,
#        7186742.06148501, 7186742.06149984, 7186742.0615184 ,
#        7186742.06155229, 7186742.06161503, 7186742.06170558,
#        7186742.06179799, 7186742.06185184, 7186742.06181702,
#        7186742.06181113, 7186742.06176434, 7186742.06172009,
#        7186742.06169605, 7186742.06170152, 7186742.06172702,
#        7186742.06175336]), 'loglike_ptsrc': 7186742.061309337, 'loglike_ext': 7186742.061394661, 'loglike_init': 7186742.060981382, 'loglike_base': 7186742.061220981, 'ext': 0.46483723781526637, 'ext_err_hi': 0.02253642945420037, 'ext_err_lo': 0.041101070719893384, 'ext_err': 0.031818750087046876, 'ext_ul95': 0.501906326675465, 'ts_ext': 0.00048310868442058563, 'ebin_e_min': array([1.00000000e+02, 1.46781053e+02, 2.15441815e+02, 3.16227766e+02,
#        4.64162446e+02, 6.81286840e+02, 1.00000000e+03, 1.46781053e+03,
#        2.15441815e+03, 3.16227766e+03, 4.64162446e+03, 6.81286840e+03,
#        1.00000000e+04, 1.46781053e+04, 2.15441815e+04, 3.16227766e+04,
#        4.64162446e+04, 6.81286840e+04, 1.00000000e+05, 1.46781053e+05,
#        2.15441815e+05, 3.16227766e+05, 4.64162446e+05, 6.81286840e+05]), 'ebin_e_ctr': array([1.21153231e+02, 1.77827941e+02, 2.61014720e+02, 3.83120155e+02,
#        5.62341325e+02, 8.25401018e+02, 1.21153231e+03, 1.77827941e+03,
#        2.61014720e+03, 3.83120155e+03, 5.62341325e+03, 8.25401018e+03,
#        1.21153231e+04, 1.77827941e+04, 2.61014720e+04, 3.83120155e+04,
#        5.62341325e+04, 8.25401018e+04, 1.21153231e+05, 1.77827941e+05,
#        2.61014720e+05, 3.83120155e+05, 5.62341325e+05, 8.25401018e+05]), 'ebin_e_max': array([1.46781053e+02, 2.15441815e+02, 3.16227766e+02, 4.64162446e+02,
#        6.81286840e+02, 1.00000000e+03, 1.46781053e+03, 2.15441815e+03,
#        3.16227766e+03, 4.64162446e+03, 6.81286840e+03, 1.00000000e+04,
#        1.46781053e+04, 2.15441815e+04, 3.16227766e+04, 4.64162446e+04,
#        6.81286840e+04, 1.00000000e+05, 1.46781053e+05, 2.15441815e+05,
#        3.16227766e+05, 4.64162446e+05, 6.81286840e+05, 1.00000000e+06]), 'ebin_ext': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err_hi': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_err_lo': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ext_ul95': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_ts_ext': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_dloglike': array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan]]), 'ebin_loglike': array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan]]), 'ebin_loglike_ptsrc': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ebin_loglike_ext': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), 'ra': 292.09724537791766, 'dec': 17.815662567309136, 'glon': 52.92999999999997, 'glat': 0.20000000000006654, 'ra_err': nan, 'dec_err': nan, 'glon_err': nan, 'glat_err': nan, 'pos_offset': 0.0, 'pos_err': nan, 'pos_r68': nan, 'pos_r95': nan, 'pos_r99': nan, 'pos_err_semimajor': nan, 'pos_err_semiminor': nan, 'pos_angle': nan, 'tsmap': WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat']
# 	shape : (31, 31)
# 	ndim  : 2
# 	unit  :
# 	dtype : float64
# , 'ptsrc_tot_map': None, 'ptsrc_src_map': None, 'ptsrc_bkg_map': None, 'ext_tot_map': None, 'ext_src_map': None, 'ext_bkg_map': None, 'source_fit': {'param_names': array([b'Prefactor', b'Index', b'Scale', b'', b'', b'', b'', b'', b'',
#        b''], dtype='|S32'), 'param_values': array([ 1.00011611e-16, -2.29713417e+00,  1.00000000e+03,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             n
#         94.4726972 , 102.34649703, 110.22026804, 118.094016  ,
#        125.96774524, 133.84145904, 141.71516   , 149.58885013,
#        157.46253106, 165.33620411, 173.20987035, 181.08353066,
#        188.95718579, 196.83083636, 204.7044829 , 212.57812585,
#        220.4517656 , 228.32540248, 236.19903678, 244.07266875,
#        251.9462986 , 259.81992652, 267.6935527 , 275.56717727,
#        283.44080037, 291.31442213]), 'pivot_energy': 959.1419638524198}}}

# %%
ext1['ext']
# Out:
# 0.7881450904040797

# %%
ext2['ext']
# Out:
# 0.46483723781526637

# %%
print(gta.roi['3HWC J1928+178PSR'])
# Out:
# Name           : 3HWC J1928+178PSR
# Associations   : ['3HWC J1928+178PSR']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.76
# Npred          : 14.31
# Flux           : 4.365e-11 +/- 3.25e-14
# EnergyFlux     :  1.87e-08 +/- 1.39e-11
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff
# Spectral Parameters
# b'Prefactor'   :      1e-14 +/-  7.447e-18
# b'Index1'      :      -1.55 +/-        nan
# b'Scale'       :       1000 +/-        nan
# b'Cutoff'      :       1930 +/-        nan
# b'Index2'      :          1 +/-        nan

# %%
print(gta.roi['3HWC J1928+178i'])
# Out:
# Name           : 3HWC J1928+178i
# Associations   : ['3HWC J1928+178i']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 89.52
# Npred          : 5114.47
# Flux           : 1.261e-08 +/-  1.9e-09
# EnergyFlux     : 1.379e-05 +/- 2.01e-06
# SpatialModel   : RadialGaussian
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  2.512e-14 +/-  8.831e-15
# b'alpha'       :      2.525 +/-     0.1665
# b'beta'        :        0.2 +/-  1.978e-05
# b'Eb'          :      1e+04 +/-        nan

# %%
print(gta.roi['3HWC J1928+178s'])
# Out:
# Name           : 3HWC J1928+178s
# Associations   : ['3HWC J1928+178s']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : -0.00
# Npred          : 0.47
# Flux           : 1.703e-12 +/-  1.4e-10
# EnergyFlux     : 6.286e-10 +/- 3.35e-08
# SpatialModel   : RadialGaussian
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  1.024e-16 +/-  4.114e-15
# b'Index'       :     -2.351 +/-      78.39
# b'Scale'       :       1000 +/-        nan

# %%
gta.print_params()
# Out:
# 2022-06-10 11:27:24 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------
# 3HWC J1928+178PSR
#    0 Prefactor                1e-05         0     1e-05     1e+03     1e-09    *
#    1 Index1                    1.55         0         0         5        -1    *
#    2 Scale                        1         0     0.001     1e+03     1e+03
#    3 Cutoff                    1.93         0     0.001     1e+03     1e+03    *
#    4 Index2                       1         0         0         2         1
# 3HWC J1928+178i
#    5 norm                    0.0251         0     1e-05     1e+03     1e-12    *
#    6 alpha                     2.53         0        -5         5         1    *
#    7 beta                         2         0        -2         2       0.1    *
#    8 Eb                           1         0     0.001     1e+03     1e+04
# 3HWC J1928+178s
#    9 Prefactor             1.02e-05  0.000411     1e-05     1e+03     1e-11    *
#   10 Index                     2.35      78.4         0         5        -1    *
#   11 Scale                        1         0     0.001     1e+03     1e+03
# 4FGL J1906.1+1651
#   72 norm                     0.802         0     1e-05     1e+03     1e-13    *
#   73 alpha                      1.7         0        -5         5         1
#   74 beta                      1.02         0        -2         2         1
#   75 Eb                    3.18e+03         0  3.18e+03  3.18e+03         1
# 4FGL J1908.9+2103
#   96 Prefactor                0.285         0     1e-05     1e+03     1e-12    *
#   97 Index1                    1.97         0         0         5        -1
#   98 Scale                 2.13e+03         0  2.13e+03  2.13e+03         1
#   99 Expfactor                0.318         0      -0.5     0.901      0.01
#  100 Index2                   0.667         0         0         2         1
# 4FGL J1911.0+0905
#  107 norm                     0.653         0     1e-05     1e+03     1e-12    *
#  108 alpha                        5         0        -5         5         1
#  109 beta                     0.826         0        -2         2         1
#  110 Eb                    3.47e+03         0  3.47e+03  3.47e+03         1
# 4FGL J1912.0+1612
#  115 Prefactor                 4.22         0     1e-05     1e+03     1e-13    *
#  116 Index                     2.65         0         0         5        -1
#  117 Scale                 1.38e+03         0  1.38e+03  1.38e+03         1
# 4FGL J1912.5+1320
#  118 norm                     0.455         0     1e-05     1e+03     1e-11    *
#  119 alpha                     3.53         0        -5         5         1
#  120 beta                     0.706         0        -2         2         1
#  121 Eb                         886         0       886       886         1
# 4FGL J1915.3+1149
#  142 norm                      3.01         0     1e-05     1e+03     1e-12    *
#  143 alpha                     2.88         0        -5         5         1
#  144 beta                      0.42         0        -2         2         1
#  145 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1916.3+1108
#  146 norm                      3.06         0     1e-05     1e+03     1e-12    *
#  147 alpha                     1.84         0        -5         5         1
#  148 beta                     0.133         0        -2         2         1
#  149 Eb                    2.02e+03         0  2.02e+03  2.02e+03         1
# 4FGL J1918.1+1215
#  150 norm                      3.28         0     1e-05     1e+03     1e-12    *
#  151 alpha                     2.86         0        -5         5         1
#  152 beta                     0.654         0        -2         2         1
#  153 Eb                    1.16e+03         0  1.16e+03  1.16e+03         1
# 4FGL J1919.1+2354
#  154 norm                     0.343         0     1e-05     1e+03     1e-12    *
#  155 alpha                     2.48         0        -5         5         1
#  156 beta                     0.426         0        -2         2         1
#  157 Eb                     1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1919.4+1313
#  158 norm                      0.77         0     1e-05     1e+03     1e-11    *
#  159 alpha                     3.78         0        -5         5         1
#  160 beta                      1.04         0        -2         2         1
#  161 Eb                         902         0       902       902         1
# 4FGL J1920.9+1408
#  166 norm                      1.42         0     1e-05     1e+03     1e-12    *
#  167 alpha                     3.01         0        -5         5         1
#  168 beta                     0.367         0        -2         2         1
#  169 Eb                    1.82e+03         0  1.82e+03  1.82e+03         1
# 4FGL J1921.1+1930
#  170 Prefactor                 2.92         0     1e-05     1e+03     1e-13    *
#  171 Index                     2.44         0         0         5        -1
#  172 Scale                  1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1922.2+2314
#  173 Prefactor                 2.93         0     1e-05     1e+03     1e-14    *
#  174 Index                     2.16         0         0         5        -1
#  175 Scale                 4.13e+03         0  4.13e+03  4.13e+03         1
# 4FGL J1922.4+1453
#  176 norm                     0.702         0     1e-05     1e+03     1e-12    *
#  177 alpha                     2.85         0        -5         5         1
#  178 beta                     0.404         0        -2         2         1
#  179 Eb                    1.68e+03         0  1.68e+03  1.68e+03         1
# 4FGL J1922.7+1428
#  180 norm                      1.44         0     1e-05     1e+03     1e-12    *
#  181 alpha                     3.67         0        -5         5         1
#  182 beta                     0.625         0        -2         2         1
#  183 Eb                    1.81e+03         0  1.81e+03  1.81e+03         1
# 4FGL J1923.2+1408e
#  184 norm                     0.614         0     1e-05     1e+03     1e-11    *
#  185 alpha                      2.2         0        -5         5         1
#  186 beta                     0.131         0        -2         2         1
#  187 Eb                    2.53e+03         0  2.53e+03  2.53e+03         1
# 4FGL J1925.1+1707
#  194 Prefactor                0.453         0     1e-05     1e+03     1e-13    *
#  195 Index                     2.34         0         0         5        -1
#  196 Scale                 3.84e+03         0  3.84e+03  3.84e+03         1
# 4FGL J1925.2+1729
#  197 Prefactor                 2.93         0     1e-05     1e+03     1e-11    *
#  198 Index1                   0.549         0         0         5        -1
#  199 Scale                 1.98e+03         0  1.98e+03  1.98e+03         1
#  200 Expfactor                 2.45         0      -0.5      2.45      0.01
#  201 Index2                   0.667         0         0         2         1
# 4FGL J1925.3+1522
#  202 norm                      1.39         0     1e-05     1e+03     1e-12    *
#  203 alpha                        3         0        -5         5         1
#  204 beta                     0.514         0        -2         2         1
#  205 Eb                     1.5e+03         0   1.5e+03   1.5e+03         1
# 4FGL J1925.4+1616
#  206 Prefactor                 1.37         0     1e-05     1e+03     1e-13    *
#  207 Index                     2.32         0         0         5        -1
#  208 Scale                 4.07e+03         0  4.07e+03  4.07e+03         1
# 4FGL J1925.7+1227
#  209 norm                     0.627         0     1e-05     1e+03     1e-12    *
#  210 alpha                     2.86         0        -5         5         1
#  211 beta                     0.266         0        -2         2         1
#  212 Eb                    1.77e+03         0  1.77e+03  1.77e+03         1
# 4FGL J1926.4+1602
#  213 norm                     0.291         0     1e-05     1e+03     1e-12    *
#  214 alpha                     3.92         0        -5         5         1
#  215 beta                     0.574         0        -2         2         1
#  216 Eb                    2.43e+03         0  2.43e+03  2.43e+03         1
# 4FGL J1929.0+1729
#  224 norm                      1.94         0     1e-05     1e+03     1e-12    *
#  225 alpha                     3.39         0        -5         5         1
#  226 beta                     0.685         0        -2         2         1
#  227 Eb                    1.63e+03         0  1.63e+03  1.63e+03         1
# 4FGL J1929.8+1832
#  228 Prefactor                 1.36         0     1e-05     1e+03     1e-13    *
#  229 Index                     2.39         0         0         5        -1
#  230 Scale                 2.64e+03         0  2.64e+03  2.64e+03         1
# 4FGL J1931.1+1656
#  239 norm                      3.65         0     1e-05     1e+03     1e-12    *
#  240 alpha                     3.04         0        -5         5         1
#  241 beta                     0.545         0        -2         2         1
#  242 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1932.3+1916
#  248 Prefactor                 2.72         0     1e-05     1e+03     1e-11    *
#  249 Index1                    1.25         0         0         5        -1
#  250 Scale                 1.54e+03         0  1.54e+03  1.54e+03         1
#  251 Expfactor                 1.31         0      -0.5      1.31      0.01
#  252 Index2                   0.667         0         0         2         1
# 4FGL J1934.3+1859
#  259 norm                      2.12         0     1e-05     1e+03     1e-12    *
#  260 alpha                     4.87         0        -5         5         1
#  261 beta                       1.4         0        -2         2         1
#  262 Eb                     1.1e+03         0   1.1e+03   1.1e+03         1
# 4FGL J1935.2+2029
#  263 Prefactor                0.886         0     1e-05     1e+03     1e-11    *
#  264 Index1                    1.73         0         0         5        -1
#  265 Scale                 1.19e+03         0  1.19e+03  1.19e+03         1
#  266 Expfactor                 1.02         0      -0.5      1.02      0.01
#  267 Index2                   0.667         0         0         2         1
# 4FGL J1936.6+1921
#  268 norm                     0.292         0     1e-05     1e+03     1e-12    *
#  269 alpha                     2.63         0        -5         5         1
#  270 beta                      0.49         0        -2         2         1
#  271 Eb                    1.88e+03         0  1.88e+03  1.88e+03         1
# 4FGL J1939.6+2135
#  272 Prefactor                0.361         0     1e-05     1e+03     1e-11    *
#  273 Index1                    1.37         0         0         5        -1
#  274 Scale                  1.8e+03         0   1.8e+03   1.8e+03         1
#  275 Expfactor                0.961         0      -0.5     0.961      0.01
#  276 Index2                   0.667         0         0         2         1
# 4FGL J1944.0+2117
#  283 norm                     0.426         0     1e-05     1e+03     1e-14    *
#  284 alpha                     1.24         0        -5         5         1
#  285 beta                     0.207         0        -2         2         1
#  286 Eb                    1.57e+04         0  1.57e+04  1.57e+04         1
# 4FGL J1949.0+1314
#  305 Prefactor                0.391         0     1e-05     1e+03     1e-12    *
#  306 Index                     2.46         0         0         5        -1
#  307 Scale                 1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1950.8+1211
#  318 norm                     0.941         0     1e-05     1e+03     1e-12    *
#  319 alpha                     2.26         0        -5         5         1
#  320 beta                     0.423         0        -2         2         1
#  321 Eb                    1.09e+03         0  1.09e+03  1.09e+03         1
# 4FGL J1951.0+2523
#  322 norm                      1.55         0     1e-05     1e+03     1e-12    *
#  323 alpha                     2.78         0        -5         5         1
#  324 beta                      0.77         0        -2         2         1
#  325 Eb                    1.19e+03         0  1.19e+03  1.19e+03         1
# 4FGL J1951.6+2621
#  326 norm                     0.965         0     1e-05     1e+03     1e-12    *
#  327 alpha                      3.1         0        -5         5         1
#  328 beta                     0.786         0        -2         2         1
#  329 Eb                    1.47e+03         0  1.47e+03  1.47e+03         1
# 4FGL J1955.2+1358
#  351 norm                       1.4         0     1e-05     1e+03     1e-12    *
#  352 alpha                     2.28         0        -5         5         1
#  353 beta                     0.186         0        -2         2         1
#  354 Eb                         925         0       925       925         1
# 4FGL J1958.1+2438
#  358 Prefactor                 1.94         0     1e-05     1e+03     1e-14    *
#  359 Index                        2         0         0         5        -1
#  360 Scale                 5.33e+03         0  5.33e+03  5.33e+03         1
# 4FGL J1959.5+2048
#  366 Prefactor                 1.27         0     1e-05     1e+03     1e-11    *
#  367 Index1                   0.799         0         0         5        -1
#  368 Scale                 1.35e+03         0  1.35e+03  1.35e+03         1
#  369 Expfactor                 1.61         0      -0.5      1.61      0.01
#  370 Index2                   0.667         0         0         2         1
# galdiff
#  411 Prefactor                0.968         0       0.1        10         1    *
#  412 Index                 0.000227         0        -1         1        -1
#  413 Scale                    1e+03         0     1e+03     1e+03         1
# isodiff
#  414 Normalization             1.15         0     0.001     1e+03         1    *

# %% [markdown]
# In this simple anlaysis we are leaving the spectral shapes of sources fixed but we're going to free the spectral shape of the source we care about.

# %% [markdown]
# Now, actually do the fit.  The software does its best to get the fit to converge by running the fit several times.

# %%
fit_results = gta.fit()
# Out:
# 2022-06-10 11:28:01 INFO    GTAnalysis.fit(): Starting fit.
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/scipy/interpolate/fitpack2.py:279: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# 2022-06-10 11:39:21 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   2 Status: 101
# 2022-06-10 11:39:21 INFO    GTAnalysis.fit(): LogLike:  7186850.835 DeltaLogLike:      108.774

# %% [markdown]
# The dictionary returned by the fit method returns a variety of diagnostic information about the fit including the fit quality, the relative improvement in the likelihood, and the correlations among the fit parameters. For example :

# %%
print('Fit Quality: ',fit_results['fit_quality'])
#print(gta.roi['4FGL J0534.5+2201i'])
# Out:
# Fit Quality:  2

# %% [markdown]
# Let's have a look at the sources and the best-fit parameters after the fit

# %%
print(gta.roi['3HWC J1928+178PSR'])
# Out:
# Name           : 3HWC J1928+178PSR
# Associations   : ['3HWC J1928+178PSR']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 0.00
# Npred          : 0.00
# Flux           : 3.669e-25 +/- 1.49e-18
# EnergyFlux     : 3.716e-23 +/- 1.54e-16
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff
# Spectral Parameters
# b'Prefactor'   :  1.064e-14 +/-  6.533e-08
# b'Index1'      :    -0.8764 +/-     -3.267
# b'Scale'       :       1000 +/-        nan
# b'Cutoff'      :        3.6 +/-      757.8
# b'Index2'      :          1 +/-        nan

# %%
print(gta.roi['3HWC J1928+178i'])
# Out:
# Name           : 3HWC J1928+178i
# Associations   : ['3HWC J1928+178i']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 683.23
# Npred          : 25094.05
# Flux           : 7.604e-08 +/- 3.53e-09
# EnergyFlux     : 3.537e-05 +/- 1.41e-06
# SpatialModel   : RadialGaussian
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  2.175e-14 +/-  7.269e-16
# b'alpha'       :      3.112 +/-   0.009069
# b'beta'        :        0.2 +/-  2.158e-06
# b'Eb'          :      1e+04 +/-        nan

# %%
print(gta.roi['3HWC J1928+178s'])
# Out:
# Name           : 3HWC J1928+178s
# Associations   : ['3HWC J1928+178s']
# RA/DEC         :    292.097/    17.816
# GLON/GLAT      :     52.930/     0.200
# TS             : 1.38
# Npred          : 53.38
# Flux           : 1.206e-10 +/-  5.8e-11
# EnergyFlux     : 2.824e-06 +/- 1.56e-06
# SpatialModel   : RadialGaussian
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :   1.96e-14 +/-  9.426e-15
# b'Index'       :      -1.34 +/-   -0.05064
# b'Scale'       :       1000 +/-        nan

# %%
gta.print_roi()
# Out:
# 2022-06-10 11:39:21 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449   3543.84     29508.8
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482     15.39      2479.5
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794    512.98     14960.2
# 3HWC J1928+178PSR   PointSource    PLSuperExpCuto    1.286      0.00         0.0
# 3HWC J1928+178i     RadialGaussian LogParabola       1.286    683.23     25094.1
# 3HWC J1928+178s     RadialGaussian PowerLaw          1.286      1.38        53.4
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399     63.03      2146.9
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527    260.15      9355.0
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846    464.24     14300.6
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991     82.35      4362.5
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000    720.14     16097.2
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289     44.13      4107.0
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386     72.62      4308.4
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977    374.24     12934.9
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097    499.70     16312.2
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314     77.08      5736.2
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343    281.55      7042.0
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431     28.01      1171.6
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820    267.60     10033.6
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855    259.05       161.9
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094     16.70       694.4
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535    191.95      8715.2
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760    116.29      2190.4
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882    571.80     19543.7
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143  26880.50     93829.8
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274    138.18      6977.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364    623.09     19104.9
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366     67.33      1596.5
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591    161.21      2895.0
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675    107.57      1700.9
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909      4.55       458.3
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260    112.15       287.4
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347    563.44     17220.2
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603    273.24      7711.0
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663     66.94      1304.1
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869     20.42       963.4
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979   1174.08      4702.6
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023      6.57      1029.0
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137    376.73     12367.5
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154    284.26      4202.7
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359    268.65      7695.3
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589     22.48       987.1
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649    291.11      2813.5
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698     69.63      1420.5
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949    112.38      3072.6
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011     61.97       926.1
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061    327.08      9066.3
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069     28.86      1791.6
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272    199.41      1595.4
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283     13.26      1730.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381      0.18       232.6
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489    122.27      1298.0
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567    159.16      6426.2
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716     69.46       990.1
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738     11.16      1206.7
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769      6.66      1568.9
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809    101.21      2312.7
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856     85.08      3545.8
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075     76.30       973.0
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298     -0.00         0.0
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313     15.15      2584.0
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418     -0.00         0.0
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574     -0.00         0.0
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590     -0.00         0.0
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606     -0.00         0.0
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748      5.05      1631.3
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870      7.42      2035.3
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961     19.82       458.7
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012     -0.00         0.0
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014     43.22      5169.2
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189     -0.00         0.0
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599      0.20       168.9
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735      0.40       594.2
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808     -0.00         0.0
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818     -0.00         0.0
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971    291.87     15127.9
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002      2.36       711.9
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033     -0.00         0.0
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077     -0.00         0.0
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093     -0.00         0.0
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279     -0.00         0.1
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518     -0.00         0.0
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536      3.58      1348.2
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561     -0.00         0.0
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582     -0.00         0.1
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686     -0.00         0.1
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006      0.41       204.6
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020      6.56      2146.3
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328     18.96      2442.1
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504     -0.00         0.0
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975      0.00        22.1
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994     -0.00         0.0
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098     -0.00         0.0
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538     -0.00         0.1
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800     -0.00         0.0
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876     -0.00         0.0
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945      0.91       648.4
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006     -0.00         0.0
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166     10.01       991.6
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456      0.08       194.7
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488     -0.00         0.0
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590     -0.00         0.0
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904     -0.00         0.0
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071     -0.00         0.0
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228     -0.00         0.0
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809     -0.00         0.0
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109     -0.00         0.0
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146     -0.00         0.0
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337     -0.00         0.0
# isodiff             ConstantValue  FileFunction      -----   6136.10    230273.3
# galdiff             MapCubeFunctio PowerLaw          -----1924666.68   4385463.9

# %%
gta.print_params()
# Out:
# 2022-06-10 11:39:21 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------
# 3HWC J1928+178PSR
#    0 Prefactor             1.06e-05      65.3     1e-05     1e+03     1e-09    *
#    1 Index1                   0.876      3.27         0         5        -1    *
#    2 Scale                        1         0     0.001     1e+03     1e+03
#    3 Cutoff                  0.0036     0.758     0.001     1e+03     1e+03    *
#    4 Index2                       1         0         0         2         1
# 3HWC J1928+178i
#    5 norm                    0.0217  0.000727     1e-05     1e+03     1e-12    *
#    6 alpha                     3.11   0.00907        -5         5         1    *
#    7 beta                         2  2.16e-05        -2         2       0.1    *
#    8 Eb                           1         0     0.001     1e+03     1e+04
# 3HWC J1928+178s
#    9 Prefactor              0.00196  0.000943     1e-05     1e+03     1e-11    *
#   10 Index                     1.34    0.0506         0         5        -1    *
#   11 Scale                        1         0     0.001     1e+03     1e+03
# 4FGL J1906.1+1651
#   72 norm                       0.8     0.107     1e-05     1e+03     1e-13    *
#   73 alpha                      1.7         0        -5         5         1
#   74 beta                      1.02         0        -2         2         1
#   75 Eb                    3.18e+03         0  3.18e+03  3.18e+03         1
# 4FGL J1908.9+2103
#   96 Prefactor                0.289     0.027     1e-05     1e+03     1e-12    *
#   97 Index1                    1.97         0         0         5        -1
#   98 Scale                 2.13e+03         0  2.13e+03  2.13e+03         1
#   99 Expfactor                0.318         0      -0.5     0.901      0.01
#  100 Index2                   0.667         0         0         2         1
# 4FGL J1911.0+0905
#  107 norm                     0.895    0.0414     1e-05     1e+03     1e-12    *
#  108 alpha                        5         0        -5         5         1
#  109 beta                     0.826         0        -2         2         1
#  110 Eb                    3.47e+03         0  3.47e+03  3.47e+03         1
# 4FGL J1912.0+1612
#  115 Prefactor                  4.7     0.404     1e-05     1e+03     1e-13    *
#  116 Index                     2.65         0         0         5        -1
#  117 Scale                 1.38e+03         0  1.38e+03  1.38e+03         1
# 4FGL J1912.5+1320
#  118 norm                     0.411    0.0187     1e-05     1e+03     1e-11    *
#  119 alpha                     3.53         0        -5         5         1
#  120 beta                     0.706         0        -2         2         1
#  121 Eb                         886         0       886       886         1
# 4FGL J1915.3+1149
#  142 norm                      2.32      0.13     1e-05     1e+03     1e-12    *
#  143 alpha                     2.88         0        -5         5         1
#  144 beta                      0.42         0        -2         2         1
#  145 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1916.3+1108
#  146 norm                      3.23     0.258     1e-05     1e+03     1e-12    *
#  147 alpha                     1.84         0        -5         5         1
#  148 beta                     0.133         0        -2         2         1
#  149 Eb                    2.02e+03         0  2.02e+03  2.02e+03         1
# 4FGL J1918.1+1215
#  150 norm                      3.25     0.201     1e-05     1e+03     1e-12    *
#  151 alpha                     2.86         0        -5         5         1
#  152 beta                     0.654         0        -2         2         1
#  153 Eb                    1.16e+03         0  1.16e+03  1.16e+03         1
# 4FGL J1919.1+2354
#  154 norm                     0.346    0.0378     1e-05     1e+03     1e-12    *
#  155 alpha                     2.48         0        -5         5         1
#  156 beta                     0.426         0        -2         2         1
#  157 Eb                     1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1919.4+1313
#  158 norm                     0.674    0.0259     1e-05     1e+03     1e-11    *
#  159 alpha                     3.78         0        -5         5         1
#  160 beta                      1.04         0        -2         2         1
#  161 Eb                         902         0       902       902         1
# 4FGL J1920.9+1408
#  166 norm                       1.4    0.0547     1e-05     1e+03     1e-12    *
#  167 alpha                     3.01         0        -5         5         1
#  168 beta                     0.367         0        -2         2         1
#  169 Eb                    1.82e+03         0  1.82e+03  1.82e+03         1
# 4FGL J1921.1+1930
#  170 Prefactor                 2.69     0.331     1e-05     1e+03     1e-13    *
#  171 Index                     2.44         0         0         5        -1
#  172 Scale                  1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1922.2+2314
#  173 Prefactor                 2.82     0.335     1e-05     1e+03     1e-14    *
#  174 Index                     2.16         0         0         5        -1
#  175 Scale                 4.13e+03         0  4.13e+03  4.13e+03         1
# 4FGL J1922.4+1453
#  176 norm                      1.01    0.0719     1e-05     1e+03     1e-12    *
#  177 alpha                     2.85         0        -5         5         1
#  178 beta                     0.404         0        -2         2         1
#  179 Eb                    1.68e+03         0  1.68e+03  1.68e+03         1
# 4FGL J1922.7+1428
#  180 norm                       1.1     0.044     1e-05     1e+03     1e-12    *
#  181 alpha                     3.67         0        -5         5         1
#  182 beta                     0.625         0        -2         2         1
#  183 Eb                    1.81e+03         0  1.81e+03  1.81e+03         1
# 4FGL J1923.2+1408e
#  184 norm                     0.627    0.0048     1e-05     1e+03     1e-11    *
#  185 alpha                      2.2         0        -5         5         1
#  186 beta                     0.131         0        -2         2         1
#  187 Eb                    2.53e+03         0  2.53e+03  2.53e+03         1
# 4FGL J1925.1+1707
#  194 Prefactor                0.395    0.0468     1e-05     1e+03     1e-13    *
#  195 Index                     2.34         0         0         5        -1
#  196 Scale                 3.84e+03         0  3.84e+03  3.84e+03         1
# 4FGL J1925.2+1729
#  197 Prefactor                 1.88     0.209     1e-05     1e+03     1e-11    *
#  198 Index1                   0.549         0         0         5        -1
#  199 Scale                 1.98e+03         0  1.98e+03  1.98e+03         1
#  200 Expfactor                 2.45         0      -0.5      2.45      0.01
#  201 Index2                   0.667         0         0         2         1
# 4FGL J1925.3+1522
#  202 norm                      1.47    0.0899     1e-05     1e+03     1e-12    *
#  203 alpha                        3         0        -5         5         1
#  204 beta                     0.514         0        -2         2         1
#  205 Eb                     1.5e+03         0   1.5e+03   1.5e+03         1
# 4FGL J1925.4+1616
#  206 Prefactor                 1.16    0.0643     1e-05     1e+03     1e-13    *
#  207 Index                     2.32         0         0         5        -1
#  208 Scale                 4.07e+03         0  4.07e+03  4.07e+03         1
# 4FGL J1925.7+1227
#  209 norm                     0.642    0.0396     1e-05     1e+03     1e-12    *
#  210 alpha                     2.86         0        -5         5         1
#  211 beta                     0.266         0        -2         2         1
#  212 Eb                    1.77e+03         0  1.77e+03  1.77e+03         1
# 4FGL J1926.4+1602
#  213 norm                     0.289    0.0122     1e-05     1e+03     1e-12    *
#  214 alpha                     3.92         0        -5         5         1
#  215 beta                     0.574         0        -2         2         1
#  216 Eb                    2.43e+03         0  2.43e+03  2.43e+03         1
# 4FGL J1929.0+1729
#  224 norm                      1.03    0.0639     1e-05     1e+03     1e-12    *
#  225 alpha                     3.39         0        -5         5         1
#  226 beta                     0.685         0        -2         2         1
#  227 Eb                    1.63e+03         0  1.63e+03  1.63e+03         1
# 4FGL J1929.8+1832
#  228 Prefactor                0.505     0.127     1e-05     1e+03     1e-13    *
#  229 Index                     2.39         0         0         5        -1
#  230 Scale                 2.64e+03         0  2.64e+03  2.64e+03         1
# 4FGL J1931.1+1656
#  239 norm                       2.9     0.111     1e-05     1e+03     1e-12    *
#  240 alpha                     3.04         0        -5         5         1
#  241 beta                     0.545         0        -2         2         1
#  242 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1932.3+1916
#  248 Prefactor                 2.76    0.0537     1e-05     1e+03     1e-11    *
#  249 Index1                    1.25         0         0         5        -1
#  250 Scale                 1.54e+03         0  1.54e+03  1.54e+03         1
#  251 Expfactor                 1.31         0      -0.5      1.31      0.01
#  252 Index2                   0.667         0         0         2         1
# 4FGL J1934.3+1859
#  259 norm                       1.9    0.0827     1e-05     1e+03     1e-12    *
#  260 alpha                     4.87         0        -5         5         1
#  261 beta                       1.4         0        -2         2         1
#  262 Eb                     1.1e+03         0   1.1e+03   1.1e+03         1
# 4FGL J1935.2+2029
#  263 Prefactor                0.852    0.0393     1e-05     1e+03     1e-11    *
#  264 Index1                    1.73         0         0         5        -1
#  265 Scale                 1.19e+03         0  1.19e+03  1.19e+03         1
#  266 Expfactor                 1.02         0      -0.5      1.02      0.01
#  267 Index2                   0.667         0         0         2         1
# 4FGL J1936.6+1921
#  268 norm                     0.325    0.0422     1e-05     1e+03     1e-12    *
#  269 alpha                     2.63         0        -5         5         1
#  270 beta                      0.49         0        -2         2         1
#  271 Eb                    1.88e+03         0  1.88e+03  1.88e+03         1
# 4FGL J1939.6+2135
#  272 Prefactor                0.355    0.0226     1e-05     1e+03     1e-11    *
#  273 Index1                    1.37         0         0         5        -1
#  274 Scale                  1.8e+03         0   1.8e+03   1.8e+03         1
#  275 Expfactor                0.961         0      -0.5     0.961      0.01
#  276 Index2                   0.667         0         0         2         1
# 4FGL J1944.0+2117
#  283 norm                     0.424    0.0508     1e-05     1e+03     1e-14    *
#  284 alpha                     1.24         0        -5         5         1
#  285 beta                     0.207         0        -2         2         1
#  286 Eb                    1.57e+04         0  1.57e+04  1.57e+04         1
# 4FGL J1949.0+1314
#  305 Prefactor                0.407    0.0281     1e-05     1e+03     1e-12    *
#  306 Index                     2.46         0         0         5        -1
#  307 Scale                 1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1950.8+1211
#  318 norm                     0.945    0.0803     1e-05     1e+03     1e-12    *
#  319 alpha                     2.26         0        -5         5         1
#  320 beta                     0.423         0        -2         2         1
#  321 Eb                    1.09e+03         0  1.09e+03  1.09e+03         1
# 4FGL J1951.0+2523
#  322 norm                      1.44      0.14     1e-05     1e+03     1e-12    *
#  323 alpha                     2.78         0        -5         5         1
#  324 beta                      0.77         0        -2         2         1
#  325 Eb                    1.19e+03         0  1.19e+03  1.19e+03         1
# 4FGL J1951.6+2621
#  326 norm                      0.97     0.101     1e-05     1e+03     1e-12    *
#  327 alpha                      3.1         0        -5         5         1
#  328 beta                     0.786         0        -2         2         1
#  329 Eb                    1.47e+03         0  1.47e+03  1.47e+03         1
# 4FGL J1955.2+1358
#  351 norm                      1.42    0.0981     1e-05     1e+03     1e-12    *
#  352 alpha                     2.28         0        -5         5         1
#  353 beta                     0.186         0        -2         2         1
#  354 Eb                         925         0       925       925         1
# 4FGL J1958.1+2438
#  358 Prefactor                 1.86      0.24     1e-05     1e+03     1e-14    *
#  359 Index                        2         0         0         5        -1
#  360 Scale                 5.33e+03         0  5.33e+03  5.33e+03         1
# 4FGL J1959.5+2048
#  366 Prefactor                 1.28    0.0484     1e-05     1e+03     1e-11    *
#  367 Index1                   0.799         0         0         5        -1
#  368 Scale                 1.35e+03         0  1.35e+03  1.35e+03         1
#  369 Expfactor                 1.61         0      -0.5      1.61      0.01
#  370 Index2                   0.667         0         0         2         1
# galdiff
#  411 Prefactor                0.969  0.000496       0.1        10         1    *
#  412 Index                 0.000227         0        -1         1        -1
#  413 Scale                    1e+03         0     1e+03     1e+03         1
# isodiff
#  414 Normalization             1.13   0.00895     0.001     1e+03         1    *

# %% [markdown]
# You can then save the state of the roi to an output file for reference later.

# %%
#gta.write_roi('fit0',make_plots=True)
gta.write_roi('J1928+178_0.1GeV_3_component',make_plots=True)
# Out:
# 2022-06-10 11:39:21 INFO    GTBinnedAnalysis.write_xml(): Writing /home/user/fermi/J1928+178/J1932+1916_0.1GeV_15_bin6/J1928+178_0.1GeV_3_component_00.xml...
# 2022-06-10 11:39:21 INFO    GTAnalysis.write_fits(): Writing /home/user/fermi/J1928+178/J1932+1916_0.1GeV_15_bin6/J1928+178_0.1GeV_3_component.fits...
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %f cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# 2022-06-10 11:39:36 INFO    GTAnalysis.write_roi(): Writing /home/user/fermi/J1928+178/J1932+1916_0.1GeV_15_bin6/J1928+178_0.1GeV_3_component.npy...

# %% [markdown]
# We can also inspect the final model map. The next command will return the model map as a `gammapy.Map` instance (Full documentation for `gammapy`  [here](https://docs.gammapy.org)).

# %%
#model_map = gta.write_model_map("Pulsar_J1932")

# %%
#print(model_map)

# %%
#model_map[0].geom.axes[0]

# %% [markdown]
# Plot the model map summed over the energy axis. The plot shows the predicted number of counts for all model components.

# %%
#model_map[0].sum_over_axes(["energy"]).plot(stretch="sqrt",cmap='plasma', add_cbar=True)
#plt.savefig("J1928+178_15_bin3/model.png")

# %% [markdown]
# Plot each energy bin of the model map. This nicely illustrates the broad PSF at low energies.

# %%
#model_map_bins = model_map[0].plot_grid(stretch="sqrt",cmap='plasma', add_cbar=True)
#plt.savefig("J1928+178_15_bin6/model_bins.png")

# %% [markdown]
# ### Reading in the results
#
# The results are saved and you can retrieve them from the output numpy file.

# %%
ls J1932+1916_15_bin_3/*npy
# Out:
# J1932+1916_15_bin_3/4fgl_j1925.2+1729_sed.npy
# J1932+1916_15_bin_3/4fgl_j1928.4+1801c_sed.npy
# J1932+1916_15_bin_3/4fgl_j1929.0+1729_sed.npy
# J1932+1916_15_bin_3/4fgl_j1932.3+1916i_ext.npy
# J1932+1916_15_bin_3/4fgl_j1932.3+1916i_sed.npy
# J1932+1916_15_bin_3/4fgl_j1932.3+1916_sed.npy
# J1932+1916_15_bin_3/4fgl_j1935.2+2029_sed.npy
# J1932+1916_15_bin_3/Pulsar_J1932.npy
# J1932+1916_15_bin_3/Reference.npy
# J1932+1916_15_bin_3/Reference_pointsource_powerlaw_2.00_residmap.npy

# %%
c = np.load('J1932+1916_0.1GeV_15_bin6/J1928+178_0.1GeV_3_component.npy', allow_pickle=True).flat[0]

# %% [markdown]
# The `sources` dictionary has an entry for each source in the model:

# %%
sorted(c['sources'].keys())
# Out:
# ['3HWC J1928+178PSR',
#  '3HWC J1928+178i',
#  '3HWC J1928+178s',
#  '4FGL J1841.3+2909',
#  '4FGL J1842.1+2737',
#  '4FGL J1844.4+1547',
#  '4FGL J1845.0+1613',
#  '4FGL J1846.3+0919',
#  '4FGL J1849.4+2745',
#  '4FGL J1850.5+2631',
#  '4FGL J1851.5+0718',
#  '4FGL J1855.2+0756',
#  '4FGL J1856.2+0749',
#  '4FGL J1856.5+1735',
#  '4FGL J1857.2+0941',
#  '4FGL J1858.5+0640',
#  '4FGL J1859.0+2329',
#  '4FGL J1859.8+1545',
#  '4FGL J1901.1+0730',
#  '4FGL J1902.5+0654',
#  '4FGL J1906.1+1651',
#  '4FGL J1906.2+0631',
#  '4FGL J1906.4+0723',
#  '4FGL J1906.9+0712',
#  '4FGL J1908.6+0915e',
#  '4FGL J1908.7+0812',
#  '4FGL J1908.9+2103',
#  '4FGL J1910.2+0904',
#  '4FGL J1910.8+2856',
#  '4FGL J1911.0+0905',
#  '4FGL J1911.7+1014',
#  '4FGL J1912.0+1612',
#  '4FGL J1912.5+1320',
#  '4FGL J1912.7+0957',
#  '4FGL J1913.3+0905',
#  '4FGL J1913.3+1019',
#  '4FGL J1914.5+1107',
#  '4FGL J1914.7+1012',
#  '4FGL J1915.3+1149',
#  '4FGL J1916.3+1108',
#  '4FGL J1918.1+1215',
#  '4FGL J1919.1+2354',
#  '4FGL J1919.4+1313',
#  '4FGL J1920.7+1334',
#  '4FGL J1920.9+1408',
#  '4FGL J1921.1+1930',
#  '4FGL J1922.2+2314',
#  '4FGL J1922.4+1453',
#  '4FGL J1922.7+1428',
#  '4FGL J1923.2+1408e',
#  '4FGL J1924.3+1601',
#  '4FGL J1925.0+2815',
#  '4FGL J1925.1+1707',
#  '4FGL J1925.2+1729',
#  '4FGL J1925.3+1522',
#  '4FGL J1925.4+1616',
#  '4FGL J1925.7+1227',
#  '4FGL J1926.4+1602',
#  '4FGL J1926.7+3027',
#  '4FGL J1928.8+3126',
#  '4FGL J1929.0+1729',
#  '4FGL J1929.8+1832',
#  '4FGL J1930.3+0911',
#  '4FGL J1931.1+0937',
#  '4FGL J1931.1+1656',
#  '4FGL J1932.2+2221',
#  '4FGL J1932.3+1916',
#  '4FGL J1933.3+0726',
#  '4FGL J1934.2+1036',
#  '4FGL J1934.3+1859',
#  '4FGL J1935.2+2029',
#  '4FGL J1936.6+1921',
#  '4FGL J1939.6+2135',
#  '4FGL J1942.7+1033',
#  '4FGL J1943.9+2841',
#  '4FGL J1944.0+2117',
#  '4FGL J1946.0+0937',
#  '4FGL J1946.1+2436',
#  '4FGL J1947.1+1729',
#  '4FGL J1947.7+2744',
#  '4FGL J1948.3+1207',
#  '4FGL J1949.0+1314',
#  '4FGL J1949.4+1247',
#  '4FGL J1949.5+0906',
#  '4FGL J1950.6+2416',
#  '4FGL J1950.8+1211',
#  '4FGL J1951.0+2523',
#  '4FGL J1951.6+2621',
#  '4FGL J1952.8+2924',
#  '4FGL J1953.6+1846',
#  '4FGL J1954.3+2836',
#  '4FGL J1954.5+2420',
#  '4FGL J1954.8+2543',
#  '4FGL J1955.2+1358',
#  '4FGL J1957.6+1230',
#  '4FGL J1958.1+2438',
#  '4FGL J1958.7+2846',
#  '4FGL J1959.5+2048',
#  '4FGL J1959.9+1833',
#  '4FGL J2004.1+2517',
#  '4FGL J2006.2+3102',
#  '4FGL J2007.9+2511',
#  '4FGL J2008.4+1619',
#  '4FGL J2010.0+0726',
#  '4FGL J2014.5+0648',
#  '4FGL J2015.0+1621',
#  '4FGL J2017.4+0602',
#  '4FGL J2019.6+0616',
#  '4FGL J2027.0+2811',
#  'galdiff',
#  'isodiff']

# %% [markdown]
# Let's take a look at the flux, spectral parameters, and TS of one of the sources.

# %%
gta.print_roi()
# Out:
# 2022-06-10 11:42:45 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449   3543.84     29508.8
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482     15.39      2479.5
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794    512.98     14960.2
# 3HWC J1928+178PSR   PointSource    PLSuperExpCuto    1.286      0.00         0.0
# 3HWC J1928+178i     RadialGaussian LogParabola       1.286    683.23     25094.1
# 3HWC J1928+178s     RadialGaussian PowerLaw          1.286      1.38        53.4
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399     63.03      2146.9
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527    260.15      9355.0
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846    464.24     14300.6
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991     82.35      4362.5
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000    720.14     16097.2
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289     44.13      4107.0
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386     72.62      4308.4
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977    374.24     12934.9
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097    499.70     16312.2
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314     77.08      5736.2
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343    281.55      7042.0
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431     28.01      1171.6
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820    267.60     10033.6
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855    259.05       161.9
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094     16.70       694.4
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535    191.95      8715.2
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760    116.29      2190.4
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882    571.80     19543.7
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143  26880.50     93829.8
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274    138.18      6977.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364    623.09     19104.9
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366     67.33      1596.5
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591    161.21      2895.0
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675    107.57      1700.9
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909      4.55       458.3
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260    112.15       287.4
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347    563.44     17220.2
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603    273.24      7711.0
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663     66.94      1304.1
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869     20.42       963.4
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979   1174.08      4702.6
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023      6.57      1029.0
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137    376.73     12367.5
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154    284.26      4202.7
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359    268.65      7695.3
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589     22.48       987.1
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649    291.11      2813.5
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698     69.63      1420.5
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949    112.38      3072.6
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011     61.97       926.1
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061    327.08      9066.3
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069     28.86      1791.6
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272    199.41      1595.4
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283     13.26      1730.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381      0.18       232.6
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489    122.27      1298.0
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567    159.16      6426.2
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716     69.46       990.1
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738     11.16      1206.7
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769      6.66      1568.9
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809    101.21      2312.7
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856     85.08      3545.8
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075     76.30       973.0
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298     -0.00         0.0
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313     15.15      2584.0
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418     -0.00         0.0
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574     -0.00         0.0
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590     -0.00         0.0
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606     -0.00         0.0
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748      5.05      1631.3
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870      7.42      2035.3
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961     19.82       458.7
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012     -0.00         0.0
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014     43.22      5169.2
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189     -0.00         0.0
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599      0.20       168.9
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735      0.40       594.2
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808     -0.00         0.0
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818     -0.00         0.0
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971    291.87     15127.9
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002      2.36       711.9
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033     -0.00         0.0
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077     -0.00         0.0
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093     -0.00         0.0
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279     -0.00         0.1
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518     -0.00         0.0
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536      3.58      1348.2
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561     -0.00         0.0
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582     -0.00         0.1
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686     -0.00         0.1
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006      0.41       204.6
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020      6.56      2146.3
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328     18.96      2442.1
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504     -0.00         0.0
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975      0.00        22.1
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994     -0.00         0.0
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098     -0.00         0.0
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538     -0.00         0.1
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800     -0.00         0.0
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876     -0.00         0.0
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945      0.91       648.4
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006     -0.00         0.0
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166     10.01       991.6
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456      0.08       194.7
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488     -0.00         0.0
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590     -0.00         0.0
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904     -0.00         0.0
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071     -0.00         0.0
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228     -0.00         0.0
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809     -0.00         0.0
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109     -0.00         0.0
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146     -0.00         0.0
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337     -0.00         0.0
# isodiff             ConstantValue  FileFunction      -----   6136.10    230273.3
# galdiff             MapCubeFunctio PowerLaw          -----1924666.68   4385463.9

# %% [markdown]
# You can also plot the spectral energy distribution (SED) for this source :

# %% [markdown]
# # 3HWC J1928+178PSR

# %%
loge_bins=gta.log_energies[::2]

# %%
E178PSR = np.array(c['sources']['3HWC J1928+178PSR']['model_flux']['energies'])
dnde178PSR = np.array(c['sources']['3HWC J1928+178PSR']['model_flux']['dnde'])
dnde_hi178PSR = np.array(c['sources']['3HWC J1928+178PSR']['model_flux']['dnde_hi'])
dnde_lo178PSR = np.array(c['sources']['3HWC J1928+178PSR']['model_flux']['dnde_lo'])
sed178PSR = gta.sed('3HWC J1928+178PSR',loge_bins=loge_bins)
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['dnde'], 
             yerr=sed178PSR['dnde_err'], fmt ='o')
plt.loglog(E178PSR, dnde178PSR, 'k--')
plt.loglog(E178PSR, dnde_hi178PSR, 'k')
plt.loglog(E178PSR, dnde_lo178PSR, 'k')
plt.xlabel('E [MeV]')
plt.ylabel(r'dN/dE [MeV$^{-1}$ cm$^{-2}$ s$^{-1}$]')
plt.title('3HWC J1928+178PSR, E=0.1-1000GeV')
plt.show()
#plt.savefig("crab_2019/spectrum.png")
# Out:
# 2022-06-10 11:45:44 INFO    GTAnalysis.sed(): Computing SED for 3HWC J1928+178PSR
# 2022-06-10 11:46:08 INFO    GTAnalysis._make_sed(): Fitting SED
# 2022-06-10 11:46:08 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178PSR     : ['Index1', 'Cutoff']
# 2022-06-10 11:46:08 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178i       : ['alpha', 'beta']
# 2022-06-10 11:46:08 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178s       : ['Index']
# 2022-06-10 11:46:25 INFO    GTAnalysis.sed(): Finished SED
# 2022-06-10 11:46:32 INFO    GTAnalysis.sed(): Execution time: 48.10 s

# %%
plt.loglog(E178PSR, (E178PSR**2)*dnde178PSR, 'k--')
plt.loglog(E178PSR, (E178PSR**2)*dnde_hi178PSR, 'k')
plt.loglog(E178PSR, (E178PSR**2)*dnde_lo178PSR, 'k')
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['e2dnde'], 
             yerr=sed178PSR['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178PSR, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')

plt.show()

# %%
plt.loglog(E178PSR, (E178PSR**2)*dnde178PSR, 'k--')
plt.loglog(E178PSR, (E178PSR**2)*dnde_hi178PSR, 'k')
plt.loglog(E178PSR, (E178PSR**2)*dnde_lo178PSR, 'k')
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['e2dnde'], 
             yerr=sed178PSR['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178PSR, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.ylim(2E-40,2E-20)
plt.show()

# %% [markdown]
# # 3HWC J1928+178i

# %%
E178i = np.array(c['sources']['3HWC J1928+178i']['model_flux']['energies'])
dnde178i = np.array(c['sources']['3HWC J1928+178i']['model_flux']['dnde'])
dnde_hi178i = np.array(c['sources']['3HWC J1928+178i']['model_flux']['dnde_hi'])
dnde_lo178i = np.array(c['sources']['3HWC J1928+178i']['model_flux']['dnde_lo'])
sed178i = gta.sed('3HWC J1928+178i',loge_bins=loge_bins)
plt.errorbar(sed178i['e_ctr'],
             sed178i['dnde'], 
             yerr=sed178i['dnde_err'], fmt ='o')
plt.loglog(E178i, dnde178i, 'k--')
plt.loglog(E178i, dnde_hi178i, 'k')
plt.loglog(E178i, dnde_lo178i, 'k')
plt.xlabel('E [MeV]')
plt.ylabel(r'dN/dE [MeV$^{-1}$ cm$^{-2}$ s$^{-1}$]')
plt.title('3HWC J1928+178i, E=0.1-1000GeV')
plt.show()
#plt.savefig("crab_2019/spectrum.png")
# Out:
# 2022-06-10 11:48:24 INFO    GTAnalysis.sed(): Computing SED for 3HWC J1928+178i
# 2022-06-10 11:52:53 INFO    GTAnalysis._make_sed(): Fitting SED
# 2022-06-10 11:52:53 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178PSR     : ['Index1', 'Cutoff']
# 2022-06-10 11:52:53 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178i       : ['alpha', 'beta']
# 2022-06-10 11:52:53 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178s       : ['Index']
# 2022-06-10 11:53:12 INFO    GTAnalysis.sed(): Finished SED
# 2022-06-10 11:53:21 INFO    GTAnalysis.sed(): Execution time: 296.94 s

# %%
plt.loglog(E178i, (E178i**2)*dnde178i, 'k--')
plt.loglog(E178i, (E178i**2)*dnde_hi178i, 'k')
plt.loglog(E178i, (E178i**2)*dnde_lo178i, 'k')
plt.errorbar(sed178i['e_ctr'],
             sed178i['e2dnde'], 
             yerr=sed178i['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178i, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')

plt.show()

# %%
plt.loglog(E178i, (E178i**2)*dnde178i, 'k--')
plt.loglog(E178i, (E178i**2)*dnde_hi178i, 'k')
plt.loglog(E178i, (E178i**2)*dnde_lo178i, 'k')
plt.errorbar(sed178i['e_ctr'],
             sed178i['e2dnde'], 
             yerr=sed178i['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178i, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.ylim(1.5E-6,1.4E-5)
plt.show()

# %% [markdown]
# # 3HWC J1928+178s

# %%
E178s = np.array(c['sources']['3HWC J1928+178s']['model_flux']['energies'])
dnde178s = np.array(c['sources']['3HWC J1928+178s']['model_flux']['dnde'])
dnde_hi178s = np.array(c['sources']['3HWC J1928+178s']['model_flux']['dnde_hi'])
dnde_lo178s = np.array(c['sources']['3HWC J1928+178s']['model_flux']['dnde_lo'])
sed178s = gta.sed('3HWC J1928+178s',loge_bins=loge_bins)
plt.errorbar(sed178s['e_ctr'],
             sed178s['dnde'], 
             yerr=sed178s['dnde_err'], fmt ='o')
plt.loglog(E178s, dnde178s, 'k--')
plt.loglog(E178s, dnde_hi178s, 'k')
plt.loglog(E178s, dnde_lo178s, 'k')
plt.xlabel('E [MeV]')
plt.ylabel(r'dN/dE [MeV$^{-1}$ cm$^{-2}$ s$^{-1}$]')
plt.title('3HWC J1928+178s, E=0.1-1000GeV')
plt.show()
#plt.savefig("crab_2019/spectrum.png")
# Out:
# 2022-06-10 11:53:24 INFO    GTAnalysis.sed(): Computing SED for 3HWC J1928+178s
# 2022-06-10 11:57:41 INFO    GTAnalysis._make_sed(): Fitting SED
# 2022-06-10 11:57:41 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178PSR     : ['Index1', 'Cutoff']
# 2022-06-10 11:57:41 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178i       : ['alpha', 'beta']
# 2022-06-10 11:57:41 INFO    GTAnalysis.free_source(): Fixing parameters for 3HWC J1928+178s       : ['Index']
# 2022-06-10 11:57:58 INFO    GTAnalysis.sed(): Finished SED
# 2022-06-10 11:58:06 INFO    GTAnalysis.sed(): Execution time: 282.13 s

# %%
plt.loglog(E178s, (E178s**2)*dnde178s, 'k--')
plt.loglog(E178s, (E178s**2)*dnde_hi178s, 'k')
plt.loglog(E178s, (E178s**2)*dnde_lo178s, 'k')
plt.errorbar(sed178s['e_ctr'],
             sed178s['e2dnde'], 
             yerr=sed178s['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178s, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')

plt.show()

# %%
plt.loglog(E178s, (E178s**2)*dnde178s, 'k--')
plt.loglog(E178s, (E178s**2)*dnde_hi178s, 'k')
plt.loglog(E178s, (E178s**2)*dnde_lo178s, 'k')
plt.errorbar(sed178s['e_ctr'],
             sed178s['e2dnde'], 
             yerr=sed178s['e2dnde_err'], fmt ='o')
#plt.errorbar(np.array(sed['e_ctr'][-3:]),
#         sed['e2dnde_ul95'][-3:], yerr=0.2*sed['e2dnde_ul95'][-3:], 
#             fmt='o', uplims=True)
plt.title('3HWC J1928+178s, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')

plt.show()

# %% [markdown]
# # 3HWC J1928+178

# %%
plt.loglog(E178PSR, (E178PSR**2)*dnde178PSR, 'k--')
plt.loglog(E178PSR, (E178PSR**2)*dnde_hi178PSR, 'k')
plt.loglog(E178PSR, (E178PSR**2)*dnde_lo178PSR, 'k')
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['e2dnde'], 
             yerr=sed178PSR['e2dnde_err'], fmt ='ko')

plt.loglog(E178i, (E178i**2)*dnde178i, 'b--')
plt.loglog(E178i, (E178i**2)*dnde_hi178i, 'b')
plt.loglog(E178i, (E178i**2)*dnde_lo178i, 'b')
plt.errorbar(sed178i['e_ctr'],
             sed178i['e2dnde'], 
             yerr=sed178i['e2dnde_err'], fmt ='bo')

plt.loglog(E178s, (E178s**2)*dnde178s, 'r--')
plt.loglog(E178s, (E178s**2)*dnde_hi178s, 'r')
plt.loglog(E178s, (E178s**2)*dnde_lo178s, 'r')
plt.errorbar(sed178s['e_ctr'],
             sed178s['e2dnde'], 
             yerr=sed178s['e2dnde_err'], fmt ='ro')

plt.title('3HWC J1928+178, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')

plt.show()

# %%
plt.loglog(E178PSR, (E178PSR**2)*dnde178PSR, 'k--',label='PSR')
plt.loglog(E178PSR, (E178PSR**2)*dnde_hi178PSR, 'k')
plt.loglog(E178PSR, (E178PSR**2)*dnde_lo178PSR, 'k')
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['e2dnde'], 
             yerr=sed178PSR['e2dnde_err'], fmt ='ko')

plt.loglog(E178i, (E178i**2)*dnde178i, 'b--',label='IC')
plt.loglog(E178i, (E178i**2)*dnde_hi178i, 'b')
plt.loglog(E178i, (E178i**2)*dnde_lo178i, 'b')
plt.errorbar(sed178i['e_ctr'],
             sed178i['e2dnde'], 
             yerr=sed178i['e2dnde_err'], fmt ='bo')

plt.loglog(E178s, (E178s**2)*dnde178s, 'r--',label='Sync')
plt.loglog(E178s, (E178s**2)*dnde_hi178s, 'r')
plt.loglog(E178s, (E178s**2)*dnde_lo178s, 'r')
plt.errorbar(sed178s['e_ctr'],
             sed178s['e2dnde'], 
             yerr=sed178s['e2dnde_err'], fmt ='ro')
plt.legend()
plt.title('3HWC J1928+178, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.ylim(2e-15,2e-5)
plt.show()

# %%
plt.loglog(E178PSR, (E178PSR**2)*dnde178PSR, 'k--',label='PSR')
plt.loglog(E178PSR, (E178PSR**2)*dnde_hi178PSR, 'k')
plt.loglog(E178PSR, (E178PSR**2)*dnde_lo178PSR, 'k')
plt.errorbar(sed178PSR['e_ctr'],
             sed178PSR['e2dnde'], 
             yerr=sed178PSR['e2dnde_err'], fmt ='ko')

plt.loglog(E178i, (E178i**2)*dnde178i, 'b--',label='IC')
plt.loglog(E178i, (E178i**2)*dnde_hi178i, 'b')
plt.loglog(E178i, (E178i**2)*dnde_lo178i, 'b')
plt.errorbar(sed178i['e_ctr'],
             sed178i['e2dnde'], 
             yerr=sed178i['e2dnde_err'], fmt ='bo')

plt.loglog(E178s, (E178s**2)*dnde178s, 'r--',label='Sync')
plt.loglog(E178s, (E178s**2)*dnde_hi178s, 'r')
plt.loglog(E178s, (E178s**2)*dnde_lo178s, 'r')
plt.errorbar(sed178s['e_ctr'],
             sed178s['e2dnde'], 
             yerr=sed178s['e2dnde_err'], fmt ='ro')
plt.legend()
plt.title('3HWC J1928+178, E=0.1-1000GeV')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.ylim(2e-10,2e-5)
plt.show()
