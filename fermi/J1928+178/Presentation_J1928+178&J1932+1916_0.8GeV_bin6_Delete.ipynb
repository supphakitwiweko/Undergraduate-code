# %% [markdown]
# # Likelihood Analysis of the Crab with fermipy

# %% [markdown]
# Instructions on installing fermipy and the Fermi ScienceTools : [fermipy Installation Instructions](http://fermipy.readthedocs.org/en/latest/install.html).
#
# Documentation for fermipy : [fermipy](http://fermipy.readthedocs.org)
#
# Credit : notebook adapted from [Likelihood Analysis of a bright point source with fermipy](https://nbviewer.org/github/me-manu/fermipy-extra/blob/master/notebooks/pg1553.ipynb)

# %% [markdown]
# ## Get the Data

# %% [markdown]
# The data were extracted from the [LAT data server](http://fermi.gsfc.nasa.gov/cgi-bin/ssc/LAT/LATDataQuery.cgi) with the following selections :

# %% [markdown]
# ### Make a file list
#
# First you need to make a file containing the list of all your input event files.

# %% [markdown]
# Read one file as a table

# %% [markdown]
# ## Make a config file
#
#
# Make a config file named 'config.yaml' ([yaml](http://yaml.org) format). For more details on the config file see [config.html](http://fermipy.readthedocs.org/en/latest/config.html).

# %%
cat config_0.8GeV/config_J1928_bin_6
# Out:
# data:
#   evfile : data_0.8GeV/photon_files.txt # list of photon files
#   scfile : data_0.8GeV/L220601025103F357373F41_SC00.fits # spacecraft file
#
# binning:
#   roiwidth   : 15.0
#   binsz      : 0.02
#   binsperdec : 6
#
# selection :
#   emin : 800 # minimum energy
#   emax : 1000000 # maximum energy
#   zmax    : 90 # zenith angle cut
#   evclass : 128 # event class : simple point source analysis for pass 8
#   evtype  : 3 # event type (front 1 + back events 2 = 3)
#   tmin : 239557417  # starting time
#   tmax : 673405656  # ending time
#   filter : DATA_QUAL>0 && LAT_CONFIG==1 # Recommendation for Galactic Point Source Analysis
#   ra : 292.747
#   dec : 18.944
#
# gtlike:
#   edisp : -2 # Enable energy dispersion
#   irfs : 'P8R3_SOURCE_V3'
#   edisp_disable : ['isodiff'] # Never enable energy dispersion for the isodiff or galdiff models
#
# model:
#   src_roiwidth : 25.0 # Includes sources outside of the ROI
#   galdiff  : 'gll_iem_v07.fits' # The most recent and up to date model of the galactic diffuse emission
#   isodiff  : 'iso_P8R3_SOURCE_V3_v1.txt' # The most recent and up to date model for the isotropic diffuse emission, and for our event class
#   catalogs : ['4FGL'] # The 4FGL catalogue, 8 year Fermi-LAT point source catalogue.

# %% [markdown]
# ## Start the analysis
#
# Next, you create an analysis script and run the setup steps (which include running the selections and generating exposure maps for example). This will take some time to run.
#
# Fermipy will load the point source model, create an xml file for you which contains the models for all your sources in the region of interest (ROI).  All of this is configurable from python or from the config file.

# %% [markdown]
# ### Load up some useful modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from astropy.table import Table
from astropy.io import fits
from astropy.wcs import WCS

# %% [markdown]
# Let's ignore some deprecation warnings

# %%
import warnings
from matplotlib import MatplotlibDeprecationWarning
warnings.filterwarnings("ignore", category=MatplotlibDeprecationWarning)

# %% [markdown]
# ### Import the GTAnalysis module from fermipy
#
# You start by importing the module and then creating an instance of the analysis object from our config file.  When instantiating the analysis object we can override any options defined in the configuration file by passing keyword arguments to the object constructor.
# The verbosity parameter is set to 3 (INFO) which supresses DEBUG output.

# %%
from fermipy.gtanalysis import GTAnalysis
gta = GTAnalysis('config_0.8GeV/config_J1928_bin_6',logging={'verbosity': 3},fileio={'outdir': 'J1928+178_0.8GeV_15_bin6'})
matplotlib.interactive(True)
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]
# 2022-06-23 00:31:26 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version v1.0.1
# ScienceTools version 2.0.8

# %% [markdown]
# ### The setup routine
#
# This gets everything ready for the likelihood analysis.  Note that fermipy will skip generating any files that already exist in the working directory.

# %%
gta.setup()
# Out:
# 2022-06-23 00:31:27 INFO    GTAnalysis.setup(): Running setup.
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis.setup(): Running setup for component 00
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/fermipy/irfs.py:51: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   log_ratio = np.log(x[xs1] / x[xs0])
# /home/user/miniconda3/envs/fermi/lib/python3.7/site-packages/fermipy/irfs.py:52: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return 0.5 * (y[ys0] * x[xs0] + y[ys1] * x[xs1]) * log_ratio
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis.setup(): Finished setup for component 00
# 2022-06-23 00:31:27 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 00.
# Drm_Cache::update Measured counts < 0 4FGL J1842.1+2737 18 -9.97271e-16 6.72081e-16
# 0.237043 0.122075 0.0490104 0.0164648 0.00502323 0.00128401 0.00033268 9.26321e-05 2.2026e-05 4.61737e-06 8.04955e-07 1.08309e-07 1.09792e-08 8.8115e-10 5.67537e-11 3.38639e-12 1.84762e-13 1.03699e-14 6.72081e-16
# 2022-06-23 00:33:19 INFO    GTAnalysis.setup(): Initializing source properties
# 2022-06-23 00:33:24 INFO    GTAnalysis.setup(): Finished setup.

# %%
h = fits.open('J1928+178_0.8GeV_15_bin6/ccube_00.fits')
filtered = fits.open('J1928+178_0.8GeV_15_bin6/ft1_00.fits')
t_filtered = Table(filtered[1].data)
catalog = fits.open('gll_psc_v22.fit')

# %% [markdown]
# Let's have a look at the components of the model :

# %%
 gta.print_model()
# Out:
# 2022-06-23 00:33:27 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916      0.449   2.791  1.85e-05   3.72       nan      6281.7
# 4FGL J1929.8+1832      0.482   1.614  4.18e-06   2.42       nan       900.4
# 4FGL J1934.3+1859      0.794   2.658  3.19e-06   4.26       nan      1348.5
# 4FGL J1928.4+1801c     1.104   0.954  3.79e-06   2.46       nan       852.8
#  J1928+178_0.8GeV_15_bin6/mcube_J1928+178_freeloc_00.fits
#  J1928+178_0.8GeV_15_bin6/mcube_J1928+178_freeloc.fits
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Coponents_2_NBL_00.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Coponents_2_NBL.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Model_00.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Model.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Reference_00.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Reference.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Test_00.fits'
# 'J1928+178_0.8GeV_15_bin6/mcube_J1928+178&J1932+1916_0.8GeV_Test.fits'
#  J1928+178_0.8GeV_15_bin6/srcmap_00.fits

# %% [markdown]
# Here is a brief explanation of the contents of each file and its role in the analysis:
#
# * **ft1_00.fits**: Event list.  This is generated by running gtselect and gtmktime on our input file list.
# * **bexpmap_00.fits**: All-sky binned exposure map.  This map is interpolated to create an exposure model when generating the srcmap file.
# * **bexpmap_roi_00.fits**: Binned exposure map for the ROI.  This file is only provided for visualization purposes in order to have an exposure map with the same binning as the data and model maps.
# * **ccube_00.fits**: Counts cube for the ROI.
# * **ltcube_00.fits**: Livetime cube.  This contains a map of the livetime for this observation over the whole sky as a function of incidence angle.
# * **srcmap_00.fits**: Source map cube.  This file contains maps for each of the components in the ROI after convolution with exposure and the PSF.  Note that energy dispersion is applied at run-time.
#
# Note that all of the files have a numerical suffix '00'.  This is the analysis component index.  In a multi-component analysis there would be instances of all of the above files for each analysis component.  The files with no component index are co-added maps that are provided for visualization purposes.
#
# To see example of one of these files we can open and plot the counts cube file.  This is a 3D cube that contains the distribution of events as a function of energy and two spatial coordinates.  In the example below we sum over the energy dimension of the cube to make a 2-D sky image.

# %%
#h = fits.open('J1928+178_15_bin3/ccube_00.fits')
h.info()

wcs = WCS(h[0].header).dropaxis(-1)  # load the coordinate system, drop the energy axis

counts = h[0].data

plt.subplot(projection=wcs)
im = plt.imshow(np.sum(counts,axis=0),vmax= 20,interpolation='nearest',origin='lower', cmap='plasma')

plt.grid()
plt.gca().tick_params(direction='out')
plt.gca().set_xlabel("R.A. (deg)")
plt.gca().set_ylabel("Dec. (deg)")
plt.colorbar(im, label="counts")
plt.show()
#plt.savefig("Crab_5_bin_6/ccube_00.png")
# Out:
# Filename: J1928+178_0.8GeV_15_bin6/ccube_00.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     138   (750, 750, 19)   int32
#   1  EBOUNDS       1 BinTableHDU     43   19R x 3C   [I, 1E, 1E]
#   2  GTI           1 BinTableHDU     50   76600R x 2C   [D, D]

# %%
#filtered = fits.open('J1928+178_15_bin3/ft1_00.fits')
#t_filtered = Table(filtered[1].data)

# %%
x=t_filtered['RA']
y=t_filtered['DEC']
z=t_filtered['ENERGY']

# %%
print('x_min',np.min(x))
print('x_max',np.max(x))
# Out:
# x_min 280.9983
# x_max 304.49734

# %%
bin = 300
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower', vmax=50, cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(304.47318, 281.0085)
#ax.set_ylim(0.3-1.5, 0.3+1.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Count maps of 13 years of Fermi LAT data',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Count maps of 13 years of Fermi LAT data')

# %%
bin = 300
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=10, cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

#ax.set_xlabel("Galactic Longitude (deg)",fontsize=40)
#ax.set_ylabel("Galactic Latitude (deg)",fontsize=40)
ax.set_xlim(304.47318, 281.0085)
#ax.set_ylim(0.3-1.5, 0.3+1.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Count maps of 13 years of Fermi LAT data',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Count maps of 13 years of Fermi LAT data')

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(292.747+7.5, 292.747-7.5)
ax.set_ylim(18.944-7.5, 18.944+7.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Count maps of 13 years of Fermi LAT data',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Count maps of 13 years of Fermi LAT data')

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))

count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=10,  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
#ax.scatter((new_t['GLON'] +180)%360 - 180, new_t['GLAT'],edgecolor = 'white' , s=700,facecolor='none')
#for i, txt in enumerate(new_t['Source_Name']):           
#    ax.annotate(txt, (new_t['GLON'][i]+0.35, new_t['GLAT'][i]+0.05),fontsize=30,color='white')

ax.set_xlabel("RA (deg)",fontsize=40)
ax.set_ylabel("DEC (deg)",fontsize=40)
ax.set_xlim(292.747+7.5, 292.747-7.5)
ax.set_ylim(18.944-7.5, 18.944+7.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 

ax.set_title('Filtered data (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Filtered data (J1928+178)')

# %% [raw]
# 292.747,
# 18.944,
# 11.10660172

# %%
catalog = fits.open("gll_psc_v22.fit")
t = Table(catalog[1].data)
new_glon = np.logical_and(t['RAJ2000'] >=292.747-2.5, t['RAJ2000']<=292.747+2.5)
new_tg = t[new_glon]
new_glat = np.logical_and(new_tg['DEJ2000'] >= 18.944-2.5, new_tg['DEJ2000'] <=18.944+2.5)
sources = new_tg[new_glat]

# %%
 gta.print_model()
# Out:
# 2022-06-23 00:33:31 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916      0.449   2.791  1.85e-05   3.72       nan      6281.7
# 4FGL J1929.8+1832      0.482   1.614  4.18e-06   2.42       nan       900.4
# 4FGL J1934.3+1859      0.794   2.658  3.19e-06   4.26       nan      1348.5
# 4FGL J1928.4+1801c     1.104   0.954  3.79e-06   2.46       nan       852.8
# 4FGL J1936.6+1921      1.399   0.324  2.06e-06   2.74       nan       584.6
# 4FGL J1929.0+1729      1.527   1.526  6.92e-06   3.17       nan      2349.5
# 4FGL J1929.0+1729  292.2559 17.4903 52.716537 ...                nan                nan             nan     0
# 4FGL J1929.8+1832  292.4541 18.5499  53.73694 ...  292.5504150390625 18.533750534057617         0.00045   264
# 4FGL J1931.1+1656  292.7847  16.944  52.47954 ...                nan                nan             nan     4
# 4FGL J1932.3+1916  293.0761 19.2685  54.64999 ... 293.08221435546875  19.27790069580078   0.00040159625     0
# 4FGL J1934.3+1859  293.5848 18.9979 54.645687 ...  293.3333435058594 18.933332443237305         0.00045    16
# 4FGL J1935.2+2029  293.8179 20.4908  56.05722 ... 293.92498779296875  20.42799949645996    0.0004194245     4
# 4FGL J1936.6+1921  294.1625 19.3538  55.22214 ...                nan                nan             nan    24

# %%
print(gta.roi['4FGL J1921.1+1930'])
# Out:
# Name           : 4FGL J1921.1+1930
# Associations   : ['4FGL J1921.1+1930']
# RA/DEC         :    290.293/    19.512
# GLON/GLAT      :     53.615/     2.509
# TS             : nan
# Npred          : 497.80
# Flux           : 8.992e-10 +/-      nan
# EnergyFlux     : 2.034e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  2.998e-13 +/-        nan
# b'Index'       :     -2.527 +/-        nan
# b'Scale'       :       1595 +/-        nan

# %%
print(gta.roi['4FGL J1925.1+1707'])
# Out:
# Name           : 4FGL J1925.1+1707
# Associations   : ['4FGL J1925.1+1707', 'MG2 J192501+1727']
# RA/DEC         :    291.289/    17.122
# GLON/GLAT      :     51.954/     0.548
# TS             : nan
# Npred          : 732.46
# Flux           :  1.34e-09 +/-      nan
# EnergyFlux     : 3.233e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :    5.1e-14 +/-        nan
# b'Index'       :      -2.47 +/-        nan
# b'Scale'       :       3843 +/-        nan

# %%
print(gta.roi['4FGL J1925.2+1729'])
# Out:
# Name           : 4FGL J1925.2+1729
# Associations   : ['4FGL J1925.2+1729', 'PSR J1925+1720', '3EG J1928+1733']
# RA/DEC         :    291.322/    17.485
# GLON/GLAT      :     52.287/     0.692
# TS             : nan
# Npred          : 1370.02
# Flux           : 2.539e-09 +/-      nan
# EnergyFlux     :  3.97e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.976e-11 +/-        nan
# b'Index1'      :   -0.08822 +/-        nan
# b'Scale'       :       1981 +/-        nan
# b'Expfactor'   :    0.02449 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1928.4+1801c'])
# Out:
# Name           : 4FGL J1928.4+1801c
# Associations   : ['4FGL J1928.4+1801c', 'MG2 J192830+1759', '3EG J1928+1733']
# RA/DEC         :    292.112/    18.019
# GLON/GLAT      :     53.115/     0.285
# TS             : nan
# Npred          : 852.82
# Flux           : 1.553e-09 +/-      nan
# EnergyFlux     : 3.794e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  9.542e-14 +/-        nan
# b'Index'       :      -2.46 +/-        nan
# b'Scale'       :       3175 +/-        nan

# %%
print(gta.roi['4FGL J1929.0+1729'])
# Out:
# Name           : 4FGL J1929.0+1729
# Associations   : ['4FGL J1929.0+1729', '3EG J1928+1733']
# RA/DEC         :    292.256/    17.490
# GLON/GLAT      :     52.717/    -0.088
# TS             : nan
# Npred          : 2349.50
# Flux           : 4.362e-09 +/-      nan
# EnergyFlux     : 6.918e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  1.526e-12 +/-        nan
# b'alpha'       :      2.644 +/-        nan
# b'beta'        :     0.3992 +/-        nan
# b'Eb'          :       1634 +/-        nan

# %%
print(gta.roi['4FGL J1929.8+1832'])
# Out:
# Name           : 4FGL J1929.8+1832
# Associations   : ['4FGL J1929.8+1832', '1RXS J193012.1+183201']
# RA/DEC         :    292.454/    18.550
# GLON/GLAT      :     53.737/     0.254
# TS             : nan
# Npred          : 900.44
# Flux           :  1.63e-09 +/-      nan
# EnergyFlux     :  4.18e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  1.614e-13 +/-        nan
# b'Index'       :     -2.421 +/-        nan
# b'Scale'       :       2635 +/-        nan

# %%
print(gta.roi['4FGL J1931.1+1656'])
# Out:
# Name           : 4FGL J1931.1+1656
# Associations   : ['4FGL J1931.1+1656']
# RA/DEC         :    292.785/    16.944
# GLON/GLAT      :     52.480/    -0.794
# TS             : nan
# Npred          : 2551.34
# Flux           : 4.744e-09 +/-      nan
# EnergyFlux     : 7.512e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :   2.82e-12 +/-        nan
# b'alpha'       :      2.532 +/-        nan
# b'beta'        :     0.3525 +/-        nan
# b'Eb'          :       1324 +/-        nan

# %%
print(gta.roi['4FGL J1932.3+1916'])
# Out:
# Name           : 4FGL J1932.3+1916
# Associations   : ['4FGL J1932.3+1916', 'PSR J1932+1916']
# RA/DEC         :    293.076/    19.268
# GLON/GLAT      :     54.650/     0.084
# TS             : nan
# Npred          : 6281.67
# Flux           : 1.155e-08 +/-      nan
# EnergyFlux     :  1.85e-05 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.791e-11 +/-        nan
# b'Index1'      :     -1.252 +/-        nan
# b'Scale'       :       1538 +/-        nan
# b'Expfactor'   :    0.01314 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1934.3+1859'])
# Out:
# Name           : 4FGL J1934.3+1859
# Associations   : ['4FGL J1934.3+1859', 'SNR G054.4-00.3']
# RA/DEC         :    293.585/    18.998
# GLON/GLAT      :     54.646/    -0.468
# TS             : nan
# Npred          : 1348.52
# Flux           : 2.506e-09 +/-      nan
# EnergyFlux     : 3.194e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  2.658e-12 +/-        nan
# b'alpha'       :      3.137 +/-        nan
# b'beta'        :     0.5334 +/-        nan
# b'Eb'          :       1105 +/-        nan

# %%
print(gta.roi['4FGL J1935.2+2029'])
# Out:
# Name           : 4FGL J1935.2+2029
# Associations   : ['4FGL J1935.2+2029', 'PSR J1935+2025']
# RA/DEC         :    293.818/    20.491
# GLON/GLAT      :     56.057/     0.065
# TS             : nan
# Npred          : 2331.49
# Flux           : 4.283e-09 +/-      nan
# EnergyFlux     : 6.302e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  1.062e-11 +/-        nan
# b'Index1'      :     -1.903 +/-        nan
# b'Scale'       :       1190 +/-        nan
# b'Expfactor'   :    0.01018 +/-        nan
# b'Index2'      :     0.6667 +/-        nan

# %%
print(gta.roi['4FGL J1936.6+1921'])
# Out:
# Name           : 4FGL J1936.6+1921
# Associations   : ['4FGL J1936.6+1921']
# RA/DEC         :    294.163/    19.354
# GLON/GLAT      :     55.222/    -0.772
# TS             : nan
# Npred          : 584.60
# Flux           : 1.062e-09 +/-      nan
# EnergyFlux     : 2.065e-06 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  3.245e-13 +/-        nan
# b'alpha'       :      2.041 +/-        nan
# b'beta'        :     0.6762 +/-        nan
# b'Eb'          :       1884 +/-        nan

# %%
plt.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'black' , s=200 , facecolor='none')
for i, txt in enumerate(sources['Source_Name']):           
    plt.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]),fontsize=10,color='black')
#plt.ylim(22.0145-2.5,22.0145+2.5)
#plt.xlim(83.633-2.5,83.633+2.5)
plt.show()

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))
count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=10,  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])

for i, txt in enumerate(sources['Source_Name']):           
    ax.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]+0.2),fontsize=20,color='b')
ax.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'white' , s=400 , facecolor='none')
ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(292.747+7.5, 292.747-7.5)
ax.set_ylim(18.944-7.5, 18.944+7.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 
ax.set_title('Filtered data map (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Filtered data map (J1928+178)')

# %%
bin = 200
fig, ax = plt.subplots(figsize=(40,20))
count, xedges, yedges = np.histogram2d(x, y, bins = bin) 
count = ax.imshow(count.T, origin='lower',vmax=10,  cmap='inferno',extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])

for i, txt in enumerate(sources['Source_Name']):           
    ax.annotate(txt, (sources['RAJ2000'][i], sources['DEJ2000'][i]+0.1),fontsize=30,color='b')
ax.scatter(sources['RAJ2000'], sources['DEJ2000'],edgecolor = 'white' , s=400 , facecolor='none')
ax.set_xlabel("Ra (deg)",fontsize=40)
ax.set_ylabel("Dec (deg)",fontsize=40)
ax.set_xlim(292.747+2.5, 292.747-2.5)
ax.set_ylim(18.944-2.5, 18.944+2.5)
ax.grid(alpha=0.5)
ax.tick_params(axis="x", labelsize=40)
ax.tick_params(axis="y", labelsize=40)
#cbar = fig.colorbar(count,ax=ax,ticks=np.arange(0,200,10))
cbar = fig.colorbar(count,ax=ax)
cbar.set_label("Photon counts",fontsize=50) 
cbar.ax.tick_params(labelsize=40) 
ax.set_title('Zoom in filtered data map (J1928+178)',fontsize = 60)
# Out:
# Text(0.5, 1.0, 'Zoom in filtered data map (J1928+178)')

# %% [markdown]
# Next, we look at the sky map of the exposure

# %% [markdown]
# ... and the energy dependence of the exposure for the central pixel

# %% [markdown]
# We can now inspect the state of the ROI before the fit

# %%
gta.print_roi()
# Out:
# 2022-06-23 00:33:32 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449       nan      6281.7
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482       nan       900.4
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794       nan      1348.5
# 4FGL J1928.4+1801c  PointSource    PowerLaw          1.104       nan       852.8
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399       nan       584.6
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527       nan      2349.5
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846       nan      2331.5
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991       nan      1370.0
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000       nan      2551.3
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289       nan       732.5
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386       nan       497.8
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977       nan      1715.4
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097       nan      1812.7
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314       nan       782.7
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343       nan      1881.6
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431       nan       531.0
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820       nan      1384.6
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855       nan       160.9
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094       nan       178.1
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535       nan      1335.9
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760       nan       336.5
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882       nan      3045.3
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143       nan     25634.0
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274       nan       354.2
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364       nan      2416.0
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366       nan       344.4
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591       nan       431.8
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675       nan       483.3
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909       nan      1143.2
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260       nan       376.0
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347       nan      1391.2
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603       nan      1205.0
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663       nan       916.4
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869       nan       192.1
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979       nan      1639.3
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023       nan       778.1
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137       nan       902.1
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154       nan       456.6
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359       nan      1476.6
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589       nan       211.0
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649       nan       815.7
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698       nan       513.4
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949       nan       900.9
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011       nan       328.6
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061       nan      1765.6
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069       nan       139.2
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272       nan       518.3
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283       nan        29.2
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381       nan        18.2
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489       nan       467.9
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567       nan       439.4
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716       nan       177.3
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738       nan       588.3
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769       nan       339.1
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809       nan       544.0
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856       nan        99.1
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075       nan       148.3
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298       nan         3.8
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313       nan        25.4
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418       nan         6.5
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574       nan        59.4
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590       nan        26.3
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606       nan        35.0
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748       nan         7.9
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870       nan        69.3
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961       nan       237.3
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012       nan         4.7
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014       nan        84.7
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189       nan         4.3
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599       nan        29.2
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735       nan        26.7
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808       nan         1.5
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818       nan         3.8
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971       nan       119.6
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002       nan         1.2
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033       nan       104.4
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077       nan        18.1
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093       nan        19.0
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279       nan         1.3
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518       nan         1.0
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536       nan         3.2
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561       nan         0.6
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582       nan         5.5
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686       nan        76.9
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006       nan         0.8
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020       nan        12.2
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328       nan         4.7
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504       nan         0.2
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975       nan         1.2
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994       nan        11.4
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098       nan         8.9
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538       nan         2.1
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800       nan         2.2
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876       nan         1.6
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945       nan         2.1
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006       nan         0.6
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166       nan         0.4
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456       nan         3.1
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488       nan         0.6
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590       nan         0.4
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904       nan         0.1
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071       nan         0.5
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228       nan         0.1
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809       nan         0.3
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109       nan         0.1
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146       nan         0.4
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337       nan         0.0
# isodiff             ConstantValue  FileFunction      -----       nan     25956.1
# galdiff             MapCubeFunctio PowerLaw          -----       nan    980621.5

# %% [markdown]
# Additional details about an individual source can be retrieved by printing the corresponding source object

# %% [markdown]
# ## Do the likelihood fitting
#
# Now that all of the ancillary files have been generated, we can move on to the actual fitting.  The first thing you should do is free some of the sources since all of the sources are initially fixed.  We'll just free those sources in the center region.

# %%
gta.print_params()
# Out:
# 2022-06-23 00:33:33 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------

# %%
gta.delete_source('4FGL J1928.4+1801c')

#gta.add_source('3HWC J1928+178i',{ 'glon' : 52.93, 'glat' : 0.2,
#                'SpectrumType' : 'LogParabola', 'alpha' : 3.005,
#                'beta' : 0.2, 'norm' : 2.555e-14,'Eb' : 1e+04,
#                'SpatialModel': 'RadialGaussian', 'SpatialWidth': 0.87 })

#gta.add_source('3HWC J1928+178ic',{ 'glon' : 52.93, 'glat' : 0.2,
#                'SpectrumType' : 'LogParabola', 'alpha' : 0.494,
#                'beta' : 0.2, 'norm' : 2.833e-15,'Eb' : 1e+04,
#                'SpatialModel': 'RadialGaussian', 'SpatialWidth': 1.0})

#gta.add_source('4FGL J1932.3+1916i',{ 'glon' : 54.650, 'glat' : 0.084,
#                'SpectrumType' : 'LogParabola', 'alpha' : 0.975,
#                'beta' : 0.2, 'norm' : 0.00971e-12,'Eb' : 1e+04,
#                'SpatialModel': 'RadialGaussian', 'SpatialWidth': 0.12 })

gta.free_sources(free=False) # make sure everything is fixed first
gta.optimize()
# Out:
# 2022-06-23 00:33:33 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1928.4+1801c
# 2022-06-23 00:33:34 INFO    GTAnalysis.optimize(): Starting
# Joint fit  ['galdiff', 'isodiff', '4FGL J1923.2+1408e', '4FGL J1932.3+1916']
# Fitting shape galdiff TS: 1033149.592
# Fitting shape 4FGL J1923.2+1408e TS:  20098.373
# Fitting shape 4FGL J1932.3+1916 TS:   2447.619
# Fitting shape 4FGL J1959.5+2048 TS:    947.664
# Fitting shape 4FGL J1931.1+1656 TS:    576.259
# Fitting shape isodiff TS:    539.514
# Fitting shape 4FGL J1929.0+1729 TS:    514.702
# Fitting shape 4FGL J1915.3+1149 TS:    329.339
# Fitting shape 4FGL J1922.7+1428 TS:    320.078
# Fitting shape 4FGL J1925.4+1616 TS:    277.469
# Fitting shape 4FGL J1944.0+2117 TS:    269.427
# Fitting shape 4FGL J1920.9+1408 TS:    268.471
# Fitting shape 4FGL J1955.2+1358 TS:    226.057
# Fitting shape 4FGL J1926.4+1602 TS:    213.201
# Fitting shape 4FGL J1935.2+2029 TS:    189.607
# Fitting shape 4FGL J1939.6+2135 TS:    185.486
# Fitting shape 4FGL J1949.0+1314 TS:    174.646
# Fitting shape 4FGL J1950.8+1211 TS:    163.487
# Fitting shape 4FGL J1918.1+1215 TS:    159.596
# Fitting shape 4FGL J1919.4+1313 TS:    149.853
# Fitting shape 4FGL J1925.7+1227 TS:    139.014
# Fitting shape 4FGL J1908.9+2103 TS:    133.807
# Fitting shape 4FGL J1925.3+1522 TS:    132.551
# Fitting shape 4FGL J1925.2+1729 TS:    127.790
# Fitting shape 4FGL J1958.1+2438 TS:    125.813
# Fitting shape 4FGL J1934.3+1859 TS:    123.013
# Fitting shape 4FGL J1912.5+1320 TS:    117.806
# Fitting shape 4FGL J1906.1+1651 TS:    116.660
# Fitting shape 4FGL J1922.2+2314 TS:    107.220
# Fitting shape 4FGL J1919.1+2354 TS:     91.382
# Fitting shape 4FGL J1922.4+1453 TS:     81.937
# Fitting shape 4FGL J1957.6+1230 TS:     78.376
# Fitting shape 4FGL J1929.8+1832 TS:     71.278
# Fitting shape 4FGL J1924.3+1601 TS:     62.893
# Fitting shape 4FGL J1925.1+1707 TS:     61.592
# Fitting shape 4FGL J1859.0+2329 TS:     58.862
# Fitting shape 4FGL J1921.1+1930 TS:     55.929
# Fitting shape 4FGL J1916.3+1108 TS:     55.768
# Fitting shape 4FGL J1948.3+1207 TS:     52.351
# Fitting shape 4FGL J1950.6+2416 TS:     48.971
# Fitting shape 4FGL J1920.7+1334 TS:     48.041
# Fitting shape 4FGL J1951.6+2621 TS:     46.863
# Fitting shape 4FGL J1953.6+1846 TS:     45.667
# Fitting shape 4FGL J1951.0+2523 TS:     45.179
# Fitting shape 4FGL J1946.1+2436 TS:     43.270
# Fitting shape 4FGL J1954.5+2420 TS:     42.744
# Fitting shape 4FGL J1954.8+2543 TS:     38.206
# Fitting shape 4FGL J1936.6+1921 TS:     33.703
# Fitting shape 4FGL J1912.0+1612 TS:     32.470
# 2022-06-23 00:41:34 INFO    GTAnalysis.optimize(): Finished
# 2022-06-23 00:41:34 INFO    GTAnalysis.optimize(): LogLike: -1796957.161226 Delta-LogLike: 661.165788
# 2022-06-23 00:41:34 INFO    GTAnalysis.optimize(): Execution time: 479.47 s
# {'loglike0': -1797618.3270140328,
#  'loglike1': -1796957.1612264714,
#  'dloglike': 661.165787561331,
#  'config': {'npred_threshold': 1.0,
#   'npred_frac': 0.95,
#   'shape_ts_threshold': 25.0,
#   'max_free_sources': 5,
#   'skip': [],
#   'optimizer': {'optimizer': 'MINUIT',
#    'tol': 0.001,
#    'max_iter': 100,
#    'init_lambda': 0.0001,
#    'retries': 3,
#    'min_fit_quality': 2,
#    'verbosity': 0}}}

# %%
# Free Normalization of all Sources within 3 deg of ROI center
gta.free_sources(distance=3.0,pars='norm')
gta.free_sources(minmax_ts=[49,None],pars='norm')
# Free normalizations of isotropic and galactic diffuse components
gta.free_source('galdiff',pars='norm')
gta.free_source('isodiff')
# Out:
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1932.3+1916     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1929.8+1832     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1934.3+1859     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1936.6+1921     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1929.0+1729     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1935.2+2029     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.2+1729     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1931.1+1656     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.1+1707     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1921.1+1930     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.4+1616     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1926.4+1602     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1924.3+1601     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1939.6+2135     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.3+1522     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1944.0+2117     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.4+1453     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.2+2314     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1922.7+1428     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1923.2+1408e    : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1920.9+1408     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1908.9+2103     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1919.1+2354     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1920.7+1334     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.1+1651     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1919.4+1313     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1925.7+1227     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1946.1+2436     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1959.5+2048     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1950.6+2416     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.5+1320     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1949.0+1314     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1918.1+1215     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1955.2+1358     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1954.5+2420     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1951.0+2523     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1915.3+1149     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1950.8+1211     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1958.1+2438     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1916.3+1108     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1859.0+2329     : ['Prefactor']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1951.6+2621     : ['norm']
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1957.6+1230     : ['Prefactor']

# %%
gta.print_params()
# Out:
# 2022-06-23 00:41:34 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------
# 4FGL J1859.0+2329
#   46 Prefactor                0.578         0     1e-05     1e+03     1e-13    *
#   47 Index                     2.14         0         0         5        -1
#   48 Scale                 2.16e+03         0  2.16e+03  2.16e+03         1
# 4FGL J1906.1+1651
#   60 norm                     0.861         0     1e-05     1e+03     1e-13    *
#   61 alpha                     1.73         0        -5         5         1
#   62 beta                      1.09         0        -2         2         1
#   63 Eb                    3.18e+03         0  3.18e+03  3.18e+03         1
# 4FGL J1908.9+2103
#   84 Prefactor                0.841         0     1e-05     1e+03     1e-12    *
#   85 Index1                   0.994         0         0         5        -1
# 4FGL J1935.2+2029
#  251 Prefactor                0.784         0     1e-05     1e+03     1e-11    *
#  252 Index1                    1.85         0         0         5        -1
#  253 Scale                 1.19e+03         0  1.19e+03  1.19e+03         1
#  254 Expfactor                 1.02         0      -0.5      1.02      0.01
#  255 Index2                   0.667         0         0         2         1
# 4FGL J1936.6+1921
#  256 norm                     0.276         0     1e-05     1e+03     1e-12    *
#  257 alpha                     2.33         0        -5         5         1
#  258 beta                     0.705         0        -2         2         1
#  259 Eb                    1.88e+03         0  1.88e+03  1.88e+03         1
# 4FGL J1939.6+2135
#  260 Prefactor                0.327         0     1e-05     1e+03     1e-11    *
#  261 Index1                    1.35         0         0         5        -1
#  262 Scale                  1.8e+03         0   1.8e+03   1.8e+03         1
#  263 Expfactor                0.961         0      -0.5     0.961      0.01
#  264 Index2                   0.667         0         0         2         1
# 4FGL J1944.0+2117
#  271 norm                     0.447         0     1e-05     1e+03     1e-14    *
#  272 alpha                     1.25         0        -5         5         1
#  273 beta                     0.215         0        -2         2         1
#  274 Eb                    1.57e+04         0  1.57e+04  1.57e+04         1
# 4FGL J1946.1+2436
#  278 norm                     0.482         0     1e-05     1e+03     1e-12    *
#  279 alpha                     1.69         0        -5         5         1
#  280 beta                     0.553         0        -2         2         1
#  281 Eb                    1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1949.0+1314
#  293 Prefactor                0.424         0     1e-05     1e+03     1e-12    *
#  294 Index                     2.53         0         0         5        -1
#  295 Scale                 1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1950.6+2416
#  302 norm                      0.51         0     1e-05     1e+03     1e-12    *
#  303 alpha                     2.33         0        -5         5         1
#  304 beta                      0.55         0        -2         2         1
#  305 Eb                    1.54e+03         0  1.54e+03  1.54e+03         1
# 4FGL J1950.8+1211
#  306 norm                     0.915         0     1e-05     1e+03     1e-12    *
#  307 alpha                     2.22         0        -5         5         1
#  308 beta                     0.417         0        -2         2         1
#  309 Eb                    1.09e+03         0  1.09e+03  1.09e+03         1
# 4FGL J1951.0+2523
#  310 norm                      1.03         0     1e-05     1e+03     1e-12    *
#  311 alpha                     1.48         0        -5         5         1
#  312 beta                       1.4         0        -2         2         1
#  313 Eb                    1.19e+03         0  1.19e+03  1.19e+03         1
# 4FGL J1951.6+2621
#  314 norm                     0.666         0     1e-05     1e+03     1e-12    *
#  315 alpha                     3.18         0        -5         5         1
#  316 beta                    -0.162         0        -2         2         1
#  317 Eb                    1.47e+03         0  1.47e+03  1.47e+03         1
# 4FGL J1954.5+2420
#  331 norm                      2.48         0     1e-05     1e+03     1e-13    *
#  332 alpha                     1.92         0        -5         5         1
#  333 beta                     0.628         0        -2         2         1
#  334 Eb                    1.86e+03         0  1.86e+03  1.86e+03         1
# 4FGL J1955.2+1358
#  339 norm                       1.5         0     1e-05     1e+03     1e-12    *
#  340 alpha                     2.48         0        -5         5         1
#  341 beta                    0.0839         0        -2         2         1
#  342 Eb                         925         0       925       925         1
# 4FGL J1957.6+1230
#  343 Prefactor                 1.14         0     1e-05     1e+03     1e-13    *
#  344 Index                     2.41         0         0         5        -1
#  345 Scale                 1.85e+03         0  1.85e+03  1.85e+03         1
# 4FGL J1958.1+2438
#  346 Prefactor                 1.97         0     1e-05     1e+03     1e-14    *
#  347 Index                     2.01         0         0         5        -1
#  348 Scale                 5.33e+03         0  5.33e+03  5.33e+03         1
# 4FGL J1959.5+2048
#  354 Prefactor                 1.23         0     1e-05     1e+03     1e-11    *
#  355 Index1                   0.775         0         0         5        -1
#  356 Scale                 1.35e+03         0  1.35e+03  1.35e+03         1
#  357 Expfactor                 1.61         0      -0.5      1.61      0.01
#  358 Index2                   0.667         0         0         2         1
# galdiff
#  399 Prefactor                0.975         0       0.1        10         1    *
#  400 Index                   0.0165         0        -1         1        -1
#  401 Scale                    1e+03         0     1e+03     1e+03         1
# isodiff
#  402 Normalization            0.997         0     0.001     1e+03         1    *

# %%
#gta.free_source('3HWC J1928+178i',pars='norm')
#gta.free_source('3HWC J1928+178ic')
gta.free_source('4FGL J1932.3+1916')
#gta.free_source('4FGL J1932.3+1916i',pars='norm')
# Out:
# 2022-06-23 00:41:34 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1932.3+1916     : ['Index1', 'Expfactor']

# %%
#print(gta.roi['3HWC J1928+178i'])

# %%
print(gta.roi['4FGL J1932.3+1916'])
# Out:
# Name           : 4FGL J1932.3+1916
# Associations   : ['4FGL J1932.3+1916', 'PSR J1932+1916']
# RA/DEC         :    293.076/    19.268
# GLON/GLAT      :     54.650/     0.084
# TS             : 2513.29
# Npred          : 6116.28
# Flux           : 1.125e-08 +/- 3.33e-09
# EnergyFlux     : 1.787e-05 +/- 6.93e-06
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.712e-11 +/-  8.807e-12
# b'Index1'      :     -1.281 +/-     0.3262
# b'Scale'       :       1538 +/-        nan
# b'Expfactor'   :    0.01314 +/-  1.808e-05
# b'Index2'      :     0.6667 +/-        nan

# %%
#print(gta.roi['4FGL J1932.3+1916i'])

# %%
#ext = gta.extension('3HWC J1928+178i',update=True,make_plots=True,fit_ebin=True,fix_shape=True)

# %%
#ext['ext']

# %%
#ext0 = gta.extension('3HWC J1928+178ic',update=True,make_plots=True,fit_ebin=True,fix_shape=True)

# %%
#ext0['ext']

# %%
#ext1 = gta.extension('4FGL J1932.3+1916i',update=True,make_plots=True,fit_ebin=True,fix_shape=True)

# %%
#ext1['ext']

# %%
#print(gta.roi['3HWC J1928+178i'])

# %%
#print(gta.roi['3HWC J1928+178ic'])

# %%
print(gta.roi['4FGL J1932.3+1916'])
# Out:
# Name           : 4FGL J1932.3+1916
# Associations   : ['4FGL J1932.3+1916', 'PSR J1932+1916']
# RA/DEC         :    293.076/    19.268
# GLON/GLAT      :     54.650/     0.084
# TS             : 2513.29
# Npred          : 6116.28
# Flux           : 1.125e-08 +/- 3.33e-09
# EnergyFlux     : 1.787e-05 +/- 6.93e-06
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.712e-11 +/-  8.807e-12
# b'Index1'      :     -1.281 +/-     0.3262
# b'Scale'       :       1538 +/-        nan
# b'Expfactor'   :    0.01314 +/-  1.808e-05
# b'Index2'      :     0.6667 +/-        nan

# %%
#print(gta.roi['4FGL J1932.3+1916i'])

# %%
gta.print_params()
# Out:
# 2022-06-23 00:41:35 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------
# 4FGL J1859.0+2329
#   46 Prefactor                0.578         0     1e-05     1e+03     1e-13    *
#   47 Index                     2.14         0         0         5        -1
#   48 Scale                 2.16e+03         0  2.16e+03  2.16e+03         1
# 4FGL J1906.1+1651
#   60 norm                     0.861         0     1e-05     1e+03     1e-13    *
#   61 alpha                     1.73         0        -5         5         1
#   62 beta                      1.09         0        -2         2         1
#   63 Eb                    3.18e+03         0  3.18e+03  3.18e+03         1
# 4FGL J1908.9+2103
#   84 Prefactor                0.841         0     1e-05     1e+03     1e-12    *
#   85 Index1                   0.994         0         0         5        -1
#   86 Scale                 2.13e+03         0  2.13e+03  2.13e+03         1
#   87 Expfactor                0.901         0      -0.5     0.901      0.01
#   88 Index2                   0.667         0         0         2         1
# 4FGL J1912.5+1320
#  106 norm                     0.383         0     1e-05     1e+03     1e-11    *
#  107 alpha                     2.64         0        -5         5         1
#  108 beta                     0.368         0        -2         2         1
#  109 Eb                         886         0       886       886         1
# 4FGL J1915.3+1149
#  130 norm                      2.38         0     1e-05     1e+03     1e-12    *
#  131 alpha                     2.35         0        -5         5         1
#  132 beta                     0.445         0        -2         2         1
#  133 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1916.3+1108
#  134 norm                      2.93         0     1e-05     1e+03     1e-12    *
#  135 alpha                     1.87         0        -5         5         1
#  136 beta                    0.0161         0        -2         2         1
#  137 Eb                    2.02e+03         0  2.02e+03  2.02e+03         1
# 4FGL J1918.1+1215
#  138 norm                      2.99         0     1e-05     1e+03     1e-12    *
#  139 alpha                     2.61         0        -5         5         1
#  140 beta                     0.702         0        -2         2         1
#  141 Eb                    1.16e+03         0  1.16e+03  1.16e+03         1
# 4FGL J1919.1+2354
#  142 norm                     0.387         0     1e-05     1e+03     1e-12    *
#  143 alpha                     2.11         0        -5         5         1
#  144 beta                      1.04         0        -2         2         1
#  145 Eb                     1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1919.4+1313
#  146 norm                     0.811         0     1e-05     1e+03     1e-11    *
#  147 alpha                     3.77         0        -5         5         1
#  148 beta                    0.0967         0        -2         2         1
#  149 Eb                         902         0       902       902         1
# 4FGL J1920.7+1334
#  150 norm                     0.525         0     1e-05     1e+03     1e-12    *
#  151 alpha                     2.83         0        -5         5         1
#  152 beta                         2         0        -2         2         1
#  153 Eb                    2.01e+03         0  2.01e+03  2.01e+03         1
# 4FGL J1920.9+1408
#  154 norm                       1.3         0     1e-05     1e+03     1e-12    *
#  155 alpha                     2.83         0        -5         5         1
#  156 beta                     0.191         0        -2         2         1
#  157 Eb                    1.82e+03         0  1.82e+03  1.82e+03         1
# 4FGL J1921.1+1930
#  158 Prefactor                 3.26         0     1e-05     1e+03     1e-13    *
#  159 Index                     2.59         0         0         5        -1
#  160 Scale                  1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1922.2+2314
#  161 Prefactor                  2.9         0     1e-05     1e+03     1e-14    *
#  162 Index                     2.16         0         0         5        -1
#  163 Scale                 4.13e+03         0  4.13e+03  4.13e+03         1
# 4FGL J1922.4+1453
#  164 norm                     0.859         0     1e-05     1e+03     1e-12    *
#  165 alpha                     3.15         0        -5         5         1
#  166 beta                     0.445         0        -2         2         1
#  167 Eb                    1.68e+03         0  1.68e+03  1.68e+03         1
# 4FGL J1922.7+1428
#  168 norm                      1.61         0     1e-05     1e+03     1e-12    *
#  169 alpha                      2.8         0        -5         5         1
#  170 beta                     0.364         0        -2         2         1
#  171 Eb                    1.81e+03         0  1.81e+03  1.81e+03         1
# 4FGL J1923.2+1408e
#  172 norm                     0.603         0     1e-05     1e+03     1e-11    *
#  173 alpha                     2.19         0        -5         5         1
#  174 beta                     0.106         0        -2         2         1
#  175 Eb                    2.53e+03         0  2.53e+03  2.53e+03         1
# 4FGL J1924.3+1601
#  176 Prefactor                 1.03         0     1e-05     1e+03     1e-13    *
#  177 Index                     2.78         0         0         5        -1
#  178 Scale                 3.12e+03         0  3.12e+03  3.12e+03         1
# 4FGL J1925.1+1707
#  182 Prefactor                 0.52         0     1e-05     1e+03     1e-13    *
#  183 Index                     2.73         0         0         5        -1
#  184 Scale                 3.84e+03         0  3.84e+03  3.84e+03         1
# 4FGL J1925.2+1729
#  185 Prefactor                 2.72         0     1e-05     1e+03     1e-11    *
#  186 Index1                   0.517         0         0         5        -1
#  187 Scale                 1.98e+03         0  1.98e+03  1.98e+03         1
#  188 Expfactor                 2.45         0      -0.5      2.45      0.01
#  189 Index2                   0.667         0         0         2         1
# 4FGL J1925.3+1522
#  190 norm                      1.35         0     1e-05     1e+03     1e-12    *
#  191 alpha                     2.73         0        -5         5         1
#  192 beta                      0.53         0        -2         2         1
#  193 Eb                     1.5e+03         0   1.5e+03   1.5e+03         1
# 4FGL J1925.4+1616
#  194 Prefactor                  1.2         0     1e-05     1e+03     1e-13    *
#  195 Index                     2.45         0         0         5        -1
#  196 Scale                 4.07e+03         0  4.07e+03  4.07e+03         1
# 4FGL J1925.7+1227
#  197 norm                     0.521         0     1e-05     1e+03     1e-12    *
#  198 alpha                     2.59         0        -5         5         1
#  199 beta                    0.0841         0        -2         2         1
#  200 Eb                    1.77e+03         0  1.77e+03  1.77e+03         1
# 4FGL J1926.4+1602
#  201 norm                     0.342         0     1e-05     1e+03     1e-12    *
#  202 alpha                     2.81         0        -5         5         1
#  203 beta                   -0.0545         0        -2         2         1
#  204 Eb                    2.43e+03         0  2.43e+03  2.43e+03         1
# 4FGL J1929.0+1729
#  212 norm                      2.05         0     1e-05     1e+03     1e-12    *
#  213 alpha                      2.9         0        -5         5         1
#  214 beta                     0.354         0        -2         2         1
#  215 Eb                    1.63e+03         0  1.63e+03  1.63e+03         1
# 4FGL J1929.8+1832
#  216 Prefactor                 1.55         0     1e-05     1e+03     1e-13    *
#  217 Index                     2.99         0         0         5        -1
#  218 Scale                 2.64e+03         0  2.64e+03  2.64e+03         1
# 4FGL J1931.1+1656
#  227 norm                      3.25         0     1e-05     1e+03     1e-12    *
#  228 alpha                      2.6         0        -5         5         1
#  229 beta                     0.335         0        -2         2         1
#  230 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1932.3+1916
#  236 Prefactor                 2.71         0     1e-05     1e+03     1e-11    *
#  237 Index1                    1.28         0         0         5        -1    *
#  238 Scale                 1.54e+03         0  1.54e+03  1.54e+03         1
#  239 Expfactor                 1.31         0      -0.5      1.31      0.01    *
#  240 Index2                   0.667         0         0         2         1
# 4FGL J1934.3+1859
#  247 norm                      2.65         0     1e-05     1e+03     1e-12    *
#  248 alpha                     3.63         0        -5         5         1
#  249 beta                    -0.104         0        -2         2         1
#  250 Eb                     1.1e+03         0   1.1e+03   1.1e+03         1
# 4FGL J1935.2+2029
#  251 Prefactor                0.784         0     1e-05     1e+03     1e-11    *
#  252 Index1                    1.85         0         0         5        -1
#  253 Scale                 1.19e+03         0  1.19e+03  1.19e+03         1
#  254 Expfactor                 1.02         0      -0.5      1.02      0.01
#  255 Index2                   0.667         0         0         2         1
# 4FGL J1936.6+1921
#  256 norm                     0.276         0     1e-05     1e+03     1e-12    *
#  257 alpha                     2.33         0        -5         5         1
#  258 beta                     0.705         0        -2         2         1
#  259 Eb                    1.88e+03         0  1.88e+03  1.88e+03         1
# 4FGL J1939.6+2135
#  260 Prefactor                0.327         0     1e-05     1e+03     1e-11    *
#  261 Index1                    1.35         0         0         5        -1
#  262 Scale                  1.8e+03         0   1.8e+03   1.8e+03         1
#  263 Expfactor                0.961         0      -0.5     0.961      0.01
#  264 Index2                   0.667         0         0         2         1
# 4FGL J1944.0+2117
#  271 norm                     0.447         0     1e-05     1e+03     1e-14    *
#  272 alpha                     1.25         0        -5         5         1
#  273 beta                     0.215         0        -2         2         1
#  274 Eb                    1.57e+04         0  1.57e+04  1.57e+04         1
# 4FGL J1946.1+2436
#  278 norm                     0.482         0     1e-05     1e+03     1e-12    *
#  279 alpha                     1.69         0        -5         5         1
#  280 beta                     0.553         0        -2         2         1
#  281 Eb                    1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1949.0+1314
#  293 Prefactor                0.424         0     1e-05     1e+03     1e-12    *
#  294 Index                     2.53         0         0         5        -1
#  295 Scale                 1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1950.6+2416
#  302 norm                      0.51         0     1e-05     1e+03     1e-12    *
#  303 alpha                     2.33         0        -5         5         1
#  304 beta                      0.55         0        -2         2         1
#  305 Eb                    1.54e+03         0  1.54e+03  1.54e+03         1
# 4FGL J1950.8+1211
#  306 norm                     0.915         0     1e-05     1e+03     1e-12    *
#  307 alpha                     2.22         0        -5         5         1
#  308 beta                     0.417         0        -2         2         1
#  309 Eb                    1.09e+03         0  1.09e+03  1.09e+03         1
# 4FGL J1951.0+2523
#  310 norm                      1.03         0     1e-05     1e+03     1e-12    *
#  311 alpha                     1.48         0        -5         5         1
#  312 beta                       1.4         0        -2         2         1
#  313 Eb                    1.19e+03         0  1.19e+03  1.19e+03         1
# 4FGL J1951.6+2621
#  314 norm                     0.666         0     1e-05     1e+03     1e-12    *
#  315 alpha                     3.18         0        -5         5         1
#  316 beta                    -0.162         0        -2         2         1
#  317 Eb                    1.47e+03         0  1.47e+03  1.47e+03         1
# 4FGL J1954.5+2420
#  331 norm                      2.48         0     1e-05     1e+03     1e-13    *
#  332 alpha                     1.92         0        -5         5         1
#  333 beta                     0.628         0        -2         2         1
#  334 Eb                    1.86e+03         0  1.86e+03  1.86e+03         1
# 4FGL J1955.2+1358
#  339 norm                       1.5         0     1e-05     1e+03     1e-12    *
#  340 alpha                     2.48         0        -5         5         1
#  341 beta                    0.0839         0        -2         2         1
#  342 Eb                         925         0       925       925         1
# 4FGL J1957.6+1230
#  343 Prefactor                 1.14         0     1e-05     1e+03     1e-13    *
#  344 Index                     2.41         0         0         5        -1
#  345 Scale                 1.85e+03         0  1.85e+03  1.85e+03         1
# 4FGL J1958.1+2438
#  346 Prefactor                 1.97         0     1e-05     1e+03     1e-14    *
#  347 Index                     2.01         0         0         5        -1
#  348 Scale                 5.33e+03         0  5.33e+03  5.33e+03         1
# 4FGL J1959.5+2048
#  354 Prefactor                 1.23         0     1e-05     1e+03     1e-11    *
#  355 Index1                   0.775         0         0         5        -1
#  356 Scale                 1.35e+03         0  1.35e+03  1.35e+03         1
#  357 Expfactor                 1.61         0      -0.5      1.61      0.01
#  358 Index2                   0.667         0         0         2         1
# galdiff
#  399 Prefactor                0.975         0       0.1        10         1    *
#  400 Index                   0.0165         0        -1         1        -1
#  401 Scale                    1e+03         0     1e+03     1e+03         1
# isodiff
#  402 Normalization            0.997         0     0.001     1e+03         1    *

# %% [markdown]
# In this simple anlaysis we are leaving the spectral shapes of sources fixed but we're going to free the spectral shape of the source we care about.

# %% [markdown]
# Now, actually do the fit.  The software does its best to get the fit to converge by running the fit several times.

# %%
fit_results = gta.fit()
# Out:
# 2022-06-23 00:41:35 INFO    GTAnalysis.fit(): Starting fit.
# 2022-06-23 00:57:12 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   2 Status: 102
# 2022-06-23 00:57:12 INFO    GTAnalysis.fit(): LogLike: -1796954.387 DeltaLogLike:        2.774

# %% [markdown]
# The dictionary returned by the fit method returns a variety of diagnostic information about the fit including the fit quality, the relative improvement in the likelihood, and the correlations among the fit parameters. For example :

# %%
print('Fit Quality: ',fit_results['fit_quality'])
# Out:
# Fit Quality:  2

# %%
#print(gta.roi['3HWC J1928+178i'])

# %%
#print(gta.roi['3HWC J1928+178ic'])

# %%
print(gta.roi['4FGL J1932.3+1916'])
# Out:
# Name           : 4FGL J1932.3+1916
# Associations   : ['4FGL J1932.3+1916', 'PSR J1932+1916']
# RA/DEC         :    293.076/    19.268
# GLON/GLAT      :     54.650/     0.084
# TS             : 2441.77
# Npred          : 6018.79
# Flux           : 1.106e-08 +/- 3.45e-09
# EnergyFlux     : 1.773e-05 +/- 6.71e-06
# SpatialModel   : PointSource
# SpectrumType   : PLSuperExpCutoff2
# Spectral Parameters
# b'Prefactor'   :  2.675e-11 +/-  8.896e-12
# b'Index1'      :     -1.251 +/-     0.2335
# b'Scale'       :       1538 +/-        nan
# b'Expfactor'   :    0.01314 +/-   1.26e-06
# b'Index2'      :     0.6667 +/-        nan

# %%
#print(gta.roi['4FGL J1932.3+1916i'])

# %% [markdown]
# Let's have a look at the sources and the best-fit parameters after the fit

# %%
gta.print_roi()
# Out:
# 2022-06-23 00:57:12 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449   2441.77      6018.8
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482     93.88      1254.5
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794    118.49      1431.9
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399     39.75       533.4
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527    500.88      3267.4
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846    198.74      1746.4
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991    104.85      1363.3
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000    508.01      2878.9
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289     70.87      1025.9
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386     59.48       549.3
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977    273.61      1905.4
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097    177.08      1850.4
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314     72.96      1156.9
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343    199.41      1521.8
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431     22.93       317.8
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820    119.89      1559.0
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855    285.80       160.9
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094     23.04       151.3
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535     99.90      1638.7
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760    112.42       396.6
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882    252.21      3088.1
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143  19766.39     25368.7
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274     35.01       407.2
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364    273.61      2862.5
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366     44.81       274.8
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591    137.44       484.5
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675     89.00       473.9
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909     50.98       880.7
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260    121.49       280.9
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347    159.44      1958.2
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603    136.60      1003.7
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663     55.88       562.8
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869     20.80       152.7
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979    948.26      1514.9
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023     57.45       656.0
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137    108.34      1097.5
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154    186.00       515.0
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359    128.95      1571.8
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589     18.60       126.4
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649    214.40       566.4
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698     51.24       439.8
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949     56.54       649.8
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011     44.90       270.4
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061    188.90      1662.9
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069      6.79        72.0
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272    160.68       478.9
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283      0.00         4.4
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381      0.19        41.5
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489    133.74       384.8
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567     99.32      1539.7
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716     60.08       145.8
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738     46.63       566.2
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769      4.94       342.6
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809     63.48       542.4
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856     21.54       399.7
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075     75.83       235.4
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298     21.47       423.8
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313      3.16       284.0
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418      6.68       334.2
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574      0.00         7.6
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590     -0.00         0.0
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606     -0.00         0.0
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748      0.69       136.4
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870     -0.00         0.1
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961     12.75       157.7
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012     -0.00         0.0
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014     -0.00         0.1
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189     -0.00         0.0
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599      0.62        92.4
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735      1.23       331.9
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808      0.09        36.9
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818      0.43        74.7
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971      8.97       784.3
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002      2.98       202.2
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033     -0.00         0.0
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077     -0.00         0.0
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093      0.00        12.9
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279     -0.00         0.0
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518     -0.00         0.0
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536      0.91       190.2
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561       nan         0.6
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582     -0.00         0.0
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686     -0.00         0.0
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006       nan         0.8
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020      0.80       218.5
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328      0.02        11.9
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504       nan         0.2
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975      0.53        54.1
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994      0.18       103.2
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098      0.01        26.4
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538     -0.00         0.0
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800     -0.00         0.0
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876     -0.00         0.0
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945     -0.00         0.0
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006       nan         0.6
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166       nan         0.4
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456      0.13        66.4
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488       nan         0.6
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590       nan         0.4
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904       nan         0.1
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071       nan         0.5
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228       nan         0.1
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809       nan         0.3
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109       nan         0.1
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146       nan         0.4
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337       nan         0.0
# isodiff             ConstantValue  FileFunction      -----    626.06     26805.2
# galdiff             MapCubeFunctio PowerLaw          ----- 880541.60    946663.0

# %%
gta.print_params()
# Out:
# 2022-06-23 00:57:13 INFO    GTAnalysis.print_params():
#  idx parname                  value     error       min       max     scale free
# --------------------------------------------------------------------------------
# 4FGL J1859.0+2329
#   46 Prefactor                0.575    0.0985     1e-05     1e+03     1e-13    *
#   47 Index                     2.14         0         0         5        -1
#   48 Scale                 2.16e+03         0  2.16e+03  2.16e+03         1
# 4FGL J1906.1+1651
#   60 norm                      0.86     0.109     1e-05     1e+03     1e-13    *
#   61 alpha                     1.73         0        -5         5         1
#   62 beta                      1.09         0        -2         2         1
#   63 Eb                    3.18e+03         0  3.18e+03  3.18e+03         1
# 4FGL J1908.9+2103
#   84 Prefactor                 0.84    0.0867     1e-05     1e+03     1e-12    *
#   85 Index1                   0.994         0         0         5        -1
#   86 Scale                 2.13e+03         0  2.13e+03  2.13e+03         1
#   87 Expfactor                0.901         0      -0.5     0.901      0.01
#   88 Index2                   0.667         0         0         2         1
# 4FGL J1912.5+1320
#  106 norm                     0.387    0.0337     1e-05     1e+03     1e-11    *
#  107 alpha                     2.64         0        -5         5         1
#  108 beta                     0.368         0        -2         2         1
#  109 Eb                         886         0       886       886         1
# 4FGL J1915.3+1149
#  130 norm                      2.28     0.161     1e-05     1e+03     1e-12    *
#  131 alpha                     2.35         0        -5         5         1
#  132 beta                     0.445         0        -2         2         1
#  133 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1916.3+1108
#  134 norm                      3.08     0.294     1e-05     1e+03     1e-12    *
#  135 alpha                     1.87         0        -5         5         1
#  136 beta                    0.0161         0        -2         2         1
#  137 Eb                    2.02e+03         0  2.02e+03  2.02e+03         1
# 4FGL J1918.1+1215
#  138 norm                      2.97     0.237     1e-05     1e+03     1e-12    *
#  139 alpha                     2.61         0        -5         5         1
#  140 beta                     0.702         0        -2         2         1
#  141 Eb                    1.16e+03         0  1.16e+03  1.16e+03         1
# 4FGL J1919.1+2354
#  142 norm                     0.387    0.0426     1e-05     1e+03     1e-12    *
#  143 alpha                     2.11         0        -5         5         1
#  144 beta                      1.04         0        -2         2         1
#  145 Eb                     1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1919.4+1313
#  146 norm                     0.831    0.0623     1e-05     1e+03     1e-11    *
#  147 alpha                     3.77         0        -5         5         1
#  148 beta                    0.0967         0        -2         2         1
#  149 Eb                         902         0       902       902         1
# 4FGL J1920.7+1334
#  150 norm                     0.529    0.0703     1e-05     1e+03     1e-12    *
#  151 alpha                     2.83         0        -5         5         1
#  152 beta                         2         0        -2         2         1
#  153 Eb                    2.01e+03         0  2.01e+03  2.01e+03         1
# 4FGL J1920.9+1408
#  154 norm                       1.3    0.0762     1e-05     1e+03     1e-12    *
#  155 alpha                     2.83         0        -5         5         1
#  156 beta                     0.191         0        -2         2         1
#  157 Eb                    1.82e+03         0  1.82e+03  1.82e+03         1
# 4FGL J1921.1+1930
#  158 Prefactor                  3.3     0.404     1e-05     1e+03     1e-13    *
#  159 Index                     2.59         0         0         5        -1
#  160 Scale                  1.6e+03         0   1.6e+03   1.6e+03         1
# 4FGL J1922.2+2314
#  161 Prefactor                 2.93     0.317     1e-05     1e+03     1e-14    *
#  162 Index                     2.16         0         0         5        -1
#  163 Scale                 4.13e+03         0  4.13e+03  4.13e+03         1
# 4FGL J1922.4+1453
#  164 norm                     0.905    0.0874     1e-05     1e+03     1e-12    *
#  165 alpha                     3.15         0        -5         5         1
#  166 beta                     0.445         0        -2         2         1
#  167 Eb                    1.68e+03         0  1.68e+03  1.68e+03         1
# 4FGL J1922.7+1428
#  168 norm                       1.5    0.0993     1e-05     1e+03     1e-12    *
#  169 alpha                      2.8         0        -5         5         1
#  170 beta                     0.364         0        -2         2         1
#  171 Eb                    1.81e+03         0  1.81e+03  1.81e+03         1
# 4FGL J1923.2+1408e
#  172 norm                     0.607   0.00559     1e-05     1e+03     1e-11    *
#  173 alpha                     2.19         0        -5         5         1
#  174 beta                     0.106         0        -2         2         1
#  175 Eb                    2.53e+03         0  2.53e+03  2.53e+03         1
# 4FGL J1924.3+1601
#  176 Prefactor                 1.08     0.125     1e-05     1e+03     1e-13    *
#  177 Index                     2.78         0         0         5        -1
#  178 Scale                 3.12e+03         0  3.12e+03  3.12e+03         1
# 4FGL J1925.1+1707
#  182 Prefactor                0.562     0.067     1e-05     1e+03     1e-13    *
#  183 Index                     2.73         0         0         5        -1
#  184 Scale                 3.84e+03         0  3.84e+03  3.84e+03         1
# 4FGL J1925.2+1729
#  185 Prefactor                 2.53     0.241     1e-05     1e+03     1e-11    *
#  186 Index1                   0.517         0         0         5        -1
#  187 Scale                 1.98e+03         0  1.98e+03  1.98e+03         1
#  188 Expfactor                 2.45         0      -0.5      2.45      0.01
#  189 Index2                   0.667         0         0         2         1
# 4FGL J1925.3+1522
#  190 norm                       1.3      0.11     1e-05     1e+03     1e-12    *
#  191 alpha                     2.73         0        -5         5         1
#  192 beta                      0.53         0        -2         2         1
#  193 Eb                     1.5e+03         0   1.5e+03   1.5e+03         1
# 4FGL J1925.4+1616
#  194 Prefactor                 1.18    0.0803     1e-05     1e+03     1e-13    *
#  195 Index                     2.45         0         0         5        -1
#  196 Scale                 4.07e+03         0  4.07e+03  4.07e+03         1
# 4FGL J1925.7+1227
#  197 norm                     0.524    0.0438     1e-05     1e+03     1e-12    *
#  198 alpha                     2.59         0        -5         5         1
#  199 beta                    0.0841         0        -2         2         1
#  200 Eb                    1.77e+03         0  1.77e+03  1.77e+03         1
# 4FGL J1926.4+1602
#  201 norm                     0.329    0.0258     1e-05     1e+03     1e-12    *
#  202 alpha                     2.81         0        -5         5         1
#  203 beta                   -0.0545         0        -2         2         1
#  204 Eb                    2.43e+03         0  2.43e+03  2.43e+03         1
# 4FGL J1929.0+1729
#  212 norm                         2    0.0855     1e-05     1e+03     1e-12    *
#  213 alpha                      2.9         0        -5         5         1
#  214 beta                     0.354         0        -2         2         1
#  215 Eb                    1.63e+03         0  1.63e+03  1.63e+03         1
# 4FGL J1929.8+1832
#  216 Prefactor                  1.6     0.151     1e-05     1e+03     1e-13    *
#  217 Index                     2.99         0         0         5        -1
#  218 Scale                 2.64e+03         0  2.64e+03  2.64e+03         1
# 4FGL J1931.1+1656
#  227 norm                      3.18     0.136     1e-05     1e+03     1e-12    *
#  228 alpha                      2.6         0        -5         5         1
#  229 beta                     0.335         0        -2         2         1
#  230 Eb                    1.32e+03         0  1.32e+03  1.32e+03         1
# 4FGL J1932.3+1916
#  236 Prefactor                 2.67      0.89     1e-05     1e+03     1e-11    *
#  237 Index1                    1.25     0.234         0         5        -1    *
#  238 Scale                 1.54e+03         0  1.54e+03  1.54e+03         1
#  239 Expfactor                 1.31  0.000126      -0.5      1.31      0.01    *
#  240 Index2                   0.667         0         0         2         1
# 4FGL J1934.3+1859
#  247 norm                       2.6     0.238     1e-05     1e+03     1e-12    *
#  248 alpha                     3.63         0        -5         5         1
#  249 beta                    -0.104         0        -2         2         1
#  250 Eb                     1.1e+03         0   1.1e+03   1.1e+03         1
# 4FGL J1935.2+2029
#  251 Prefactor                0.791    0.0521     1e-05     1e+03     1e-11    *
#  252 Index1                    1.85         0         0         5        -1
#  253 Scale                 1.19e+03         0  1.19e+03  1.19e+03         1
#  254 Expfactor                 1.02         0      -0.5      1.02      0.01
#  255 Index2                   0.667         0         0         2         1
# 4FGL J1936.6+1921
#  256 norm                     0.286     0.042     1e-05     1e+03     1e-12    *
#  257 alpha                     2.33         0        -5         5         1
#  258 beta                     0.705         0        -2         2         1
#  259 Eb                    1.88e+03         0  1.88e+03  1.88e+03         1
# 4FGL J1939.6+2135
#  260 Prefactor                0.331    0.0227     1e-05     1e+03     1e-11    *
#  261 Index1                    1.35         0         0         5        -1
#  262 Scale                  1.8e+03         0   1.8e+03   1.8e+03         1
#  263 Expfactor                0.961         0      -0.5     0.961      0.01
#  264 Index2                   0.667         0         0         2         1
# 4FGL J1944.0+2117
#  271 norm                     0.447    0.0435     1e-05     1e+03     1e-14    *
#  272 alpha                     1.25         0        -5         5         1
#  273 beta                     0.215         0        -2         2         1
#  274 Eb                    1.57e+04         0  1.57e+04  1.57e+04         1
# 4FGL J1946.1+2436
#  278 norm                     0.489    0.0621     1e-05     1e+03     1e-12    *
#  279 alpha                     1.69         0        -5         5         1
#  280 beta                     0.553         0        -2         2         1
#  281 Eb                    1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1949.0+1314
#  293 Prefactor                0.428    0.0401     1e-05     1e+03     1e-12    *
#  294 Index                     2.53         0         0         5        -1
#  295 Scale                 1.44e+03         0  1.44e+03  1.44e+03         1
# 4FGL J1950.6+2416
#  302 norm                     0.523    0.0633     1e-05     1e+03     1e-12    *
#  303 alpha                     2.33         0        -5         5         1
#  304 beta                      0.55         0        -2         2         1
#  305 Eb                    1.54e+03         0  1.54e+03  1.54e+03         1
# 4FGL J1950.8+1211
#  306 norm                     0.927    0.0877     1e-05     1e+03     1e-12    *
#  307 alpha                     2.22         0        -5         5         1
#  308 beta                     0.417         0        -2         2         1
#  309 Eb                    1.09e+03         0  1.09e+03  1.09e+03         1
# 4FGL J1951.0+2523
#  310 norm                      1.05     0.127     1e-05     1e+03     1e-12    *
#  311 alpha                     1.48         0        -5         5         1
#  312 beta                       1.4         0        -2         2         1
#  313 Eb                    1.19e+03         0  1.19e+03  1.19e+03         1
# 4FGL J1951.6+2621
#  314 norm                     0.677     0.082     1e-05     1e+03     1e-12    *
#  315 alpha                     3.18         0        -5         5         1
#  316 beta                    -0.162         0        -2         2         1
#  317 Eb                    1.47e+03         0  1.47e+03  1.47e+03         1
# 4FGL J1954.5+2420
#  331 norm                       2.5      0.33     1e-05     1e+03     1e-13    *
#  332 alpha                     1.92         0        -5         5         1
#  333 beta                     0.628         0        -2         2         1
#  334 Eb                    1.86e+03         0  1.86e+03  1.86e+03         1
# 4FGL J1955.2+1358
#  339 norm                      1.49      0.11     1e-05     1e+03     1e-12    *
#  340 alpha                     2.48         0        -5         5         1
#  341 beta                    0.0839         0        -2         2         1
#  342 Eb                         925         0       925       925         1
# 4FGL J1957.6+1230
#  343 Prefactor                 1.13     0.143     1e-05     1e+03     1e-13    *
#  344 Index                     2.41         0         0         5        -1
#  345 Scale                 1.85e+03         0  1.85e+03  1.85e+03         1
# 4FGL J1958.1+2438
#  346 Prefactor                 1.98     0.215     1e-05     1e+03     1e-14    *
#  347 Index                     2.01         0         0         5        -1
#  348 Scale                 5.33e+03         0  5.33e+03  5.33e+03         1
# 4FGL J1959.5+2048
#  354 Prefactor                 1.23    0.0463     1e-05     1e+03     1e-11    *
#  355 Index1                   0.775         0         0         5        -1
#  356 Scale                 1.35e+03         0  1.35e+03  1.35e+03         1
#  357 Expfactor                 1.61         0      -0.5      1.61      0.01
#  358 Index2                   0.667         0         0         2         1
# galdiff
#  399 Prefactor                0.973   0.00119       0.1        10         1    *
#  400 Index                   0.0165         0        -1         1        -1
#  401 Scale                    1e+03         0     1e+03     1e+03         1
# isodiff
#  402 Normalization             1.03    0.0312     0.001     1e+03         1    *

# %% [markdown]
# You can then save the state of the roi to an output file for reference later.

# %%
#gta.write_roi('fit0',make_plots=True)
gta.write_roi('J1928+178&J1932+1916_0.8GeV_Delete',make_plots=True)
# Out:
# 2022-06-23 00:57:13 INFO    GTBinnedAnalysis.write_xml(): Writing /home/user/fermi/J1928+178/J1928+178_0.8GeV_15_bin6/J1928+178&J1932+1916_0.8GeV_Delete_00.xml...
# 2022-06-23 00:57:13 INFO    GTAnalysis.write_fits(): Writing /home/user/fermi/J1928+178/J1928+178_0.8GeV_15_bin6/J1928+178&J1932+1916_0.8GeV_Delete.fits...
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %f cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# 2022-06-23 00:57:27 INFO    GTAnalysis.write_roi(): Writing /home/user/fermi/J1928+178/J1928+178_0.8GeV_15_bin6/J1928+178&J1932+1916_0.8GeV_Delete.npy...

# %% [markdown]
# We can also inspect the final model map. The next command will return the model map as a `gammapy.Map` instance (Full documentation for `gammapy`  [here](https://docs.gammapy.org)).

# %%
model_map = gta.write_model_map("J1928+178&J1932+1916_0.8GeV_Delete")
# Out:
# 2022-06-23 00:58:06 INFO    GTBinnedAnalysis.write_model_map(): Generating model map for component 00.

# %%
print(model_map)
# Out:
# [WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat', 'energy']
# 	shape : (750, 750, 19)
# 	ndim  : 3
# 	unit  :
# 	dtype : float32
# , WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat', 'energy']
# 	shape : (750, 750, 19)
# 	ndim  : 3
# 	unit  :
# 	dtype : float64
# ]

# %%
#model_map[0].geom.axes[0]

# %% [markdown]
# Plot the model map summed over the energy axis. The plot shows the predicted number of counts for all model components.

# %%
model_map[0].sum_over_axes(["energy"]).plot(stretch="sqrt",cmap='plasma', add_cbar=True)
#plt.savefig("J1928+178_15_bin3/model.png")
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <WCSAxesSubplot:xlabel='Right Ascension', ylabel='Declination'>,
#  <matplotlib.colorbar.Colorbar at 0x7fe6850c35d0>)

# %% [markdown]
# Plot each energy bin of the model map. This nicely illustrates the broad PSF at low energies.

# %%
model_map_bins = model_map[0].plot_grid(stretch="sqrt",cmap='plasma', add_cbar=True)
#plt.savefig("J1928+178_15_bin6/model_bins.png")

# %%
#residmap = gta.residmap("Reference", make_plots=True)

# %% [markdown]
# ### Reading in the results
#
# The results are saved and you can retrieve them from the output numpy file.

# %%
ls J1928+178_20GeV_15_bin6/*npy
# Out:
#  J1928+178_20GeV_15_bin6/3hwc_j1928+178ic_ext.npy
#  J1928+178_20GeV_15_bin6/3hwc_j1928+178ic_sed.npy
#  J1928+178_20GeV_15_bin6/3hwc_j1928+178i_ext.npy
#  J1928+178_20GeV_15_bin6/3hwc_j1928+178i_loc.npy
#  J1928+178_20GeV_15_bin6/3hwc_j1928+178i_sed.npy
#  J1928+178_20GeV_15_bin6/4fgl_j1929.0+1729_sed.npy
#  J1928+178_20GeV_15_bin6/4fgl_j1932.3+1916i_ext.npy
#  J1928+178_20GeV_15_bin6/4fgl_j1932.3+1916i_loc.npy
#  J1928+178_20GeV_15_bin6/4fgl_j1932.3+1916i_sed.npy
#  J1928+178_20GeV_15_bin6/J1928+178_1_component_best.npy
#  J1928+178_20GeV_15_bin6/J1928+178_1_component_freeloc.npy
#  J1928+178_20GeV_15_bin6/J1928+178_1_component.npy
#  J1928+178_20GeV_15_bin6/J1928+178_2_component_best.npy
# 'J1928+178_20GeV_15_bin6/J1928+178&J1932+1916_20GeV_Coponents_1_NBL_Allfree_Location.npy'
# 'J1928+178_20GeV_15_bin6/J1928+178&J1932+1916_20GeV_Coponents_2_NBL.npy'
#  J1928+178_20GeV_15_bin6/J1932+1916_20GeV_Coponents_1_NBL_Allfree_Location.npy

# %%
c = np.load('J1928+178_0.8GeV_15_bin6/J1928+178&J1932+1916_0.8GeV_Delete.npy', allow_pickle=True).flat[0]

# %% [markdown]
# The `sources` dictionary has an entry for each source in the model:

# %%
sorted(c['sources'].keys())
# Out:
# ['4FGL J1841.3+2909',
#  '4FGL J1842.1+2737',
#  '4FGL J1844.4+1547',
#  '4FGL J1845.0+1613',
#  '4FGL J1846.3+0919',
#  '4FGL J1849.4+2745',
#  '4FGL J1850.5+2631',
#  '4FGL J1851.5+0718',
#  '4FGL J1855.2+0756',
#  '4FGL J1856.2+0749',
#  '4FGL J1856.5+1735',
#  '4FGL J1857.2+0941',
#  '4FGL J1858.5+0640',
#  '4FGL J1859.0+2329',
#  '4FGL J1859.8+1545',
#  '4FGL J1901.1+0730',
#  '4FGL J1902.5+0654',
#  '4FGL J1906.1+1651',
#  '4FGL J1906.2+0631',
#  '4FGL J1906.4+0723',
#  '4FGL J1906.9+0712',
#  '4FGL J1908.6+0915e',
#  '4FGL J1908.7+0812',
#  '4FGL J1908.9+2103',
#  '4FGL J1910.2+0904',
#  '4FGL J1910.8+2856',
#  '4FGL J1911.0+0905',
#  '4FGL J1911.7+1014',
#  '4FGL J1912.0+1612',
#  '4FGL J1912.5+1320',
#  '4FGL J1912.7+0957',
#  '4FGL J1913.3+0905',
#  '4FGL J1913.3+1019',
#  '4FGL J1914.5+1107',
#  '4FGL J1914.7+1012',
#  '4FGL J1915.3+1149',
#  '4FGL J1916.3+1108',
#  '4FGL J1918.1+1215',
#  '4FGL J1919.1+2354',
#  '4FGL J1919.4+1313',
#  '4FGL J1920.7+1334',
#  '4FGL J1920.9+1408',
#  '4FGL J1921.1+1930',
#  '4FGL J1922.2+2314',
#  '4FGL J1922.4+1453',
#  '4FGL J1922.7+1428',
#  '4FGL J1923.2+1408e',
#  '4FGL J1924.3+1601',
#  '4FGL J1925.0+2815',
#  '4FGL J1925.1+1707',
#  '4FGL J1925.2+1729',
#  '4FGL J1925.3+1522',
#  '4FGL J1925.4+1616',
#  '4FGL J1925.7+1227',
#  '4FGL J1926.4+1602',
#  '4FGL J1926.7+3027',
#  '4FGL J1928.8+3126',
#  '4FGL J1929.0+1729',
#  '4FGL J1929.8+1832',
#  '4FGL J1930.3+0911',
#  '4FGL J1931.1+0937',
#  '4FGL J1931.1+1656',
#  '4FGL J1932.2+2221',
#  '4FGL J1932.3+1916',
#  '4FGL J1933.3+0726',
#  '4FGL J1934.2+1036',
#  '4FGL J1934.3+1859',
#  '4FGL J1935.2+2029',
#  '4FGL J1936.6+1921',
#  '4FGL J1939.6+2135',
#  '4FGL J1942.7+1033',
#  '4FGL J1943.9+2841',
#  '4FGL J1944.0+2117',
#  '4FGL J1946.0+0937',
#  '4FGL J1946.1+2436',
#  '4FGL J1947.1+1729',
#  '4FGL J1947.7+2744',
#  '4FGL J1948.3+1207',
#  '4FGL J1949.0+1314',
#  '4FGL J1949.4+1247',
#  '4FGL J1949.5+0906',
#  '4FGL J1950.6+2416',
#  '4FGL J1950.8+1211',
#  '4FGL J1951.0+2523',
#  '4FGL J1951.6+2621',
#  '4FGL J1952.8+2924',
#  '4FGL J1953.6+1846',
#  '4FGL J1954.3+2836',
#  '4FGL J1954.5+2420',
#  '4FGL J1954.8+2543',
#  '4FGL J1955.2+1358',
#  '4FGL J1957.6+1230',
#  '4FGL J1958.1+2438',
#  '4FGL J1958.7+2846',
#  '4FGL J1959.5+2048',
#  '4FGL J1959.9+1833',
#  '4FGL J2004.1+2517',
#  '4FGL J2006.2+3102',
#  '4FGL J2007.9+2511',
#  '4FGL J2008.4+1619',
#  '4FGL J2010.0+0726',
#  '4FGL J2014.5+0648',
#  '4FGL J2015.0+1621',
#  '4FGL J2017.4+0602',
#  '4FGL J2019.6+0616',
#  '4FGL J2027.0+2811',
#  'galdiff',
#  'isodiff']

# %% [markdown]
# Let's take a look at the flux, spectral parameters, and TS of one of the sources.

# %%
gta.print_roi()
# Out:
# 2022-06-23 00:58:34 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1932.3+1916   PointSource    PLSuperExpCuto    0.449   2441.77      6018.8
# 4FGL J1929.8+1832   PointSource    PowerLaw          0.482     93.88      1254.5
# 4FGL J1934.3+1859   PointSource    LogParabola       0.794    118.49      1431.9
# 4FGL J1936.6+1921   PointSource    LogParabola       1.399     39.75       533.4
# 4FGL J1929.0+1729   PointSource    LogParabola       1.527    500.88      3267.4
# 4FGL J1935.2+2029   PointSource    PLSuperExpCuto    1.846    198.74      1746.4
# 4FGL J1925.2+1729   PointSource    PLSuperExpCuto    1.991    104.85      1363.3
# 4FGL J1931.1+1656   PointSource    LogParabola       2.000    508.01      2878.9
# 4FGL J1925.1+1707   PointSource    PowerLaw          2.289     70.87      1025.9
# 4FGL J1921.1+1930   PointSource    PowerLaw          2.386     59.48       549.3
# 4FGL J1925.4+1616   PointSource    PowerLaw          2.977    273.61      1905.4
# 4FGL J1926.4+1602   PointSource    LogParabola       3.097    177.08      1850.4
# 4FGL J1924.3+1601   PointSource    PowerLaw          3.314     72.96      1156.9
# 4FGL J1939.6+2135   PointSource    PLSuperExpCuto    3.343    199.41      1521.8
# 4FGL J1932.2+2221   PointSource    PLSuperExpCuto    3.431     22.93       317.8
# 4FGL J1925.3+1522   PointSource    LogParabola       3.820    119.89      1559.0
# 4FGL J1944.0+2117   PointSource    LogParabola       3.855    285.80       160.9
# 4FGL J1947.1+1729   PointSource    PowerLaw          4.094     23.04       151.3
# 4FGL J1922.4+1453   PointSource    LogParabola       4.535     99.90      1638.7
# 4FGL J1922.2+2314   PointSource    PowerLaw          4.760    112.42       396.6
# 4FGL J1922.7+1428   PointSource    LogParabola       4.882    252.21      3088.1
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       5.143  19766.39     25368.7
# 4FGL J1912.0+1612   PointSource    PowerLaw          5.274     35.01       407.2
# 4FGL J1920.9+1408   PointSource    LogParabola       5.364    273.61      2862.5
# 4FGL J1953.6+1846   PointSource    LogParabola       5.366     44.81       274.8
# 4FGL J1908.9+2103   PointSource    PLSuperExpCuto    5.591    137.44       484.5
# 4FGL J1919.1+2354   PointSource    LogParabola       5.675     89.00       473.9
# 4FGL J1920.7+1334   PointSource    LogParabola       5.909     50.98       880.7
# 4FGL J1906.1+1651   PointSource    LogParabola       6.260    121.49       280.9
# 4FGL J1919.4+1313   PointSource    LogParabola       6.347    159.44      1958.2
# 4FGL J1925.7+1227   PointSource    LogParabola       6.603    136.60      1003.7
# 4FGL J1946.1+2436   PointSource    LogParabola       6.663     55.88       562.8
# 4FGL J1959.9+1833   PointSource    PowerLaw          6.869     20.80       152.7
# 4FGL J1959.5+2048   PointSource    PLSuperExpCuto    6.979    948.26      1514.9
# 4FGL J1950.6+2416   PointSource    LogParabola       7.023     57.45       656.0
# 4FGL J1912.5+1320   PointSource    LogParabola       7.137    108.34      1097.5
# 4FGL J1949.0+1314   PointSource    PowerLaw          7.154    186.00       515.0
# 4FGL J1918.1+1215   PointSource    LogParabola       7.359    128.95      1571.8
# 4FGL J1949.4+1247   PointSource    PowerLaw          7.589     18.60       126.4
# 4FGL J1955.2+1358   PointSource    LogParabola       7.649    214.40       566.4
# 4FGL J1954.5+2420   PointSource    LogParabola       7.698     51.24       439.8
# 4FGL J1951.0+2523   PointSource    LogParabola       7.949     56.54       649.8
# 4FGL J1948.3+1207   PointSource    LogParabola       8.011     44.90       270.4
# 4FGL J1915.3+1149   PointSource    LogParabola       8.061    188.90      1662.9
# 4FGL J1859.8+1545   PointSource    PowerLaw          8.069      6.79        72.0
# 4FGL J1950.8+1211   PointSource    LogParabola       8.272    160.68       478.9
# 4FGL J1856.5+1735   PointSource    PowerLaw          8.283      0.00         4.4
# 4FGL J1934.2+1036   PointSource    PowerLaw          8.381      0.19        41.5
# 4FGL J1958.1+2438   PointSource    PowerLaw          8.489    133.74       384.8
# 4FGL J1916.3+1108   PointSource    LogParabola       8.567     99.32      1539.7
# 4FGL J1859.0+2329   PointSource    PowerLaw          8.716     60.08       145.8
# 4FGL J1954.8+2543   PointSource    LogParabola       8.738     46.63       566.2
# 4FGL J1914.5+1107   PointSource    LogParabola       8.769      4.94       342.6
# 4FGL J1951.6+2621   PointSource    LogParabola       8.809     63.48       542.4
# 4FGL J1942.7+1033   PointSource    PowerLaw          8.856     21.54       399.7
# 4FGL J1957.6+1230   PointSource    PowerLaw          9.075     75.83       235.4
# 4FGL J2008.4+1619   PointSource    PowerLaw          9.298     21.47       423.8
# 4FGL J1931.1+0937   PointSource    LogParabola       9.313      3.16       284.0
# 4FGL J1925.0+2815   PointSource    PowerLaw          9.418      6.68       334.2
# 4FGL J1914.7+1012   PointSource    LogParabola       9.574      0.00         7.6
# 4FGL J1947.7+2744   PointSource    LogParabola       9.590     -0.00         0.0
# 4FGL J1913.3+1019   PointSource    PowerLaw          9.606     -0.00         0.0
# 4FGL J1930.3+0911   PointSource    LogParabola       9.748      0.69       136.4
# 4FGL J1911.7+1014   PointSource    LogParabola       9.870     -0.00         0.1
# 4FGL J2004.1+2517   PointSource    LogParabola       9.961     12.75       157.7
# 4FGL J1946.0+0937   PointSource    PowerLaw         10.012     -0.00         0.0
# 4FGL J1912.7+0957   PointSource    LogParabola      10.014     -0.00         0.1
# 4FGL J1943.9+2841   PointSource    PowerLaw         10.189     -0.00         0.0
# 4FGL J2007.9+2511   PointSource    LogParabola      10.599      0.62        92.4
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto   10.735      1.23       331.9
# 4FGL J2015.0+1621   PointSource    PowerLaw         10.808      0.09        36.9
# 4FGL J1949.5+0906   PointSource    PowerLaw         10.818      0.43        74.7
# 4FGL J1911.0+0905   PointSource    LogParabola      10.971      8.97       784.3
# 4FGL J1910.8+2856   PointSource    PowerLaw         11.002      2.98       202.2
# 4FGL J1954.3+2836   PointSource    PLSuperExpCuto   11.033     -0.00         0.0
# 4FGL J1910.2+0904   PointSource    PowerLaw         11.077     -0.00         0.0
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw         11.093      0.00        12.9
# 4FGL J1845.0+1613   PointSource    PowerLaw         11.279     -0.00         0.0
# 4FGL J1933.3+0726   PointSource    PowerLaw         11.518     -0.00         0.0
# 4FGL J1844.4+1547   PointSource    LogParabola      11.536      0.91       190.2
# 4FGL J1926.7+3027   PointSource    LogParabola      11.561       nan         0.6
# 4FGL J1952.8+2924   PointSource    LogParabola      11.582     -0.00         0.0
# 4FGL J1958.7+2846   PointSource    PLSuperExpCuto   11.686     -0.00         0.0
# 4FGL J1850.5+2631   PointSource    PowerLaw         12.006       nan         0.8
# 4FGL J1908.7+0812   PointSource    LogParabola      12.020      0.80       218.5
# 4FGL J1857.2+0941   PointSource    LogParabola      12.328      0.02        11.9
# 4FGL J1928.8+3126   PointSource    PowerLaw         12.504       nan         0.2
# 4FGL J1849.4+2745   PointSource    PowerLaw         12.975      0.53        54.1
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto   12.994      0.18       103.2
# 4FGL J1906.9+0712   PointSource    LogParabola      13.098      0.01        26.4
# 4FGL J1901.1+0730   PointSource    LogParabola      13.538     -0.00         0.0
# 4FGL J1906.2+0631   PointSource    LogParabola      13.800     -0.00         0.0
# 4FGL J1902.5+0654   PointSource    LogParabola      13.876     -0.00         0.0
# 4FGL J1856.2+0749   PointSource    LogParabola      13.945     -0.00         0.0
# 4FGL J1855.2+0756   PointSource    PowerLaw         14.006       nan         0.6
# 4FGL J1842.1+2737   PointSource    LogParabola      14.166       nan         0.4
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto   14.456      0.13        66.4
# 4FGL J2006.2+3102   PointSource    PLSuperExpCuto   14.488       nan         0.6
# 4FGL J1858.5+0640   PointSource    PowerLaw         14.590       nan         0.4
# 4FGL J2010.0+0726   PointSource    PowerLaw         14.904       nan         0.1
# 4FGL J1851.5+0718   PointSource    LogParabola      15.071       nan         0.5
# 4FGL J1841.3+2909   PointSource    PowerLaw         15.228       nan         0.1
# 4FGL J2027.0+2811   PointSource    LogParabola      15.809       nan         0.3
# 4FGL J2014.5+0648   PointSource    PowerLaw         16.109       nan         0.1
# 4FGL J2017.4+0602   PointSource    PLSuperExpCuto   17.146       nan         0.4
# 4FGL J2019.6+0616   PointSource    PowerLaw         17.337       nan         0.0
# isodiff             ConstantValue  FileFunction      -----    626.06     26805.2
# galdiff             MapCubeFunctio PowerLaw          ----- 880541.60    946663.0

# %% [markdown]
# You can also plot the spectral energy distribution (SED) for this source :

# %% [markdown]
# # 3HWC J1928+178i

# %%
loge_bins=gta.log_energies[::2]

# %% [markdown]
# # 4FGL J1932.3+1916

# %%
sed1916 = gta.sed('4FGL J1932.3+1916',loge_bins=loge_bins)
# Out:
# 2022-06-23 00:58:34 INFO    GTAnalysis.sed(): Computing SED for 4FGL J1932.3+1916
# 2022-06-23 01:12:02 INFO    GTAnalysis._make_sed(): Fitting SED
# 2022-06-23 01:12:02 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1932.3+1916     : ['Index1', 'Expfactor']
# 2022-06-23 01:12:18 INFO    GTAnalysis.sed(): Finished SED
# 2022-06-23 01:12:27 INFO    GTAnalysis.sed(): Execution time: 832.94 s

# %%
E1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['energies'])
dnde1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde'])
dnde_hi1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde_hi'])
dnde_lo1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde_lo'])
plt.errorbar(sed1916['e_ctr'],
             sed1916['dnde'], 
             yerr=sed1916['dnde_err'], fmt ='ko')
plt.loglog(E1916, dnde1916, 'k--',label = '4FGL J1932.3+1916')
plt.loglog(E1916, dnde_hi1916, 'k')
plt.loglog(E1916, dnde_lo1916, 'k')
plt.xlabel('E [MeV]')
plt.ylabel(r'dN/dE [MeV$^{-1}$ cm$^{-2}$ s$^{-1}$]')
plt.title('4FGL J1932.3+1916, E=0.8-1000GeV')
plt.show()

# %%
plt.loglog(E1916, dnde1916*E1916**2, 'k--',label = '4FGL J1932.3+1916')
plt.loglog(E1916, dnde_hi1916*E1916**2, 'k')
plt.loglog(E1916, dnde_lo1916*E1916**2, 'k')

plt.errorbar(sed1916['e_ctr'],
             sed1916['dnde']*sed1916['e_ctr']**2, 
             yerr=sed1916['dnde_err']*sed1916['e_ctr']**2, fmt ='ko')

plt.legend()
plt.grid(ls= '--',alpha=0.5,which='minor')
#plt.ylim(1e-8,1e-3)
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.title('4FGL J1932.3+1916, E=0.8-1000GeV')

plt.show()

# %%
plt.loglog(E1916, dnde1916*E1916**2, 'k--',label = '4FGL J1932.3+1916')
plt.loglog(E1916, dnde_hi1916*E1916**2, 'k')
plt.loglog(E1916, dnde_lo1916*E1916**2, 'k')

plt.errorbar(sed1916['e_ctr'],
             sed1916['dnde']*sed1916['e_ctr']**2, 
             yerr=sed1916['dnde_err']*sed1916['e_ctr']**2, fmt ='ko')
plt.legend()
plt.grid(ls= '--',alpha=0.5,which='minor')

plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.title('4FGL J1932.3+1916, E=0.8-1000GeV')
plt.show()

# %% [markdown]
# # combined

# %%
fig = plt.figure(figsize=(14, 10))

plt.errorbar(sed1916['e_ctr'],
             sed1916['dnde']*sed1916['e_ctr']**2, 
             yerr=sed1916['dnde_err']*sed1916['e_ctr']**2, fmt ='ko')
plt.loglog(E1916, dnde1916*E1916**2, 'k--',label = '4FGL J1932.3+1916')
plt.loglog(E1916, dnde_hi1916*E1916**2, 'k')
plt.loglog(E1916, dnde_lo1916*E1916**2, 'k')

plt.errorbar(sed1916i['e_ctr'],
             sed1916i['dnde']*sed1916i['e_ctr']**2, 
             yerr=sed1916i['dnde_err']*sed1916i['e_ctr']**2, fmt ='bo')
plt.loglog(E1916i, dnde1916i*E1916i**2, 'b--',label = '4FGL J1932.3+1916i')
plt.loglog(E1916i, dnde_hi1916i*E1916i**2, 'b')
plt.loglog(E1916i, dnde_lo1916i*E1916i**2, 'b')

plt.grid(ls= '--',alpha=0.5,which='minor')
plt.ylim(1e-7,2e-5)
plt.legend(loc='upper right',fontsize=20)
plt.tick_params(which='minor', direction='in', length=5, width=1, bottom=True, top=True, left=True, right=True)
plt.xlabel('E [MeV]')
plt.grid(which='major')
plt.rcParams.update({'font.size': 20})
plt.ylabel(r'E$^{2}$dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.title('4FGL J1932.3+1916, E=0.8-1000GeV')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1206/2598700220.py in <module>
#       8 plt.loglog(E1916, dnde_lo1916*E1916**2, 'k')
#       9
# ---> 10 plt.errorbar(sed1916i['e_ctr'],
#      11              sed1916i['dnde']*sed1916i['e_ctr']**2,
#      12              yerr=sed1916i['dnde_err']*sed1916i['e_ctr']**2, fmt ='bo')
#
# NameError: name 'sed1916i' is not defined

# %%
# Imports
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from astropy.io import fits

# Functions
def e2f_pl(x,a,b,c):
     return x*x*(a*pow(x/b,-c))
    
def e2f_err_sup(x,a,b,c,dc,da):
    return e2f_pl(x,a,b,c) * ( 1. + np.sqrt( (da/a)**2. + ((np.log(x/b)*dc)**2.)) )

def e2f_err_inf(x,a,b,c,dc,da):
    return e2f_pl(x,a,b,c) * ( 1. - np.sqrt( (da/a)**2. + ((np.log(x/b)*dc)**2.)) )

erg = 1.609

# J1932 parameters
j1932_3ML_emin = 1
j1932_3ML_emax = 43
j1932_3ML_epivot = 10
j1932_3ML_flux = 1.945141e-24 * 1e9 * erg
j1932_3ML_flux_err_low = 4.6e-25* 1e9 * erg
j1932_3ML_flux_err_high = 6.43e-25 * 1e9 * erg
j1932_3ML_index = 2.457317e+00
j1932_3ML_index_err = 2.4e-01

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('Energy (TeV)')
ax.set_ylabel('E$^2$ dN/dE (erg cm$^{-2}$ s$^{-1}$)')
ax.set_yscale('log')
ax.set_xscale('log')
plt.rcParams.update({'font.size': 20})

x = np.arange(j1932_3ML_emin, j1932_3ML_emax, 0.2)
y = e2f_pl(x,j1932_3ML_flux,j1932_3ML_epivot,j1932_3ML_index)
ax.plot(x,y, color='orange', label='HAWC J1932+192 (3ML - this work)')
yt = e2f_err_sup(x,j1932_3ML_flux,j1932_3ML_epivot,j1932_3ML_index,j1932_3ML_index_err,j1932_3ML_flux_err_high)
yb = e2f_err_inf(x,j1932_3ML_flux,j1932_3ML_epivot,j1932_3ML_index,j1932_3ML_index_err,j1932_3ML_flux_err_low)
plt.fill_between(x, yt, yb, color='orange',alpha=0.3)

#ax.set_xlim([0.6,100])
ax.set_ylim([1e-14,5e-11])
ax.tick_params(axis='y', direction='in', length=10, width=1, left=True, right=True)
ax.tick_params(axis='x', direction='in', length=10, width=1, pad=8, bottom=True, top=True)
plt.tick_params(which='minor', direction='in', length=5, width=1, bottom=True, top=True, left=True, right=True)

#
#E1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['energies'])
#dnde1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde'])
#dnde_hi1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde_hi'])
#dnde_lo1916 = np.array(c['sources']['4FGL J1932.3+1916']['model_flux']['dnde_lo'])

E1916i = np.array(c['sources']['4FGL J1932.3+1916i']['model_flux']['energies'])
dnde1916i = np.array(c['sources']['4FGL J1932.3+1916i']['model_flux']['dnde'])
dnde_hi1916i = np.array(c['sources']['4FGL J1932.3+1916i']['model_flux']['dnde_hi'])
dnde_lo1916i = np.array(c['sources']['4FGL J1932.3+1916i']['model_flux']['dnde_lo'])

ax.errorbar(sed1916['e_ctr']*1e-6,
             sed1916['dnde']*erg*1e-6*sed1916['e_ctr']**2, 
             yerr=sed1916['dnde_err']*erg*1e-6*sed1916['e_ctr']**2, fmt ='ko')
ax.loglog(E1916*1e-6, dnde1916*erg*1e-6*E1916**2, 'k--',label = '4FGL J1932.3+1916')
ax.loglog(E1916*1e-6, dnde_hi1916*erg*1e-6*E1916**2, 'k')
ax.loglog(E1916*1e-6, dnde_lo1916*erg*1e-6*E1916**2, 'k')

ax.errorbar(sed1916i['e_ctr']*1e-6,
             sed1916i['dnde']*erg*1e-6*sed1916i['e_ctr']**2, 
             yerr=sed1916i['dnde_err']*erg*1e-6*sed1916i['e_ctr']**2, fmt ='bo')
ax.loglog(E1916i*1e-6, dnde1916i*erg*1e-6*E1916i**2, 'b--',label = '4FGL J1932.3+1916i')
ax.loglog(E1916i*1e-6, dnde_hi1916i*1e-6*erg*E1916i**2, 'b')
ax.loglog(E1916i*1e-6, dnde_lo1916i*1e-6*erg*E1916i**2, 'b')
#
#plt.legend(loc='upper right', prop={'size': 14})
plt.title('4FGL J1932.3+1916, E=0.8-1000GeV')
plt.subplots_adjust(left=0.17, right=0.95, top=0.95, bottom=0.12)
plt.rcParams.update({'font.size': 14})
plt.grid()
